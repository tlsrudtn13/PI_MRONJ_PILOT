# %% [markdown]
# # PI-MRONJ — One-click reproducible pipeline (R, Colab)
#
# Cleaned, seed-fixed reorganisation of the analysis. **Same analysis logic, same results** — only structure and reproducibility changed.
#
# **Run order:** Setup → Data foundation → **0-month model selection (run once, frozen)** → **offset validation loop (3/6/9M: Cells 8–10 only)** → **table & figure generation**.
#
# **Required uploads to `/content/`:** `PI_MRONJ_v4.xlsx`, `ICC_radiomics_evaluation.xlsx`.
#
# ICC *regeneration* (from observer-remeasurement files) lives in the separate notebook `Reliability_regeneration_ICC.ipynb`. To run everything here: *Runtime ▸ Run all*.

# %% [markdown]
# ## 1. Setup & configuration

# %%
# ================================================================
# PI-MRONJ full analysis — R (Google Colab)
# Auto-install + auto-load version
# ================================================================

# 1. apt-get based packages (install fast on Colab)
apt_pkgs <- c(
  "r-cran-readxl", "r-cran-dplyr", "r-cran-tidyr", "r-cran-ggplot2",
  "r-cran-survival", "r-cran-proc", "r-cran-rms", "r-cran-scales",
  "r-cran-caret", "r-cran-writexl", "r-cran-vgam", "r-cran-e1071",
  "r-cran-xgboost", "r-cran-car"
)

system("apt-get update")
system(paste("apt-get install -y", paste(apt_pkgs, collapse = " ")))

# 2. Packages that must be installed from CRAN
cran_pkgs <- c(
  "geepack", "survminer", "glmnet", "gridExtra", "cowplot", "tableone",
  "forestplot", "ggrepel", "viridis", "ggcorrplot", "dcurves",
  "corrplot", "RColorBrewer", "ResourceSelection", "randomForest",
  "patchwork", "svglite", "ggbreak"
)

# 3. Install only the packages not already installed
to_install <- cran_pkgs[!(cran_pkgs %in% installed.packages()[, "Package"])]

if (length(to_install) > 0) {
  install.packages(to_install, repos = "https://cran.rstudio.com")
}

# 4. Load all packages
all_pkgs <- c(
  "readxl", "dplyr", "tidyr", "ggplot2", "geepack", "survival",
  "survminer", "glmnet", "pROC", "rms", "scales", "gridExtra",
  "cowplot", "tableone", "ggrepel", "viridis", "writexl", "caret",
  "e1071", "xgboost", "car", "ggcorrplot", "dcurves", "corrplot",
  "RColorBrewer", "ResourceSelection", "randomForest", "patchwork",
  "svglite", "ggbreak"
)

suppressPackageStartupMessages(
  lapply(all_pkgs, library, character.only = TRUE)
)

cat("✅ All required packages installed and loaded!\n")

# ── Paths & theme setup ───────────────────────────────────
DATA_PATH <- "/content/PI_MRONJ_v4.xlsx"
SAVE_DIR  <- "/content/Results_R"
dir.create(SAVE_DIR, showWarnings = FALSE, recursive = TRUE)

#theme_mronj <- theme_bw(base_size = 12) +
#  theme(plot.title    = element_text(face = "bold", hjust = 0.5),
#        plot.subtitle = element_text(hjust = 0.5, color = "gray40"),
#        legend.position = "bottom",
#        strip.background = element_rect(fill = "gray95"))

cat(sprintf("🚀 Setup complete! (save path: %s)\n", SAVE_DIR))

# ── Reproducibility & run config ───────────────────────────────
SEED    <- 42L            # project-wide RNG seed (governs Uni-GEE set.seed & bootstrap)
OFFSETS <- c(0, 3, 6, 9)  # 0 = full model selection; 3/6/9 = sensitivity validation only
set.seed(SEED)
# NOTE: R's default RNG (Mersenne-Twister / Inversion / Rejection) is used, as in the
#       original analysis. No RNGkind() override is set, to preserve the exact random stream.

# ── Required inputs (upload to SAVE_DIR before running) ────────
#   Upload BOTH to /content/ (not Results_R, which is created only when this cell runs):
#   1) /content/PI_MRONJ_v4.xlsx              -> main de-identified feature table (DATA_PATH)
#   2) /content/ICC_radiomics_evaluation.xlsx -> radiomic reliability table consumed by Multi-GEE
#                                                (sheet 'ICC_stable_features'); prepared upstream.
icc_input <- file.path("/content", "ICC_radiomics_evaluation.xlsx")
if (!file.exists(icc_input))
  warning(sprintf("ICC table not found at %s — Multi-GEE will fail until it is uploaded.", icc_input))
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘litedown’, ‘markdown’, ‘png’, ‘jpeg’, ‘gtools’, ‘ggsci’, ‘ggsignif’, ‘polynom’, ‘rstatix’, ‘exactRankTests’, ‘gridtext’, ‘mitools’, ‘gdata’, ‘gridGraphics’, ‘ggpubr’, ‘maxstat’, ‘ggtext’, ‘survey’, ‘gmodels’, ‘labelled’, ‘pbapply’, ‘ggfun’, ‘ggplotify’, ‘aplot’, ‘yulab.utils’
# [[1]]
# [1] "readxl"    "stats"     "graphics"  "grDevices" "utils"     "datasets"
# [7] "methods"   "base"
#
# [[2]]
# [1] "dplyr"     "readxl"    "stats"     "graphics"  "grDevices" "utils"
# [7] "datasets"  "methods"   "base"
#
# [[3]]
#  [1] "tidyr"     "dplyr"     "readxl"    "stats"     "graphics"  "grDevices"
#  [7] "utils"     "datasets"  "methods"   "base"
#
# [[4]]
#  [1] "ggplot2"   "tidyr"     "dplyr"     "readxl"    "stats"     "graphics"
#  [7] "grDevices" "utils"     "datasets"  "methods"   "base"
#
# [[5]]
#  [1] "geepack"   "ggplot2"   "tidyr"     "dplyr"     "readxl"    "stats"
#  [7] "graphics"  "grDevices" "utils"     "datasets"  "methods"   "base"
#
# [[6]]
#  [1] "survival"  "geepack"   "ggplot2"   "tidyr"     "dplyr"     "readxl"
#  [7] "stats"     "graphics"  "grDevices" "utils"     "datasets"  "methods"
# [13] "base"
#
# [[7]]
#  [1] "survminer" "ggpubr"    "survival"  "geepack"   "ggplot2"   "tidyr"
#  [7] "dplyr"     "readxl"    "stats"     "graphics"  "grDevices" "utils"
# [13] "datasets"  "methods"   "base"
#
# [[8]]
#  [1] "glmnet"    "Matrix"    "survminer" "ggpubr"    "survival"  "geepack"
#  [7] "ggplot2"   "tidyr"     "dplyr"     "readxl"    "stats"     "graphics"
# [13] "grDevices" "utils"     "datasets"  "methods"   "base"
#
# [[9]]
#  [1] "pROC"      "glmnet"    "Matrix"    "survminer" "ggpubr"    "survival"
#  [7] "geepack"   "ggplot2"   "tidyr"     "dplyr"     "readxl"    "stats"
# [13] "graphics"  "grDevices" "utils"     "datasets"  "methods"   "base"
#
# [[10]]
#  [1] "rms"       "Hmisc"     "pROC"      "glmnet"    "Matrix"    "survminer"
#  [7] "ggpubr"    "survival"  "geepack"   "ggplot2"   "tidyr"     "dplyr"
# [13] "readxl"    "stats"     "graphics"  "grDevices" "utils"     "datasets"
# [19] "methods"   "base"
#
# [[11]]
#  [1] "scales"    "rms"       "Hmisc"     "pROC"      "glmnet"    "Matrix"
#  [7] "survminer" "ggpubr"    "survival"  "geepack"   "ggplot2"   "tidyr"
# [13] "dplyr"     "readxl"    "stats"     "graphics"  "grDevices" "utils"
# [19] "datasets"  "methods"   "base"
#
# [[12]]
#  [1] "gridExtra" "scales"    "rms"       "Hmisc"     "pROC"      "glmnet"
#  [7] "Matrix"    "survminer" "ggpubr"    "survival"  "geepack"   "ggplot2"
# [13] "tidyr"     "dplyr"     "readxl"    "stats"     "graphics"  "grDevices"
# [19] "utils"     "datasets"  "methods"   "base"
#
# [[13]]
#  [1] "cowplot"   "gridExtra" "scales"    "rms"       "Hmisc"     "pROC"
#  [7] "glmnet"    "Matrix"    "survminer" "ggpubr"    "survival"  "geepack"
# [13] "ggplot2"   "tidyr"     "dplyr"     "readxl"    "stats"     "graphics"
# [19] "grDevices" "utils"     "datasets"  "methods"   "base"
#
# [[14]]
#  [1] "tableone"  "cowplot"   "gridExtra" "scales"    "rms"       "Hmisc"
#  [7] "pROC"      "glmnet"    "Matrix"    "survminer" "ggpubr"    "survival"
# [13] "geepack"   "ggplot2"   "tidyr"     "dplyr"     "readxl"    "stats"
# [19] "graphics"  "grDevices" "utils"     "datasets"  "methods"   "base"
#
# [[15]]
#  [1] "ggrepel"   "tableone"  "cowplot"   "gridExtra" "scales"    "rms"
#  [7] "Hmisc"     "pROC"      "glmnet"    "Matrix"    "survminer" "ggpubr"
# [13] "survival"  "geepack"   "ggplot2"   "tidyr"     "dplyr"     "readxl"
# [19] "stats"     "graphics"  "grDevices" "utils"     "datasets"  "methods"
# [25] "base"
#
# [[16]]
#  [1] "viridis"     "viridisLite" "ggrepel"     "tableone"    "cowplot"
#  [6] "gridExtra"   "scales"      "rms"         "Hmisc"       "pROC"
# [11] "glmnet"      "Matrix"      "survminer"   "ggpubr"      "survival"
# [16] "geepack"     "ggplot2"     "tidyr"       "dplyr"       "readxl"
# [21] "stats"       "graphics"    "grDevices"   "utils"       "datasets"
# [26] "methods"     "base"
#
# [[17]]
#  [1] "writexl"     "viridis"     "viridisLite" "ggrepel"     "tableone"
#  [6] "cowplot"     "gridExtra"   "scales"      "rms"         "Hmisc"
# [11] "pROC"        "glmnet"      "Matrix"      "survminer"   "ggpubr"
# [16] "survival"    "geepack"     "ggplot2"     "tidyr"       "dplyr"
# [21] "readxl"      "stats"       "graphics"    "grDevices"   "utils"
# [26] "datasets"    "methods"     "base"
#
# [[18]]
#  [1] "caret"       "lattice"     "writexl"     "viridis"     "viridisLite"
#  [6] "ggrepel"     "tableone"    "cowplot"     "gridExtra"   "scales"
# [11] "rms"         "Hmisc"       "pROC"        "glmnet"      "Matrix"
# [16] "survminer"   "ggpubr"      "survival"    "geepack"     "ggplot2"
# [21] "tidyr"       "dplyr"       "readxl"      "stats"       "graphics"
# [26] "grDevices"   "utils"       "datasets"    "methods"     "base"
#
# [[19]]
#  [1] "e1071"       "caret"       "lattice"     "writexl"     "viridis"
#  [6] "viridisLite" "ggrepel"     "tableone"    "cowplot"     "gridExtra"
# [11] "scales"      "rms"         "Hmisc"       "pROC"        "glmnet"
# [16] "Matrix"      "survminer"   "ggpubr"      "survival"    "geepack"
# [21] "ggplot2"     "tidyr"       "dplyr"       "readxl"      "stats"
# [26] "graphics"    "grDevices"   "utils"       "datasets"    "methods"
# [31] "base"
#
# [[20]]
#  [1] "xgboost"     "e1071"       "caret"       "lattice"     "writexl"
#  [6] "viridis"     "viridisLite" "ggrepel"     "tableone"    "cowplot"
# [11] "gridExtra"   "scales"      "rms"         "Hmisc"       "pROC"
# [16] "glmnet"      "Matrix"      "survminer"   "ggpubr"      "survival"
# [21] "geepack"     "ggplot2"     "tidyr"       "dplyr"       "readxl"
# [26] "stats"       "graphics"    "grDevices"   "utils"       "datasets"
# [31] "methods"     "base"
#
# [[21]]
#  [1] "car"         "carData"     "xgboost"     "e1071"       "caret"
#  [6] "lattice"     "writexl"     "viridis"     "viridisLite" "ggrepel"
# [11] "tableone"    "cowplot"     "gridExtra"   "scales"      "rms"
# [16] "Hmisc"       "pROC"        "glmnet"      "Matrix"      "survminer"
# [21] "ggpubr"      "survival"    "geepack"     "ggplot2"     "tidyr"
# [26] "dplyr"       "readxl"      "stats"       "graphics"    "grDevices"
# [31] "utils"       "datasets"    "methods"     "base"
#
# [[22]]
#  [1] "ggcorrplot"  "car"         "carData"     "xgboost"     "e1071"
#  [6] "caret"       "lattice"     "writexl"     "viridis"     "viridisLite"
# [11] "ggrepel"     "tableone"    "cowplot"     "gridExtra"   "scales"
# [16] "rms"         "Hmisc"       "pROC"        "glmnet"      "Matrix"
# [21] "survminer"   "ggpubr"      "survival"    "geepack"     "ggplot2"
# [26] "tidyr"       "dplyr"       "readxl"      "stats"       "graphics"
# [31] "grDevices"   "utils"       "datasets"    "methods"     "base"
#
# [[23]]
#  [1] "dcurves"     "ggcorrplot"  "car"         "carData"     "xgboost"
#  [6] "e1071"       "caret"       "lattice"     "writexl"     "viridis"
# [11] "viridisLite" "ggrepel"     "tableone"    "cowplot"     "gridExtra"
# [16] "scales"      "rms"         "Hmisc"       "pROC"        "glmnet"
# [21] "Matrix"      "survminer"   "ggpubr"      "survival"    "geepack"
# [26] "ggplot2"     "tidyr"       "dplyr"       "readxl"      "stats"
# [31] "graphics"    "grDevices"   "utils"       "datasets"    "methods"
# [36] "base"
#
# [[24]]
#  [1] "corrplot"    "dcurves"     "ggcorrplot"  "car"         "carData"
#  [6] "xgboost"     "e1071"       "caret"       "lattice"     "writexl"
# [11] "viridis"     "viridisLite" "ggrepel"     "tableone"    "cowplot"
# [16] "gridExtra"   "scales"      "rms"         "Hmisc"       "pROC"
# [21] "glmnet"      "Matrix"      "survminer"   "ggpubr"      "survival"
# [26] "geepack"     "ggplot2"     "tidyr"       "dplyr"       "readxl"
# [31] "stats"       "graphics"    "grDevices"   "utils"       "datasets"
# [36] "methods"     "base"
#
# [[25]]
#  [1] "RColorBrewer" "corrplot"     "dcurves"      "ggcorrplot"   "car"
#  [6] "carData"      "xgboost"      "e1071"        "caret"        "lattice"
# [11] "writexl"      "viridis"      "viridisLite"  "ggrepel"      "tableone"
# [16] "cowplot"      "gridExtra"    "scales"       "rms"          "Hmisc"
# [21] "pROC"         "glmnet"       "Matrix"       "survminer"    "ggpubr"
# [26] "survival"     "geepack"      "ggplot2"      "tidyr"        "dplyr"
# [31] "readxl"       "stats"        "graphics"     "grDevices"    "utils"
# [36] "datasets"     "methods"      "base"
#
# [[26]]
#  [1] "ResourceSelection" "RColorBrewer"      "corrplot"
#  [4] "dcurves"           "ggcorrplot"        "car"
#  [7] "carData"           "xgboost"           "e1071"
# [10] "caret"             "lattice"           "writexl"
# [13] "viridis"           "viridisLite"       "ggrepel"
# [16] "tableone"          "cowplot"           "gridExtra"
# [19] "scales"            "rms"               "Hmisc"
# [22] "pROC"              "glmnet"            "Matrix"
# [25] "survminer"         "ggpubr"            "survival"
# [28] "geepack"           "ggplot2"           "tidyr"
# [31] "dplyr"             "readxl"            "stats"
# [34] "graphics"          "grDevices"         "utils"
# [37] "datasets"          "methods"           "base"
#
# [[27]]
#  [1] "randomForest"      "ResourceSelection" "RColorBrewer"
#  [4] "corrplot"          "dcurves"           "ggcorrplot"
#  [7] "car"               "carData"           "xgboost"
# [10] "e1071"             "caret"             "lattice"
# [13] "writexl"           "viridis"           "viridisLite"
# [16] "ggrepel"           "tableone"          "cowplot"
# [19] "gridExtra"         "scales"            "rms"
# [22] "Hmisc"             "pROC"              "glmnet"
# [25] "Matrix"            "survminer"         "ggpubr"
# [28] "survival"          "geepack"           "ggplot2"
# [31] "tidyr"             "dplyr"             "readxl"
# [34] "stats"             "graphics"          "grDevices"
# [37] "utils"             "datasets"          "methods"
# [40] "base"
#
# [[28]]
#  [1] "patchwork"         "randomForest"      "ResourceSelection"
#  [4] "RColorBrewer"      "corrplot"          "dcurves"
#  [7] "ggcorrplot"        "car"               "carData"
# [10] "xgboost"           "e1071"             "caret"
# [13] "lattice"           "writexl"           "viridis"
# [16] "viridisLite"       "ggrepel"           "tableone"
# [19] "cowplot"           "gridExtra"         "scales"
# [22] "rms"               "Hmisc"             "pROC"
# [25] "glmnet"            "Matrix"            "survminer"
# [28] "ggpubr"            "survival"          "geepack"
# [31] "ggplot2"           "tidyr"             "dplyr"
# [34] "readxl"            "stats"             "graphics"
# [37] "grDevices"         "utils"             "datasets"
# [40] "methods"           "base"
#
# [[29]]
#  [1] "svglite"           "patchwork"         "randomForest"
#  [4] "ResourceSelection" "RColorBrewer"      "corrplot"
#  [7] "dcurves"           "ggcorrplot"        "car"
# [10] "carData"           "xgboost"           "e1071"
# [13] "caret"             "lattice"           "writexl"
# [16] "viridis"           "viridisLite"       "ggrepel"
# [19] "tableone"          "cowplot"           "gridExtra"
# [22] "scales"            "rms"               "Hmisc"
# [25] "pROC"              "glmnet"            "Matrix"
# [28] "survminer"         "ggpubr"            "survival"
# [31] "geepack"           "ggplot2"           "tidyr"
# [34] "dplyr"             "readxl"            "stats"
# [37] "graphics"          "grDevices"         "utils"
# [40] "datasets"          "methods"           "base"
#
# [[30]]
#  [1] "ggbreak"           "svglite"           "patchwork"
#  [4] "randomForest"      "ResourceSelection" "RColorBrewer"
#  [7] "corrplot"          "dcurves"           "ggcorrplot"
# [10] "car"               "carData"           "xgboost"
# [13] "e1071"             "caret"             "lattice"
# [16] "writexl"           "viridis"           "viridisLite"
# [19] "ggrepel"           "tableone"          "cowplot"
# [22] "gridExtra"         "scales"            "rms"
# [25] "Hmisc"             "pROC"              "glmnet"
# [28] "Matrix"            "survminer"         "ggpubr"
# [31] "survival"          "geepack"           "ggplot2"
# [34] "tidyr"             "dplyr"             "readxl"
# [37] "stats"             "graphics"          "grDevices"
# [40] "utils"             "datasets"          "methods"
# [43] "base"
# ✅ All required packages installed and loaded!
# 🚀 Setup complete! (save path: /content/Results_R)

# %% [markdown]
# ## 2. Data foundation (offset-independent)

# %%
# ==============================================================================
# Data foundation (offset-independent): loaders + feature-table builders
#   build_raw_base / build_df_tp / build_df_imp / apply_sensitivity_cutoff
#   Runs build_raw_base() once -> raw_full, clin_cols, radio_base/_wav/_all
# ==============================================================================

build_raw_base <- function(data_path, sheet = "Coding") {
  raw0 <- read_excel(data_path, sheet = sheet)

  clin_cols0  <- c(
    "Insertion_Depth_mm", "Insertion_Angle_deviation",
    "Calculated_C_I_Ratio", "Crown_Height_mm",
    "Is_Single_Prosthesis", "Has_Cantilever",
    "Jaw_Code", "Region_Code", "Opposing_Teeth_Code"
  )

  radio_base0 <- names(raw0)[grepl("^(FO_|GLCM_|GLRLM_|GLSZM_|NGTDM_)", names(raw0))]
  radio_wav0  <- names(raw0)[grepl("^Wav_", names(raw0))]
  radio_all0  <- c(radio_base0, radio_wav0)

  num_cols0 <- c("Days_Since_Surgery", clin_cols0, radio_all0)

  raw0 <- raw0 %>%
    mutate(
      across(any_of(num_cols0), ~ suppressWarnings(as.numeric(.x))),
      Study_Date  = as.numeric(Study_Date),   # relative day-offset (de-identified; no real dates)
      T0_Surgery  = as.numeric(T0_Surgery),   # relative day-offset (de-identified; no real dates)
      PI_MRONJ    = as.integer(`PI-MRONJ`),
      Implant_UID = paste(Patient_ID, Implant_ID, sep = "_")
    )

  list(
    raw = raw0,
    clin_cols = clin_cols0,
    radio_base = radio_base0,
    radio_wav = radio_wav0,
    radio_all = radio_all0
  )
}

build_df_tp <- function(raw_dat, radio_all) {
  raw_dat %>%
    arrange(Implant_UID, Study_Date) %>%
    group_by(Implant_UID) %>%
    mutate(
      Implant_Num = cur_group_id(),
      across(all_of(radio_all), ~ .x - first(.x), .names = "{.col}_change"),
      across(all_of(radio_all), ~ .x - lag(.x), .names = "{.col}_delta"),
      across(
        all_of(radio_all),
        ~ (.x - lag(.x)) /
          pmax(as.numeric(Study_Date - lag(Study_Date)), 1),
        .names = "{.col}_slope"
      )
    ) %>%
    ungroup() %>%
    mutate(
      across(
        where(is.numeric) & !any_of(c("PI_MRONJ", "Implant_Num")),
        ~ ifelse(is.na(.x), median(.x, na.rm = TRUE), .x)
      )
    )
}

build_df_imp <- function(raw_dat, clin_cols, radio_all) {
  raw_dat %>%
    arrange(Implant_UID, Study_Date) %>%
    group_by(Implant_UID, Patient_ID, Implant_ID, PI_MRONJ) %>%
    summarise(
      n_obs = n(),
      Duration = max(as.numeric(max(Study_Date) - min(Study_Date)), 1),
      across(all_of(clin_cols), ~ first(.x)),
      across(all_of(radio_all), ~ first(.x), .names = "{.col}_first"),
      across(all_of(radio_all), ~ if (n() > 1) last(.x) - first(.x) else 0, .names = "{.col}_net"),
      across(
        all_of(radio_all),
        ~ {
          y <- .x
          x <- as.numeric(Study_Date - first(Study_Date))
          if (n() < 2 || max(x) == 0) 0 else unname(coef(lm(y ~ x))[2])
        },
        .names = "{.col}_trend"
      ),
      .groups = "drop"
    ) %>%
    mutate(Event = PI_MRONJ) %>%
    mutate(
      across(
        where(is.numeric) & !any_of(c("PI_MRONJ", "Event", "n_obs", "Duration")),
        ~ ifelse(is.na(.x), median(.x, na.rm = TRUE), .x)
      )
    )
}

apply_sensitivity_cutoff <- function(raw_full, cutoff_months) {
  cutoff_days <- cutoff_months * 30

  # 1. Get each patient's last surgery date (T0_last)
  patient_last_t0 <- raw_full %>%
    filter(!is.na(T0_Surgery)) %>%
    group_by(Patient_ID) %>%
    summarise(T0_last = max(T0_Surgery, na.rm = TRUE), .groups = "drop")

  # 2. Assign a reference date (ref_date) per implant
  # - MRONJ group (Event) uses its own T0_Surgery
  # - Control group (Survival) uses the patient's latest T0_Surgery (T0_last)
  implant_ref <- raw_full %>%
    select(Implant_UID, Patient_ID, T0_Surgery) %>%
    distinct() %>%
    left_join(patient_last_t0, by = "Patient_ID") %>%
    mutate(ref_date = coalesce(T0_Surgery, T0_last)) %>%
    select(Implant_UID, ref_date)

  # 3. Merge reference date and recompute Days_Since_Surgery (T0-based time axis) for all rows
  raw_processed <- raw_full %>%
    left_join(implant_ref, by = "Implant_UID") %>%
    mutate(
      # days from T0 (ref_date) to Study_Date (negative = before surgery)
      Days_Since_Surgery = as.numeric(Study_Date - ref_date),
      # days remaining to T0, for filtering (positive = before surgery)
      Days_To_T0 = as.numeric(ref_date - Study_Date)
    )

  # 4. Strictly apply the cutoff (offset); no exception for controls
  if (cutoff_months > 0) {
    raw_processed <- raw_processed %>%
      # keep only panoramas taken >= cutoff_days before T0, for both groups
      filter(Days_To_T0 >= cutoff_days)
  }

  # drop temporary helper columns and return
  raw_processed %>%
    select(-ref_date, -Days_To_T0)
}

base_obj <- build_raw_base(DATA_PATH, sheet = "Coding")

raw_full    <- base_obj$raw
clin_cols   <- base_obj$clin_cols
radio_base  <- base_obj$radio_base
radio_wav   <- base_obj$radio_wav
radio_all   <- base_obj$radio_all

# %% [markdown]
# ## 3. 0-month model selection (run once → frozen model pool)
# Cells 1–7 run **only at 0M**. Re-running them at another offset would change `df_imp` and therefore the selected models, so they are **not** looped.

# %%
SENS_CUTOFF_MONTHS <- 0L   # model selection is performed once at the 0-month offset

raw <- apply_sensitivity_cutoff(raw_full, SENS_CUTOFF_MONTHS)

df_tp  <- build_df_tp(raw, radio_all)
df_imp <- build_df_imp(raw, clin_cols, radio_all)

tp_radio_raw    <- radio_all
tp_radio_change <- paste0(radio_all, "_change")
tp_radio_delta  <- paste0(radio_all, "_delta")
tp_radio_slope  <- paste0(radio_all, "_slope")

imp_radio_first <- paste0(radio_all, "_first")
imp_radio_net   <- paste0(radio_all, "_net")
imp_radio_trend <- paste0(radio_all, "_trend")

cat("\n[CELL 1] Data preparation complete\n")
cat(sprintf("Sensitivity cutoff: %d months\n", SENS_CUTOFF_MONTHS))
cat(sprintf("raw active: %d rows\n", nrow(raw)))
cat(sprintf("df_tp ready: %d rows | %d cols\n", nrow(df_tp), ncol(df_tp)))
cat(sprintf("df_imp ready: %d rows | %d cols\n", nrow(df_imp), ncol(df_imp)))
cat(sprintf("  MRONJ=%d | Control=%d\n",
            sum(df_imp$PI_MRONJ), sum(df_imp$PI_MRONJ == 0)))
cat(sprintf("  Duration: %.0f ~ %.0f days\n",
            min(df_imp$Duration), max(df_imp$Duration)))

cat("\nColumn groups defined:\n")
cat(sprintf("  tp_radio_raw:    %d\n", length(tp_radio_raw)))
cat(sprintf("  tp_radio_change: %d\n", length(tp_radio_change)))
cat(sprintf("  tp_radio_delta:  %d\n", length(tp_radio_delta)))
cat(sprintf("  tp_radio_slope:  %d\n", length(tp_radio_slope)))
cat(sprintf("  imp_radio_first: %d\n", length(imp_radio_first)))
cat(sprintf("  imp_radio_net:   %d\n", length(imp_radio_net)))
cat(sprintf("  imp_radio_trend: %d\n", length(imp_radio_trend)))
# Out:
# [CELL 1] Data preparation complete
# Sensitivity cutoff: 0 months
# raw active: 245 rows
# df_tp ready: 245 rows | 522 cols
# df_imp ready: 58 rows | 391 cols
#   MRONJ=19 | Control=39
#   Duration: 35 ~ 1843 days
#
# Column groups defined:
#   tp_radio_raw:    125
#   tp_radio_change: 125
#   tp_radio_delta:  125
#   tp_radio_slope:  125
#   imp_radio_first: 125
#   imp_radio_net:   125
#   imp_radio_trend: 125

# %%
# ╔══════════════════════════════════════════════════════════════╗
# ║  CELL 2 — Uni-GEE (D1: single-timepoint, D2: temporal)      ║
# ║  Input : df_tp, Implant_Num, clin_cols, tp_radio_*           ║
# ║  Output: gee_d1, gee_d2, sig_gee (p<0.05 pooled)             ║
# ╚══════════════════════════════════════════════════════════════╝
set.seed(SEED)
cat("\n[CELL 2] Uni-GEE analysis...\n")

# ── Shared GEE function ───────────────────────────────────────
run_gee <- function(vars, data, type_label) {
  results <- lapply(vars, function(v) {
    if (!v %in% names(data)) return(NULL)
    df_tmp <- data %>%
      mutate(x = suppressWarnings(scale(!!sym(v))[,1])) %>%
      select(PI_MRONJ, x, Implant_Num) %>%
      na.omit()
    if (nrow(df_tmp) < 20 || length(unique(df_tmp$x)) < 2) return(NULL)
    tryCatch({
      fit <- geeglm(PI_MRONJ ~ x, data=df_tmp,
                    id=Implant_Num, family=binomial(),
                    corstr="independence")
      s <- summary(fit)$coefficients
      data.frame(
        Feature = v,
        Type    = type_label,
        OR      = round(exp(s["x","Estimate"]), 3),
        CI_lo   = round(exp(s["x","Estimate"] - 1.96*s["x","Std.err"]), 3),
        CI_hi   = round(exp(s["x","Estimate"] + 1.96*s["x","Std.err"]), 3),
        p_value = round(s["x","Pr(>|W|)"], 4)
      )
    }, error=function(e) NULL)
  })
  do.call(rbind, Filter(Negate(is.null), results)) %>%
   mutate(Sig = case_when(
     p_value<0.001~"***", p_value<0.01~"**",
     p_value<0.05~"*",    p_value<0.10~"†", TRUE~"ns")) %>%
    arrange(p_value)
  #do.call(rbind, Filter(Negate(is.null), results)) %>%
   # mutate(
    #  q_value = p.adjust(p_value, method = "BH"),  # 👈 [add 1] compute FDR (q-value) via BH method
     # Sig = case_when(
      #  p_value<0.001~"***", p_value<0.01~"**",
       # p_value<0.05~"*",    p_value<0.10~"†", TRUE~"ns"),
     # Sig_FDR = case_when(                         # 👈 [add 2] flag whether FDR passed
      #  q_value<0.05~"*",    q_value<0.10~"†", TRUE~"ns")
   # ) %>%
    #arrange(p_value)
}

# ── After edit (first line + all comments removed) ─────────────
cat("  [D1] Single-timepoint GEE (radiomics only per v4 protocol)...\n")
gee_d1 <- run_gee(tp_radio_raw, df_tp, "Radiomics")

cat(sprintf("  D1 tested: %d | p<0.05: %d | p<0.10: %d\n",
            nrow(gee_d1),
            sum(gee_d1$p_value<0.05),
            sum(gee_d1$p_value<0.10)))

# ── D2: temporal (change / delta / slope) ─────────────────────
cat("  [D2] Temporal GEE (change / delta / slope)...\n")
gee_d2_change <- run_gee(tp_radio_change, df_tp, "Radiomics_change")
gee_d2_delta  <- run_gee(tp_radio_delta,  df_tp, "Radiomics_delta")
gee_d2_slope  <- run_gee(tp_radio_slope,  df_tp, "Radiomics_slope")
gee_d2 <- bind_rows(gee_d2_change, gee_d2_delta, gee_d2_slope) %>%
  arrange(p_value)

cat(sprintf("  D2 tested: %d | p<0.05: %d | p<0.10: %d\n",
            nrow(gee_d2),
            sum(gee_d2$p_value<0.05),
            sum(gee_d2$p_value<0.10)))

# ── Print results ─────────────────────────────────────────────
cat("\n===== D1 p<0.05 =====\n")
print(gee_d1 %>% filter(p_value<0.05) %>%
      select(Feature, Type, OR, CI_lo, CI_hi, p_value, Sig))

cat("\n===== D2 p<0.05 by type =====\n")
for (tp in c("Radiomics_change","Radiomics_delta","Radiomics_slope")) {
  sub <- gee_d2 %>% filter(Type==tp, p_value<0.05)
  cat(sprintf("  [%s] n=%d\n", sub("Radiomics_","",tp), nrow(sub)))
  if (nrow(sub)>0)
    print(sub %>% select(Feature, OR, CI_lo, CI_hi, p_value, Sig))
}

# ── sig_gee: significant-feature list passed to downstream steps ──
# D1 significant features (clinical kept as-is; radiomics saved as the _first variant)
sig_d1_raw <- gee_d1 %>% filter(p_value<0.10) %>% pull(Feature)

sig_gee <- data.frame(
  Feature_gee = sig_d1_raw,
  Feature_imp = paste0(sig_d1_raw, "_first"),
  Source = "D1",
  stringsAsFactors = FALSE
)

# D2 significant features (recognize the suffix on the base name and map to the df_imp column name)
sig_d2_raw <- gee_d2 %>% filter(p_value<0.10) %>% pull(Feature)
if (length(sig_d2_raw) > 0) {
  sig_gee <- bind_rows(sig_gee, data.frame(
    Feature_gee = sig_d2_raw,
    Feature_imp = sig_d2_raw,   # _change is not in df_imp; only _slope is used in Cox
    Source      = sub(".*_(change|delta|slope)$","D2_\\1", sig_d2_raw),
    stringsAsFactors = FALSE
  ))
}

cat(sprintf("\nTotal sig_gee entries: %d\n", nrow(sig_gee)))

# ── Save to Excel ─────────────────────────────────────────────
save_name_c3 <- sprintf("%s/%dM_Cell2_UniGEE.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS)

write_xlsx(
  list(
    "D1_Single_Timepoint" = gee_d1,
    "D2_Change"   = gee_d2 %>% filter(Type=="Radiomics_change"),
    "D2_Delta"    = gee_d2 %>% filter(Type=="Radiomics_delta"),
    "D2_Slope"    = gee_d2 %>% filter(Type=="Radiomics_slope"),
    "Sig_Features"= sig_gee
  ),
  path = save_name_c3
)
cat(sprintf("Saved: %s\n", save_name_c3))
# Out:
# [CELL 2] Uni-GEE analysis...
#   [D1] Single-timepoint GEE (radiomics only per v4 protocol)...
#   D1 tested: 125 | p<0.05: 1 | p<0.10: 11
#   [D2] Temporal GEE (change / delta / slope)...
#   D2 tested: 375 | p<0.05: 10 | p<0.10: 22
#
# ===== D1 p<0.05 =====
#              Feature      Type    OR CI_lo CI_hi p_value Sig
# 1 Wav_LH_FO_Skewness Radiomics 1.639 1.164 2.307  0.0046  **
#
# ===== D2 p<0.05 by type =====
#   [change] n=3
#                     Feature    OR CI_lo CI_hi p_value Sig
# 1 Wav_HL_FO_Skewness_change 0.550 0.375 0.808  0.0023  **
# 2 Wav_LH_FO_Skewness_change 1.633 1.142 2.336  0.0072  **
# 3     NGTDM_Contrast_change 1.333 1.007 1.765  0.0445   *
#   [delta] n=2
#                    Feature    OR CI_lo CI_hi p_value Sig
# 1 Wav_LH_FO_Skewness_delta 1.182 1.046 1.336  0.0075  **
# 2 Wav_HL_FO_Skewness_delta 0.853 0.752 0.967  0.0130   *
#   [slope] n=5
#                      Feature    OR CI_lo CI_hi p_value Sig
# 1     Wav_HH_FO_Median_slope 1.265 1.016 1.575  0.0352   *
# 2     Wav_LH_FO_Energy_slope 0.820 0.681 0.988  0.0372   *
# 3 Wav_LH_FO_Uniformity_slope 0.820 0.681 0.988  0.0372   *
# 4         Wav_HL_FO_CV_slope 1.341 1.008 1.784  0.0440   *
# 5               FO_IQR_slope 1.205 1.004 1.445  0.0448   *
#
# Total sig_gee entries: 33
# Saved: /content/Results_R/0M_Cell2_UniGEE.xlsx

# %%
# ╔══════════════════════════════════════════════════════════════╗
# ║  CELL 3 — Multi-GEE (★ rule-based auto-combination / revised) ║
# ║  Input : df_tp, Implant_Num, gee_d1, gee_d2 (CELL 2 output)  ║
# ║  Output: multi_gee_res, multi_gee_detail, feat_sets          ║
# ║                                                              ║
# ║  [Revised rules]                                             ║
# ║   Static pool  = UniGEE D1 p<0.10 + ICC_Inter >= 0.75        ║
# ║   Dynamic pool = UniGEE D2 p<0.10 + ICC_Inter >= 0.75        ║
# ║                 one representative per family/sub-band       ║
# ║                 priority: slope > change > delta             ║
# ║                 within the same priority, pick lowest p      ║
# ║   3 combo types: Static×Static / Static×Dynamic / Dynamic×Dynamic║
# ║   Filter   : cross-family/sub-band only (same-family pairs excluded)║
# ║   Clinical vars: excluded from GEE combos (go straight to Cox)║
# ╚══════════════════════════════════════════════════════════════╝

cat("\n[CELL 3] Multi-GEE (rule-based auto-combination, revised)...\n")

# ══════════════════════════════════════════════════════════════
# 0) Load ICC and prepare passing features
#     - the ICC file is keyed by base feature name (e.g. Wav_HH_FO_Median)
#     - D2 features must have their suffix stripped to match by base name
# ══════════════════════════════════════════════════════════════
icc_tbl <- readxl::read_excel(
  file.path("/content/ICC_radiomics_evaluation.xlsx"),
  sheet = "ICC_stable_features"
)

icc_pass_features <- icc_tbl %>%
  dplyr::filter(ICC_Inter >= 0.75) %>%
  dplyr::pull(Feature)

cat(sprintf("  ICC pass features (ICC_Inter >= 0.75): %d\n", length(icc_pass_features)))

# ══════════════════════════════════════════════════════════════
# 1) helper functions: family / type / ICC-base
# ══════════════════════════════════════════════════════════════
fam_of <- function(x) {
  x0 <- sub("_(change|delta|slope)$", "", x)
  if (grepl("^Wav_LL_", x0)) return("Wav_LL")
  if (grepl("^Wav_LH_", x0)) return("Wav_LH")
  if (grepl("^Wav_HL_", x0)) return("Wav_HL")
  if (grepl("^Wav_HH_", x0)) return("Wav_HH")
  sub("_.*$", "", x0)   # FO / GLCM / GLRLM / GLSZM / NGTDM
}

d2_type <- function(x) {
  if (grepl("_slope$",  x)) return("slope")
  if (grepl("_change$", x)) return("change")
  if (grepl("_delta$",  x)) return("delta")
  return(NA_character_)
}

icc_base_of <- function(x) {
  sub("_(change|delta|slope)$", "", x)
}

d2_priority <- function(x) {
  if (x == "slope")  return(1L)
  if (x == "change") return(2L)
  if (x == "delta")  return(3L)
  return(99L)
}

# ══════════════════════════════════════════════════════════════
# 2) Static pool — UniGEE D1 p<0.10 + ICC gate
#     (clinical excluded; not reduced to one per sub-band)
# ══════════════════════════════════════════════════════════════
static_pool <- gee_d1 %>%
  dplyr::filter(p_value < 0.10) %>%
  dplyr::filter(Feature %in% icc_pass_features) %>%
  dplyr::pull(Feature) %>%
  setdiff(clin_cols) %>%
  unique()

cat(sprintf("  Static pool (all D1, p<0.10 + ICC>=0.75): %d\n", length(static_pool)))
if (length(static_pool) > 0) print(static_pool)

# ══════════════════════════════════════════════════════════════
# 3) Dynamic pool — UniGEE D2 p<0.10 + ICC gate
#     one representative per family/sub-band
#     priority: slope > change > delta
#     within the same priority, pick lowest p
# ══════════════════════════════════════════════════════════════
dyn_sig <- gee_d2 %>%
  dplyr::filter(p_value < 0.10) %>%
  dplyr::mutate(
    ICC_base   = vapply(Feature, icc_base_of, character(1)),
    Family     = vapply(Feature, fam_of, character(1)),
    D2type     = vapply(Feature, d2_type, character(1)),
    D2priority = vapply(vapply(Feature, d2_type, character(1)), d2_priority, integer(1))
  ) %>%
  dplyr::filter(ICC_base %in% icc_pass_features)

cat(sprintf("  Dynamic significant candidates (p<0.10 + ICC>=0.75): %d\n", nrow(dyn_sig)))
if (nrow(dyn_sig) > 0) {
  print(dyn_sig %>% dplyr::select(Family, Feature, ICC_base, D2type, D2priority, p_value))
}

dynamic_rep <- dyn_sig %>%
  dplyr::group_by(Family) %>%
  dplyr::arrange(D2priority, p_value, Feature, .by_group = TRUE) %>%
  dplyr::slice(1) %>%
  dplyr::ungroup() %>%
  dplyr::distinct(Family, .keep_all = TRUE)

dynamic_pool <- unique(dynamic_rep$Feature)

cat(sprintf("  Dynamic pool (one representative per family): %d\n", length(dynamic_pool)))
if (nrow(dynamic_rep) > 0) {
  print(dynamic_rep %>% dplyr::select(Family, Feature, ICC_base, D2type, p_value))
}

# ══════════════════════════════════════════════════════════════
# 4) Generate combinations — cross-family only
#     same-family/sub-band combinations excluded
# ══════════════════════════════════════════════════════════════
make_pairs <- function(a_set, b_set, tag) {
  out  <- list()
  meta <- character(0)

  for (a in a_set) {
    for (b in b_set) {
      if (a == b) next
      if (fam_of(a) == fam_of(b)) next   # cross-family only

      key <- paste(sort(c(a, b)), collapse = "__")
      if (key %in% names(out)) next

      out[[key]] <- c(a, b)
      meta[key]  <- tag
    }
  }
  list(sets = out, tag = meta)
}

p_ss <- make_pairs(static_pool,  static_pool,  "SS")  # Static × Static
p_sd <- make_pairs(static_pool,  dynamic_pool, "SD")  # Static × Dynamic
p_dd <- make_pairs(dynamic_pool, dynamic_pool, "DD")  # Dynamic × Dynamic

feat_sets <- c(p_ss$sets, p_sd$sets, p_dd$sets)
combo_tag <- c(p_ss$tag,  p_sd$tag,  p_dd$tag)

# model-name convention: <combo-type><number>_<short-feature-names>
if (length(feat_sets) == 0) {
  cat("\n  ⚠️ 0 combinations — not enough D1/D2 significant features\n")
} else {
  short <- function(v) gsub("Wav_|_FO|_change|_delta|_slope|_first|_", "", v)
  nm <- vapply(seq_along(feat_sets), function(i) {
    sprintf("%s%02d_%s", combo_tag[i], i,
            paste(vapply(feat_sets[[i]], short, character(1)), collapse = "_"))
  }, character(1))
  names(feat_sets) <- nm
}

cat(sprintf("\n  Auto-generated combinations: %d  (SS=%d, SD=%d, DD=%d)\n",
            length(feat_sets), length(p_ss$sets), length(p_sd$sets), length(p_dd$sets)))

# ══════════════════════════════════════════════════════════════
# 5) Multi-GEE execution function
#     - screening is broad, using p<0.10
# ══════════════════════════════════════════════════════════════
run_gee_multi <- function(feat_name, feat_cols, data) {
  cols <- feat_cols[feat_cols %in% names(data)]
  # FIX: Ensure no empty strings in 'cols' to prevent formula parsing errors
  cols <- cols[cols != ""]

  if (length(cols) < 2) {
    cat(sprintf("  [%s] skipped: <2 valid features\n", feat_name))
    return(NULL)
  }

  df_tmp <- data %>%
    dplyr::mutate(dplyr::across(dplyr::all_of(cols), ~ suppressWarnings(scale(.x)[, 1]))) %>%
    dplyr::select(PI_MRONJ, Implant_Num, dplyr::all_of(cols)) %>%
    stats::na.omit()

  fit <- tryCatch(
    geepack::geeglm(
      as.formula(paste("PI_MRONJ ~", paste(cols, collapse = " + "))),
      data   = df_tmp,
      id     = Implant_Num,
      family = stats::binomial(),
      corstr = "independence"
    ),
    error = function(e) {
      cat(sprintf("  [%s] error: %s\n", feat_name, e$message))
      NULL
    }
  )

  if (is.null(fit)) return(NULL)

  s    <- summary(fit)$coefficients
  vars <- rownames(s)[rownames(s) != "(Intercept)"]

  # final YES criterion unchanged: both predictors p < 0.10
  all_sig <- all(s[vars, "Pr(>|W|)"] < 0.10)

  data.frame(
    Model   = feat_name,
    Feature = vars,
    OR      = round(exp(s[vars, "Estimate"]), 3),
    CI_lo   = round(exp(s[vars, "Estimate"] - 1.96 * s[vars, "Std.err"]), 3),
    CI_hi   = round(exp(s[vars, "Estimate"] + 1.96 * s[vars, "Std.err"]), 3),
    p_value = round(s[vars, "Pr(>|W|)"], 4),
    Sig     = ifelse(s[vars, "Pr(>|W|)"] < 0.001, "***",
              ifelse(s[vars, "Pr(>|W|)"] < 0.01,  "**",
              ifelse(s[vars, "Pr(>|W|)"] < 0.05,  "*",
              ifelse(s[vars, "Pr(>|W|)"] < 0.10,  "†", "ns")))),
    All_p10 = ifelse(all_sig, "YES", "NO"),
    stringsAsFactors = FALSE
  )
}

# ══════════════════════════════════════════════════════════════
# 6) Run all + summarize
# ══════════════════════════════════════════════════════════════
cat(sprintf("\n  Running %d feature sets...\n", length(feat_sets)))

res_list <- mapply(
  run_gee_multi,
  names(feat_sets),
  feat_sets,
  MoreArgs = list(data = df_tp),
  SIMPLIFY = FALSE
)

res_list <- Filter(Negate(is.null), res_list)

if (length(res_list) > 0) {
  multi_gee_detail <- do.call(rbind, res_list)
} else {
  multi_gee_detail <- data.frame()
}

if (nrow(multi_gee_detail) > 0) {
  multi_gee_res <- multi_gee_detail %>%
    dplyr::group_by(Model, All_p10) %>%
    dplyr::summarise(
      Features = paste(Feature, collapse = " + "),
      Min_p    = round(min(p_value), 4),
      Max_p    = round(max(p_value), 4),
      .groups  = "drop"
    ) %>%
    dplyr::mutate(Combo = sub("[0-9].*$", "", Model)) %>%
    dplyr::arrange(All_p10 == "NO", Max_p)

  yes_models <- multi_gee_res %>% dplyr::filter(All_p10 == "YES")

  if (nrow(yes_models) > 0) {
    print(as.data.frame(yes_models))
    cat(sprintf("\n  YES models: %d (SS=%d, SD=%d, DD=%d)\n",
                nrow(yes_models),
                sum(yes_models$Combo == "SS"),
                sum(yes_models$Combo == "SD"),
                sum(yes_models$Combo == "DD")))
    cat("\n  YES details:\n")
    print(
      multi_gee_detail %>%
        dplyr::filter(Model %in% yes_models$Model) %>%
        dplyr::select(Model, Feature, OR, CI_lo, CI_hi, p_value, Sig)
    )
  } else {
    cat("  None. lowest-Max_p 5:\n")
    print(as.data.frame(utils::head(multi_gee_res, 5)))
  }

  cat("\n===== Multi-GEE: full summary =====\n")
  print(as.data.frame(multi_gee_res))
} else {
  multi_gee_res <- data.frame()
  yes_models    <- data.frame()
  cat("\n  ⚠️ No runnable Multi-GEE results.\n")
}

# ══════════════════════════════════════════════════════════════
# 7) For saving Dynamic_Pool
#     - saved separately: the broad-screening result (dynamic_rep) and
#       the D2 features actually p<0.05 in Multi-GEE (dynamic_pool_final)
# ══════════════════════════════════════════════════════════════
if (nrow(multi_gee_detail) > 0 && length(dynamic_pool) > 0) {
  dynamic_pool_final <- multi_gee_detail %>%
    dplyr::filter(p_value < 0.10) %>%         # actually significant in Multi-GEE
    dplyr::filter(Feature %in% dynamic_pool) %>%
    dplyr::distinct(Feature, .keep_all = TRUE) %>%
    dplyr::mutate(
      Family = vapply(Feature, fam_of, character(1)),
      D2type = vapply(Feature, d2_type, character(1))
    ) %>%
    dplyr::select(Family, Feature, D2type, p_value)
} else {
  dynamic_pool_final <- data.frame(
    Family  = character(0),
    Feature = character(0),
    D2type  = character(0),
    p_value = numeric(0)
  )
}

# also save the dynamic representative used for broad screening
dynamic_pool_screened <- if (nrow(dynamic_rep) > 0) {
  dynamic_rep %>%
    dplyr::select(Family, Feature, D2type, p_value, ICC_base)
} else {
  data.frame(
    Family   = character(0),
    Feature  = character(0),
    D2type   = character(0),
    p_value  = numeric(0),
    ICC_base = character(0)
  )
}

# ══════════════════════════════════════════════════════════════
# 8) Save
# ══════════════════════════════════════════════════════════════
save_name_c4 <- sprintf("%s/%dM_Cell3_MultiGEE.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS)

writexl::write_xlsx(
  list(
    "MultiGEE_Summary"          = multi_gee_res,
    "MultiGEE_Detail"           = multi_gee_detail,
    "MultiGEE_YES"              = if (nrow(multi_gee_detail) > 0) multi_gee_detail %>% dplyr::filter(All_p10 == "YES") else data.frame(),
    "Static_Pool"               = data.frame(Feature = static_pool),
    "Dynamic_Pool_Screened"     = dynamic_pool_screened,  # p<0.10 + ICC>=0.75 + family representative
    "Dynamic_Pool_MultiGEE_p05" = dynamic_pool_final      # only D2 actually p<0.05 in Multi-GEE
  ),
  path = save_name_c4
)

cat(sprintf("\nSaved: %s\n", save_name_c4))
# Out:
# [CELL 3] Multi-GEE (rule-based auto-combination, revised)...
#   ICC pass features (ICC_Inter >= 0.75): 73
#   Static pool (all D1, p<0.10 + ICC>=0.75): 10
#  [1] "Wav_HH_FO_Median"   "GLRLM_LRLGE"        "Wav_LL_FO_Std"
#  [4] "GLRLM_RLN"          "GLRLM_RLNU"         "FO_Std"
#  [7] "Wav_LL_FO_P90"      "FO_P90"             "Wav_LH_FO_P25"
# [10] "Wav_LL_FO_Variance"
#   Dynamic significant candidates (p<0.10 + ICC>=0.75): 7
#   Family                   Feature           ICC_base D2type D2priority p_value
# 1 Wav_HH    Wav_HH_FO_Median_slope   Wav_HH_FO_Median  slope          1  0.0352
# 2  NGTDM     NGTDM_Contrast_change     NGTDM_Contrast change          2  0.0445
# 3     FO              FO_IQR_slope             FO_IQR  slope          1  0.0448
# 4 Wav_LL       Wav_LL_FO_IQR_slope      Wav_LL_FO_IQR  slope          1  0.0536
# 5  GLRLM        GLRLM_LRLGE_change        GLRLM_LRLGE change          2  0.0606
# 6 Wav_HH Wav_HH_FO_Variance_change Wav_HH_FO_Variance change          2  0.0856
# 7 Wav_HL      Wav_HL_FO_P25_change      Wav_HL_FO_P25 change          2  0.0980
#   Dynamic pool (one representative per family): 6
# # A tibble: 6 × 5
#   Family Feature                ICC_base         D2type p_value
#   <chr>  <chr>                  <chr>            <chr>    <dbl>
# 1 FO     FO_IQR_slope           FO_IQR           slope   0.0448
# 2 GLRLM  GLRLM_LRLGE_change     GLRLM_LRLGE      change  0.0606
# 3 NGTDM  NGTDM_Contrast_change  NGTDM_Contrast   change  0.0445
# 4 Wav_HH Wav_HH_FO_Median_slope Wav_HH_FO_Median slope   0.0352
# 5 Wav_HL Wav_HL_FO_P25_change   Wav_HL_FO_P25    change  0.098
# 6 Wav_LL Wav_LL_FO_IQR_slope    Wav_LL_FO_IQR    slope   0.0536
#
#   Auto-generated combinations: 104  (SS=38, SD=51, DD=15)
#
#   Running 104 feature sets...
#                            Model All_p10
# 1    DD99_NGTDMContrast_HHMedian     YES
# 2    SD41_HHMedian_NGTDMContrast     YES
# 3          SS38_LHP25_LLVariance     YES
# 4            SD43_HHMedian_LLIQR     YES
# 5            SD39_HHMedian_FOIQR     YES
# 6  SD45_GLRLMLRLGE_NGTDMContrast     YES
# 7               SS20_LLStd_LHP25     YES
# 8       SD40_HHMedian_GLRLMLRLGE     YES
# 9               SS32_FOStd_LHP25     YES
# 10         DD98_GLRLMLRLGE_LLIQR     YES
# 11      SS01_HHMedian_GLRLMLRLGE     YES
# 12         SD48_GLRLMLRLGE_LLIQR     YES
# 13           SS02_HHMedian_LLStd     YES
# 14         DD90_FOIQR_GLRLMLRLGE     YES
# 15         SD44_GLRLMLRLGE_FOIQR     YES
# 16           SD52_LLStd_HHMedian     YES
# 17         SD50_LLStd_GLRLMLRLGE     YES
# 18           SS05_HHMedian_FOStd     YES
# 19         SD64_FOStd_GLRLMLRLGE     YES
# 20           SD66_FOStd_HHMedian     YES
# 21      SD46_GLRLMLRLGE_HHMedian     YES
# 22      SS09_HHMedian_LLVariance     YES
# 23         SS10_GLRLMLRLGE_LLStd     YES
# 24      DD96_GLRLMLRLGE_HHMedian     YES
# 25 DD95_GLRLMLRLGE_NGTDMContrast     YES
# 26    SD86_LLVariance_GLRLMLRLGE     YES
# 27      SD81_LHP25_NGTDMContrast     YES
# 28         SS11_GLRLMLRLGE_FOStd     YES
# 29      SD88_LLVariance_HHMedian     YES
# 30      SS25_GLRLMRLN_LLVariance     YES
# 31     SS30_GLRLMRLNU_LLVariance     YES
#                                          Features  Min_p  Max_p Combo
# 1  NGTDM_Contrast_change + Wav_HH_FO_Median_slope 0.0393 0.0461    DD
# 2        Wav_HH_FO_Median + NGTDM_Contrast_change 0.0307 0.0464    SD
# 3              Wav_LH_FO_P25 + Wav_LL_FO_Variance 0.0648 0.0689    SS
# 4          Wav_HH_FO_Median + Wav_LL_FO_IQR_slope 0.0580 0.0693    SD
# 5                 Wav_HH_FO_Median + FO_IQR_slope 0.0491 0.0699    SD
# 6             GLRLM_LRLGE + NGTDM_Contrast_change 0.0516 0.0715    SD
# 7                   Wav_LL_FO_Std + Wav_LH_FO_P25 0.0653 0.0716    SS
# 8           Wav_HH_FO_Median + GLRLM_LRLGE_change 0.0632 0.0720    SD
# 9                          FO_Std + Wav_LH_FO_P25 0.0710 0.0745    SS
# 10       GLRLM_LRLGE_change + Wav_LL_FO_IQR_slope 0.0554 0.0762    DD
# 11                 Wav_HH_FO_Median + GLRLM_LRLGE 0.0655 0.0766    SS
# 12              GLRLM_LRLGE + Wav_LL_FO_IQR_slope 0.0436 0.0772    SD
# 13               Wav_HH_FO_Median + Wav_LL_FO_Std 0.0603 0.0773    SS
# 14              FO_IQR_slope + GLRLM_LRLGE_change 0.0473 0.0776    DD
# 15                     GLRLM_LRLGE + FO_IQR_slope 0.0366 0.0780    SD
# 16         Wav_LL_FO_Std + Wav_HH_FO_Median_slope 0.0471 0.0806    SD
# 17             Wav_LL_FO_Std + GLRLM_LRLGE_change 0.0797 0.0811    SD
# 18                      Wav_HH_FO_Median + FO_Std 0.0606 0.0815    SS
# 19                    FO_Std + GLRLM_LRLGE_change 0.0806 0.0856    SD
# 20                FO_Std + Wav_HH_FO_Median_slope 0.0480 0.0858    SD
# 21           GLRLM_LRLGE + Wav_HH_FO_Median_slope 0.0679 0.0896    SD
# 22          Wav_HH_FO_Median + Wav_LL_FO_Variance 0.0585 0.0900    SS
# 23                    GLRLM_LRLGE + Wav_LL_FO_Std 0.0800 0.0901    SS
# 24    GLRLM_LRLGE_change + Wav_HH_FO_Median_slope 0.0504 0.0932    DD
# 25     GLRLM_LRLGE_change + NGTDM_Contrast_change 0.0606 0.0933    DD
# 26        Wav_LL_FO_Variance + GLRLM_LRLGE_change 0.0774 0.0939    SD
# 27          Wav_LH_FO_P25 + NGTDM_Contrast_change 0.0479 0.0953    SD
# 28                           GLRLM_LRLGE + FO_Std 0.0804 0.0955    SS
# 29    Wav_LL_FO_Variance + Wav_HH_FO_Median_slope 0.0456 0.0967    SD
# 30                 GLRLM_RLN + Wav_LL_FO_Variance 0.0949 0.0994    SS
# 31                GLRLM_RLNU + Wav_LL_FO_Variance 0.0949 0.0994    SS
#
#   YES models: 31 (SS=11, SD=15, DD=5)
#
#   YES details:
#                                                         Model
# SS01_HHMedian_GLRLMLRLGE.1           SS01_HHMedian_GLRLMLRLGE
# SS01_HHMedian_GLRLMLRLGE.2           SS01_HHMedian_GLRLMLRLGE
# SS02_HHMedian_LLStd.1                     SS02_HHMedian_LLStd
# SS02_HHMedian_LLStd.2                     SS02_HHMedian_LLStd
# SS05_HHMedian_FOStd.1                     SS05_HHMedian_FOStd
# SS05_HHMedian_FOStd.2                     SS05_HHMedian_FOStd
# SS09_HHMedian_LLVariance.1           SS09_HHMedian_LLVariance
# SS09_HHMedian_LLVariance.2           SS09_HHMedian_LLVariance
# SS10_GLRLMLRLGE_LLStd.1                 SS10_GLRLMLRLGE_LLStd
# SS10_GLRLMLRLGE_LLStd.2                 SS10_GLRLMLRLGE_LLStd
# SS11_GLRLMLRLGE_FOStd.1                 SS11_GLRLMLRLGE_FOStd
# SS11_GLRLMLRLGE_FOStd.2                 SS11_GLRLMLRLGE_FOStd
# SS20_LLStd_LHP25.1                           SS20_LLStd_LHP25
# SS20_LLStd_LHP25.2                           SS20_LLStd_LHP25
# SS25_GLRLMRLN_LLVariance.1           SS25_GLRLMRLN_LLVariance
# SS25_GLRLMRLN_LLVariance.2           SS25_GLRLMRLN_LLVariance
# SS30_GLRLMRLNU_LLVariance.1         SS30_GLRLMRLNU_LLVariance
# SS30_GLRLMRLNU_LLVariance.2         SS30_GLRLMRLNU_LLVariance
# SS32_FOStd_LHP25.1                           SS32_FOStd_LHP25
# SS32_FOStd_LHP25.2                           SS32_FOStd_LHP25
# SS38_LHP25_LLVariance.1                 SS38_LHP25_LLVariance
# SS38_LHP25_LLVariance.2                 SS38_LHP25_LLVariance
# SD39_HHMedian_FOIQR.1                     SD39_HHMedian_FOIQR
# SD39_HHMedian_FOIQR.2                     SD39_HHMedian_FOIQR
# SD40_HHMedian_GLRLMLRLGE.1           SD40_HHMedian_GLRLMLRLGE
# SD40_HHMedian_GLRLMLRLGE.2           SD40_HHMedian_GLRLMLRLGE
# SD41_HHMedian_NGTDMContrast.1     SD41_HHMedian_NGTDMContrast
# SD41_HHMedian_NGTDMContrast.2     SD41_HHMedian_NGTDMContrast
# SD43_HHMedian_LLIQR.1                     SD43_HHMedian_LLIQR
# SD43_HHMedian_LLIQR.2                     SD43_HHMedian_LLIQR
# SD44_GLRLMLRLGE_FOIQR.1                 SD44_GLRLMLRLGE_FOIQR
# SD44_GLRLMLRLGE_FOIQR.2                 SD44_GLRLMLRLGE_FOIQR
# SD45_GLRLMLRLGE_NGTDMContrast.1 SD45_GLRLMLRLGE_NGTDMContrast
# SD45_GLRLMLRLGE_NGTDMContrast.2 SD45_GLRLMLRLGE_NGTDMContrast
# SD46_GLRLMLRLGE_HHMedian.1           SD46_GLRLMLRLGE_HHMedian
# SD46_GLRLMLRLGE_HHMedian.2           SD46_GLRLMLRLGE_HHMedian
# SD48_GLRLMLRLGE_LLIQR.1                 SD48_GLRLMLRLGE_LLIQR
# SD48_GLRLMLRLGE_LLIQR.2                 SD48_GLRLMLRLGE_LLIQR
# SD50_LLStd_GLRLMLRLGE.1                 SD50_LLStd_GLRLMLRLGE
# SD50_LLStd_GLRLMLRLGE.2                 SD50_LLStd_GLRLMLRLGE
# SD52_LLStd_HHMedian.1                     SD52_LLStd_HHMedian
# SD52_LLStd_HHMedian.2                     SD52_LLStd_HHMedian
# SD64_FOStd_GLRLMLRLGE.1                 SD64_FOStd_GLRLMLRLGE
# SD64_FOStd_GLRLMLRLGE.2                 SD64_FOStd_GLRLMLRLGE
# SD66_FOStd_HHMedian.1                     SD66_FOStd_HHMedian
# SD66_FOStd_HHMedian.2                     SD66_FOStd_HHMedian
# SD81_LHP25_NGTDMContrast.1           SD81_LHP25_NGTDMContrast
# SD81_LHP25_NGTDMContrast.2           SD81_LHP25_NGTDMContrast
# SD86_LLVariance_GLRLMLRLGE.1       SD86_LLVariance_GLRLMLRLGE
# SD86_LLVariance_GLRLMLRLGE.2       SD86_LLVariance_GLRLMLRLGE
# SD88_LLVariance_HHMedian.1           SD88_LLVariance_HHMedian
# SD88_LLVariance_HHMedian.2           SD88_LLVariance_HHMedian
# DD90_FOIQR_GLRLMLRLGE.1                 DD90_FOIQR_GLRLMLRLGE
# DD90_FOIQR_GLRLMLRLGE.2                 DD90_FOIQR_GLRLMLRLGE
# DD95_GLRLMLRLGE_NGTDMContrast.1 DD95_GLRLMLRLGE_NGTDMContrast
# DD95_GLRLMLRLGE_NGTDMContrast.2 DD95_GLRLMLRLGE_NGTDMContrast
# DD96_GLRLMLRLGE_HHMedian.1           DD96_GLRLMLRLGE_HHMedian
# DD96_GLRLMLRLGE_HHMedian.2           DD96_GLRLMLRLGE_HHMedian
# DD98_GLRLMLRLGE_LLIQR.1                 DD98_GLRLMLRLGE_LLIQR
# DD98_GLRLMLRLGE_LLIQR.2                 DD98_GLRLMLRLGE_LLIQR
# DD99_NGTDMContrast_HHMedian.1     DD99_NGTDMContrast_HHMedian
# DD99_NGTDMContrast_HHMedian.2     DD99_NGTDMContrast_HHMedian
#                                                Feature    OR CI_lo CI_hi
# SS01_HHMedian_GLRLMLRLGE.1            Wav_HH_FO_Median 1.309 0.983 1.744
# SS01_HHMedian_GLRLMLRLGE.2                 GLRLM_LRLGE 0.250 0.054 1.160
# SS02_HHMedian_LLStd.1                 Wav_HH_FO_Median 1.324 0.988 1.775
# SS02_HHMedian_LLStd.2                    Wav_LL_FO_Std 1.402 0.964 2.038
# SS05_HHMedian_FOStd.1                 Wav_HH_FO_Median 1.324 0.988 1.774
# SS05_HHMedian_FOStd.2                           FO_Std 1.396 0.959 2.032
# SS09_HHMedian_LLVariance.1            Wav_HH_FO_Median 1.328 0.990 1.782
# SS09_HHMedian_LLVariance.2          Wav_LL_FO_Variance 1.369 0.952 1.969
# SS10_GLRLMLRLGE_LLStd.1                    GLRLM_LRLGE 0.263 0.059 1.173
# SS10_GLRLMLRLGE_LLStd.2                  Wav_LL_FO_Std 1.398 0.949 2.061
# SS11_GLRLMLRLGE_FOStd.1                    GLRLM_LRLGE 0.266 0.060 1.174
# SS11_GLRLMLRLGE_FOStd.2                         FO_Std 1.391 0.944 2.051
# SS20_LLStd_LHP25.1                       Wav_LL_FO_Std 1.439 0.977 2.120
# SS20_LLStd_LHP25.2                       Wav_LH_FO_P25 0.710 0.489 1.031
# SS25_GLRLMRLN_LLVariance.1                   GLRLM_RLN 1.194 0.970 1.471
# SS25_GLRLMRLN_LLVariance.2          Wav_LL_FO_Variance 1.363 0.943 1.969
# SS30_GLRLMRLNU_LLVariance.1                 GLRLM_RLNU 1.194 0.970 1.471
# SS30_GLRLMRLNU_LLVariance.2         Wav_LL_FO_Variance 1.363 0.943 1.969
# SS32_FOStd_LHP25.1                              FO_Std 1.429 0.970 2.105
# SS32_FOStd_LHP25.2                       Wav_LH_FO_P25 0.713 0.491 1.034
# SS38_LHP25_LLVariance.1                  Wav_LH_FO_P25 0.704 0.486 1.022
# SS38_LHP25_LLVariance.2             Wav_LL_FO_Variance 1.414 0.973 2.055
# SD39_HHMedian_FOIQR.1                 Wav_HH_FO_Median 1.315 0.978 1.769
# SD39_HHMedian_FOIQR.2                     FO_IQR_slope 1.187 1.001 1.408
# SD40_HHMedian_GLRLMLRLGE.1            Wav_HH_FO_Median 1.317 0.985 1.762
# SD40_HHMedian_GLRLMLRLGE.2          GLRLM_LRLGE_change 0.350 0.112 1.098
# SD41_HHMedian_NGTDMContrast.1         Wav_HH_FO_Median 1.344 1.005 1.798
# SD41_HHMedian_NGTDMContrast.2    NGTDM_Contrast_change 1.350 1.028 1.773
# SD43_HHMedian_LLIQR.1                 Wav_HH_FO_Median 1.316 0.979 1.770
# SD43_HHMedian_LLIQR.2              Wav_LL_FO_IQR_slope 1.181 0.994 1.404
# SD44_GLRLMLRLGE_FOIQR.1                    GLRLM_LRLGE 0.244 0.051 1.171
# SD44_GLRLMLRLGE_FOIQR.2                   FO_IQR_slope 1.225 1.013 1.481
# SD45_GLRLMLRLGE_NGTDMContrast.1            GLRLM_LRLGE 0.246 0.053 1.130
# SD45_GLRLMLRLGE_NGTDMContrast.2  NGTDM_Contrast_change 1.327 0.998 1.764
# SD46_GLRLMLRLGE_HHMedian.1                 GLRLM_LRLGE 0.270 0.060 1.224
# SD46_GLRLMLRLGE_HHMedian.2      Wav_HH_FO_Median_slope 1.225 0.985 1.523
# SD48_GLRLMLRLGE_LLIQR.1                    GLRLM_LRLGE 0.243 0.051 1.167
# SD48_GLRLMLRLGE_LLIQR.2            Wav_LL_FO_IQR_slope 1.218 1.006 1.475
# SD50_LLStd_GLRLMLRLGE.1                  Wav_LL_FO_Std 1.407 0.959 2.065
# SD50_LLStd_GLRLMLRLGE.2             GLRLM_LRLGE_change 0.365 0.118 1.127
# SD52_LLStd_HHMedian.1                    Wav_LL_FO_Std 1.400 0.960 2.043
# SD52_LLStd_HHMedian.2           Wav_HH_FO_Median_slope 1.261 1.003 1.586
# SD64_FOStd_GLRLMLRLGE.1                         FO_Std 1.401 0.954 2.056
# SD64_FOStd_GLRLMLRLGE.2             GLRLM_LRLGE_change 0.367 0.119 1.130
# SD66_FOStd_HHMedian.1                           FO_Std 1.394 0.954 2.035
# SD66_FOStd_HHMedian.2           Wav_HH_FO_Median_slope 1.259 1.002 1.583
# SD81_LHP25_NGTDMContrast.1               Wav_LH_FO_P25 0.730 0.505 1.057
# SD81_LHP25_NGTDMContrast.2       NGTDM_Contrast_change 1.334 1.003 1.776
# SD86_LLVariance_GLRLMLRLGE.1        Wav_LL_FO_Variance 1.378 0.947 2.005
# SD86_LLVariance_GLRLMLRLGE.2        GLRLM_LRLGE_change 0.356 0.113 1.120
# SD88_LLVariance_HHMedian.1          Wav_LL_FO_Variance 1.367 0.945 1.977
# SD88_LLVariance_HHMedian.2      Wav_HH_FO_Median_slope 1.262 1.005 1.586
# DD90_FOIQR_GLRLMLRLGE.1                   FO_IQR_slope 1.219 1.002 1.481
# DD90_FOIQR_GLRLMLRLGE.2             GLRLM_LRLGE_change 0.367 0.121 1.117
# DD95_GLRLMLRLGE_NGTDMContrast.1     GLRLM_LRLGE_change 0.379 0.122 1.177
# DD95_GLRLMLRLGE_NGTDMContrast.2  NGTDM_Contrast_change 1.321 0.988 1.767
# DD96_GLRLMLRLGE_HHMedian.1          GLRLM_LRLGE_change 0.366 0.113 1.183
# DD96_GLRLMLRLGE_HHMedian.2      Wav_HH_FO_Median_slope 1.242 1.000 1.544
# DD98_GLRLMLRLGE_LLIQR.1             GLRLM_LRLGE_change 0.365 0.120 1.112
# DD98_GLRLMLRLGE_LLIQR.2            Wav_LL_FO_IQR_slope 1.212 0.996 1.475
# DD99_NGTDMContrast_HHMedian.1    NGTDM_Contrast_change 1.333 1.005 1.768
# DD99_NGTDMContrast_HHMedian.2   Wav_HH_FO_Median_slope 1.256 1.011 1.560
#                                 p_value Sig
# SS01_HHMedian_GLRLMLRLGE.1       0.0655   †
# SS01_HHMedian_GLRLMLRLGE.2       0.0766   †
# SS02_HHMedian_LLStd.1            0.0603   †
# SS02_HHMedian_LLStd.2            0.0773   †
# SS05_HHMedian_FOStd.1            0.0606   †
# SS05_HHMedian_FOStd.2            0.0815   †
# SS09_HHMedian_LLVariance.1       0.0585   †
# SS09_HHMedian_LLVariance.2       0.0900   †
# SS10_GLRLMLRLGE_LLStd.1          0.0800   †
# SS10_GLRLMLRLGE_LLStd.2          0.0901   †
# SS11_GLRLMLRLGE_FOStd.1          0.0804   †
# SS11_GLRLMLRLGE_FOStd.2          0.0955   †
# SS20_LLStd_LHP25.1               0.0653   †
# SS20_LLStd_LHP25.2               0.0716   †
# SS25_GLRLMRLN_LLVariance.1       0.0949   †
# SS25_GLRLMRLN_LLVariance.2       0.0994   †
# SS30_GLRLMRLNU_LLVariance.1      0.0949   †
# SS30_GLRLMRLNU_LLVariance.2      0.0994   †
# SS32_FOStd_LHP25.1               0.0710   †
# SS32_FOStd_LHP25.2               0.0745   †
# SS38_LHP25_LLVariance.1          0.0648   †
# SS38_LHP25_LLVariance.2          0.0689   †
# SD39_HHMedian_FOIQR.1            0.0699   †
# SD39_HHMedian_FOIQR.2            0.0491   *
# SD40_HHMedian_GLRLMLRLGE.1       0.0632   †
# SD40_HHMedian_GLRLMLRLGE.2       0.0720   †
# SD41_HHMedian_NGTDMContrast.1    0.0464   *
# SD41_HHMedian_NGTDMContrast.2    0.0307   *
# SD43_HHMedian_LLIQR.1            0.0693   †
# SD43_HHMedian_LLIQR.2            0.0580   †
# SD44_GLRLMLRLGE_FOIQR.1          0.0780   †
# SD44_GLRLMLRLGE_FOIQR.2          0.0366   *
# SD45_GLRLMLRLGE_NGTDMContrast.1  0.0715   †
# SD45_GLRLMLRLGE_NGTDMContrast.2  0.0516   †
# SD46_GLRLMLRLGE_HHMedian.1       0.0896   †
# SD46_GLRLMLRLGE_HHMedian.2       0.0679   †
# SD48_GLRLMLRLGE_LLIQR.1          0.0772   †
# SD48_GLRLMLRLGE_LLIQR.2          0.0436   *
# SD50_LLStd_GLRLMLRLGE.1          0.0811   †
# SD50_LLStd_GLRLMLRLGE.2          0.0797   †
# SD52_LLStd_HHMedian.1            0.0806   †
# SD52_LLStd_HHMedian.2            0.0471   *
# SD64_FOStd_GLRLMLRLGE.1          0.0856   †
# SD64_FOStd_GLRLMLRLGE.2          0.0806   †
# SD66_FOStd_HHMedian.1            0.0858   †
# SD66_FOStd_HHMedian.2            0.0480   *
# SD81_LHP25_NGTDMContrast.1       0.0953   †
# SD81_LHP25_NGTDMContrast.2       0.0479   *
# SD86_LLVariance_GLRLMLRLGE.1     0.0939   †
# SD86_LLVariance_GLRLMLRLGE.2     0.0774   †
# SD88_LLVariance_HHMedian.1       0.0967   †
# SD88_LLVariance_HHMedian.2       0.0456   *
# DD90_FOIQR_GLRLMLRLGE.1          0.0473   *
# DD90_FOIQR_GLRLMLRLGE.2          0.0776   †
# DD95_GLRLMLRLGE_NGTDMContrast.1  0.0933   †
# DD95_GLRLMLRLGE_NGTDMContrast.2  0.0606   †
# DD96_GLRLMLRLGE_HHMedian.1       0.0932   †
# DD96_GLRLMLRLGE_HHMedian.2       0.0504   †
# DD98_GLRLMLRLGE_LLIQR.1          0.0762   †
# DD98_GLRLMLRLGE_LLIQR.2          0.0554   †
# DD99_NGTDMContrast_HHMedian.1    0.0461   *
# DD99_NGTDMContrast_HHMedian.2    0.0393   *
#
# ===== Multi-GEE: full summary =====
#                             Model All_p10
# 1     DD99_NGTDMContrast_HHMedian     YES
# 2     SD41_HHMedian_NGTDMContrast     YES
# 3           SS38_LHP25_LLVariance     YES
# 4             SD43_HHMedian_LLIQR     YES
# 5             SD39_HHMedian_FOIQR     YES
# 6   SD45_GLRLMLRLGE_NGTDMContrast     YES
# 7                SS20_LLStd_LHP25     YES
# 8        SD40_HHMedian_GLRLMLRLGE     YES
# 9                SS32_FOStd_LHP25     YES
# 10          DD98_GLRLMLRLGE_LLIQR     YES
# 11       SS01_HHMedian_GLRLMLRLGE     YES
# 12          SD48_GLRLMLRLGE_LLIQR     YES
# 13            SS02_HHMedian_LLStd     YES
# 14          DD90_FOIQR_GLRLMLRLGE     YES
# 15          SD44_GLRLMLRLGE_FOIQR     YES
# 16            SD52_LLStd_HHMedian     YES
# 17          SD50_LLStd_GLRLMLRLGE     YES
# 18            SS05_HHMedian_FOStd     YES
# 19          SD64_FOStd_GLRLMLRLGE     YES
# 20            SD66_FOStd_HHMedian     YES
# 21       SD46_GLRLMLRLGE_HHMedian     YES
# 22       SS09_HHMedian_LLVariance     YES
# 23          SS10_GLRLMLRLGE_LLStd     YES
# 24       DD96_GLRLMLRLGE_HHMedian     YES
# 25  DD95_GLRLMLRLGE_NGTDMContrast     YES
# 26     SD86_LLVariance_GLRLMLRLGE     YES
# 27       SD81_LHP25_NGTDMContrast     YES
# 28          SS11_GLRLMLRLGE_FOStd     YES
# 29       SD88_LLVariance_HHMedian     YES
# 30       SS25_GLRLMRLN_LLVariance     YES
# 31      SS30_GLRLMRLNU_LLVariance     YES
# 32               SD84_LHP25_LLIQR      NO
# 33               SD79_LHP25_FOIQR      NO
# 34     SS15_GLRLMLRLGE_LLVariance      NO
# 35            SS06_HHMedian_LLP90      NO
# 36            SS07_HHMedian_FOP90      NO
# 37          SD89_LLVariance_HLP25      NO
# 38            SS16_LLStd_GLRLMRLN      NO
# 39           SS17_LLStd_GLRLMRLNU      NO
# 40            SD72_LLP90_HHMedian      NO
# 41              DD104_HLP25_LLIQR      NO
# 42            SD58_GLRLMRLN_LLIQR      NO
# 43           SD63_GLRLMRLNU_LLIQR      NO
# 44            SS08_HHMedian_LHP25      NO
# 45               SD53_LLStd_HLP25      NO
# 46            SD76_FOP90_HHMedian      NO
# 47               DD93_FOIQR_HLP25      NO
# 48               SD67_FOStd_HLP25      NO
# 49            SD54_GLRLMRLN_FOIQR      NO
# 50           SD59_GLRLMRLNU_FOIQR      NO
# 51            SS21_GLRLMRLN_FOStd      NO
# 52           SS26_GLRLMRLNU_FOStd      NO
# 53           DD102_HHMedian_HLP25      NO
# 54            DD92_FOIQR_HHMedian      NO
# 55         SS03_HHMedian_GLRLMRLN      NO
# 56        SS04_HHMedian_GLRLMRLNU      NO
# 57            SD42_HHMedian_HLP25      NO
# 58            SD82_LHP25_HHMedian      NO
# 59               SD73_LLP90_HLP25      NO
# 60               SD77_FOP90_HLP25      NO
# 61           DD103_HHMedian_LLIQR      NO
# 62               DD94_FOIQR_LLIQR      NO
# 63         SD56_GLRLMRLN_HHMedian      NO
# 64        SD61_GLRLMRLNU_HHMedian      NO
# 65    SD55_GLRLMRLN_NGTDMContrast      NO
# 66   SD60_GLRLMRLNU_NGTDMContrast      NO
# 67               SS35_LLP90_LHP25      NO
# 68          SS12_GLRLMLRLGE_LLP90      NO
# 69               SS36_FOP90_LHP25      NO
# 70          SS13_GLRLMLRLGE_FOP90      NO
# 71               SS18_LLStd_FOStd      NO
# 72          SD70_LLP90_GLRLMLRLGE      NO
# 73          SD74_FOP90_GLRLMLRLGE      NO
# 74          DD97_GLRLMLRLGE_HLP25      NO
# 75          SD47_GLRLMLRLGE_HLP25      NO
# 76       SD75_FOP90_NGTDMContrast      NO
# 77      DD100_NGTDMContrast_HLP25      NO
# 78       SD71_LLP90_NGTDMContrast      NO
# 79               SD69_LLP90_FOIQR      NO
# 80          SS14_GLRLMLRLGE_LHP25      NO
# 81               SD78_FOP90_LLIQR      NO
# 82          SD80_LHP25_GLRLMLRLGE      NO
# 83            SS22_GLRLMRLN_LLP90      NO
# 84           SS27_GLRLMRLNU_LLP90      NO
# 85            SS23_GLRLMRLN_FOP90      NO
# 86           SS28_GLRLMRLNU_FOP90      NO
# 87               SD83_LHP25_HLP25      NO
# 88       SD65_FOStd_NGTDMContrast      NO
# 89  SD87_LLVariance_NGTDMContrast      NO
# 90       SD51_LLStd_NGTDMContrast      NO
# 91               SS31_FOStd_LLP90      NO
# 92               SS19_LLStd_FOP90      NO
# 93       DD91_FOIQR_NGTDMContrast      NO
# 94          SS37_FOP90_LLVariance      NO
# 95               SS34_LLP90_FOP90      NO
# 96            SS24_GLRLMRLN_LHP25      NO
# 97           SS29_GLRLMRLNU_LHP25      NO
# 98               SD49_LLStd_FOIQR      NO
# 99      DD101_NGTDMContrast_LLIQR      NO
# 100         SD85_LLVariance_FOIQR      NO
# 101              SD68_FOStd_LLIQR      NO
# 102         SS33_FOStd_LLVariance      NO
# 103           SD57_GLRLMRLN_HLP25      NO
# 104          SD62_GLRLMRLNU_HLP25      NO
#                                           Features  Min_p  Max_p Combo
# 1   NGTDM_Contrast_change + Wav_HH_FO_Median_slope 0.0393 0.0461    DD
# 2         Wav_HH_FO_Median + NGTDM_Contrast_change 0.0307 0.0464    SD
# 3               Wav_LH_FO_P25 + Wav_LL_FO_Variance 0.0648 0.0689    SS
# 4           Wav_HH_FO_Median + Wav_LL_FO_IQR_slope 0.0580 0.0693    SD
# 5                  Wav_HH_FO_Median + FO_IQR_slope 0.0491 0.0699    SD
# 6              GLRLM_LRLGE + NGTDM_Contrast_change 0.0516 0.0715    SD
# 7                    Wav_LL_FO_Std + Wav_LH_FO_P25 0.0653 0.0716    SS
# 8            Wav_HH_FO_Median + GLRLM_LRLGE_change 0.0632 0.0720    SD
# 9                           FO_Std + Wav_LH_FO_P25 0.0710 0.0745    SS
# 10        GLRLM_LRLGE_change + Wav_LL_FO_IQR_slope 0.0554 0.0762    DD
# 11                  Wav_HH_FO_Median + GLRLM_LRLGE 0.0655 0.0766    SS
# 12               GLRLM_LRLGE + Wav_LL_FO_IQR_slope 0.0436 0.0772    SD
# 13                Wav_HH_FO_Median + Wav_LL_FO_Std 0.0603 0.0773    SS
# 14               FO_IQR_slope + GLRLM_LRLGE_change 0.0473 0.0776    DD
# 15                      GLRLM_LRLGE + FO_IQR_slope 0.0366 0.0780    SD
# 16          Wav_LL_FO_Std + Wav_HH_FO_Median_slope 0.0471 0.0806    SD
# 17              Wav_LL_FO_Std + GLRLM_LRLGE_change 0.0797 0.0811    SD
# 18                       Wav_HH_FO_Median + FO_Std 0.0606 0.0815    SS
# 19                     FO_Std + GLRLM_LRLGE_change 0.0806 0.0856    SD
# 20                 FO_Std + Wav_HH_FO_Median_slope 0.0480 0.0858    SD
# 21            GLRLM_LRLGE + Wav_HH_FO_Median_slope 0.0679 0.0896    SD
# 22           Wav_HH_FO_Median + Wav_LL_FO_Variance 0.0585 0.0900    SS
# 23                     GLRLM_LRLGE + Wav_LL_FO_Std 0.0800 0.0901    SS
# 24     GLRLM_LRLGE_change + Wav_HH_FO_Median_slope 0.0504 0.0932    DD
# 25      GLRLM_LRLGE_change + NGTDM_Contrast_change 0.0606 0.0933    DD
# 26         Wav_LL_FO_Variance + GLRLM_LRLGE_change 0.0774 0.0939    SD
# 27           Wav_LH_FO_P25 + NGTDM_Contrast_change 0.0479 0.0953    SD
# 28                            GLRLM_LRLGE + FO_Std 0.0804 0.0955    SS
# 29     Wav_LL_FO_Variance + Wav_HH_FO_Median_slope 0.0456 0.0967    SD
# 30                  GLRLM_RLN + Wav_LL_FO_Variance 0.0949 0.0994    SS
# 31                 GLRLM_RLNU + Wav_LL_FO_Variance 0.0949 0.0994    SS
# 32             Wav_LH_FO_P25 + Wav_LL_FO_IQR_slope 0.0576 0.1002    SD
# 33                    Wav_LH_FO_P25 + FO_IQR_slope 0.0486 0.1012    SD
# 34                GLRLM_LRLGE + Wav_LL_FO_Variance 0.0786 0.1028    SS
# 35                Wav_HH_FO_Median + Wav_LL_FO_P90 0.0721 0.1038    SS
# 36                       Wav_HH_FO_Median + FO_P90 0.0719 0.1049    SS
# 37       Wav_LL_FO_Variance + Wav_HL_FO_P25_change 0.1017 0.1118    SD
# 38                       Wav_LL_FO_Std + GLRLM_RLN 0.0877 0.1120    SS
# 39                      Wav_LL_FO_Std + GLRLM_RLNU 0.0877 0.1120    SS
# 40          Wav_LL_FO_P90 + Wav_HH_FO_Median_slope 0.0815 0.1128    SD
# 41      Wav_HL_FO_P25_change + Wav_LL_FO_IQR_slope 0.0944 0.1131    DD
# 42                 GLRLM_RLN + Wav_LL_FO_IQR_slope 0.0698 0.1142    SD
# 43                GLRLM_RLNU + Wav_LL_FO_IQR_slope 0.0698 0.1142    SD
# 44                Wav_HH_FO_Median + Wav_LH_FO_P25 0.0829 0.1142    SS
# 45            Wav_LL_FO_Std + Wav_HL_FO_P25_change 0.0861 0.1145    SD
# 46                 FO_P90 + Wav_HH_FO_Median_slope 0.0822 0.1147    SD
# 47             FO_IQR_slope + Wav_HL_FO_P25_change 0.0846 0.1152    DD
# 48                   FO_Std + Wav_HL_FO_P25_change 0.0925 0.1177    SD
# 49                        GLRLM_RLN + FO_IQR_slope 0.0612 0.1181    SD
# 50                       GLRLM_RLNU + FO_IQR_slope 0.0612 0.1181    SD
# 51                              GLRLM_RLN + FO_Std 0.0935 0.1189    SS
# 52                             GLRLM_RLNU + FO_Std 0.0935 0.1189    SS
# 53   Wav_HH_FO_Median_slope + Wav_HL_FO_P25_change 0.0639 0.1399    DD
# 54           FO_IQR_slope + Wav_HH_FO_Median_slope 0.0827 0.1399    DD
# 55                    Wav_HH_FO_Median + GLRLM_RLN 0.0745 0.1416    SS
# 56                   Wav_HH_FO_Median + GLRLM_RLNU 0.0745 0.1416    SS
# 57         Wav_HH_FO_Median + Wav_HL_FO_P25_change 0.0898 0.1422    SD
# 58          Wav_LH_FO_P25 + Wav_HH_FO_Median_slope 0.1257 0.1534    SD
# 59            Wav_LL_FO_P90 + Wav_HL_FO_P25_change 0.1375 0.1563    SD
# 60                   FO_P90 + Wav_HL_FO_P25_change 0.1400 0.1575    SD
# 61    Wav_HH_FO_Median_slope + Wav_LL_FO_IQR_slope 0.0806 0.1590    DD
# 62              FO_IQR_slope + Wav_LL_FO_IQR_slope 0.1569 0.1783    DD
# 63              GLRLM_RLN + Wav_HH_FO_Median_slope 0.0715 0.1976    SD
# 64             GLRLM_RLNU + Wav_HH_FO_Median_slope 0.0715 0.1976    SD
# 65               GLRLM_RLN + NGTDM_Contrast_change 0.0796 0.2234    SD
# 66              GLRLM_RLNU + NGTDM_Contrast_change 0.0796 0.2234    SD
# 67                   Wav_LL_FO_P90 + Wav_LH_FO_P25 0.2052 0.2255    SS
# 68                     GLRLM_LRLGE + Wav_LL_FO_P90 0.1527 0.2279    SS
# 69                          FO_P90 + Wav_LH_FO_P25 0.2098 0.2280    SS
# 70                            GLRLM_LRLGE + FO_P90 0.1524 0.2314    SS
# 71                          Wav_LL_FO_Std + FO_Std 0.2178 0.2382    SS
# 72              Wav_LL_FO_P90 + GLRLM_LRLGE_change 0.1649 0.2507    SD
# 73                     FO_P90 + GLRLM_LRLGE_change 0.1673 0.2520    SD
# 74       GLRLM_LRLGE_change + Wav_HL_FO_P25_change 0.2403 0.2574    DD
# 75              GLRLM_LRLGE + Wav_HL_FO_P25_change 0.1914 0.2778    SD
# 76                  FO_P90 + NGTDM_Contrast_change 0.2765 0.2841    SD
# 77    NGTDM_Contrast_change + Wav_HL_FO_P25_change 0.1971 0.2856    DD
# 78           Wav_LL_FO_P90 + NGTDM_Contrast_change 0.2753 0.2866    SD
# 79                    Wav_LL_FO_P90 + FO_IQR_slope 0.1525 0.2979    SD
# 80                     GLRLM_LRLGE + Wav_LH_FO_P25 0.2406 0.3239    SS
# 81                    FO_P90 + Wav_LL_FO_IQR_slope 0.1529 0.3286    SD
# 82              Wav_LH_FO_P25 + GLRLM_LRLGE_change 0.2170 0.3375    SD
# 83                       GLRLM_RLN + Wav_LL_FO_P90 0.1419 0.4230    SS
# 84                      GLRLM_RLNU + Wav_LL_FO_P90 0.1419 0.4230    SS
# 85                              GLRLM_RLN + FO_P90 0.1443 0.4284    SS
# 86                             GLRLM_RLNU + FO_P90 0.1443 0.4284    SS
# 87            Wav_LH_FO_P25 + Wav_HL_FO_P25_change 0.4037 0.4658    SD
# 88                  FO_Std + NGTDM_Contrast_change 0.3958 0.5029    SD
# 89      Wav_LL_FO_Variance + NGTDM_Contrast_change 0.4547 0.5053    SD
# 90           Wav_LL_FO_Std + NGTDM_Contrast_change 0.3878 0.5132    SD
# 91                          FO_Std + Wav_LL_FO_P90 0.4979 0.5249    SS
# 92                          Wav_LL_FO_Std + FO_P90 0.4675 0.5369    SS
# 93            FO_IQR_slope + NGTDM_Contrast_change 0.1581 0.5488    DD
# 94                     FO_P90 + Wav_LL_FO_Variance 0.4677 0.5540    SS
# 95                          Wav_LL_FO_P90 + FO_P90 0.5394 0.5591    SS
# 96                       GLRLM_RLN + Wav_LH_FO_P25 0.3061 0.5651    SS
# 97                      GLRLM_RLNU + Wav_LH_FO_P25 0.3061 0.5651    SS
# 98                    Wav_LL_FO_Std + FO_IQR_slope 0.1757 0.5657    SD
# 99     NGTDM_Contrast_change + Wav_LL_FO_IQR_slope 0.1523 0.5834    DD
# 100              Wav_LL_FO_Variance + FO_IQR_slope 0.2173 0.5917    SD
# 101                   FO_Std + Wav_LL_FO_IQR_slope 0.1789 0.5922    SD
# 102                    FO_Std + Wav_LL_FO_Variance 0.4333 0.6401    SS
# 103               GLRLM_RLN + Wav_HL_FO_P25_change 0.3440 0.9914    SD
# 104              GLRLM_RLNU + Wav_HL_FO_P25_change 0.3440 0.9914    SD
#
# Saved: /content/Results_R/0M_Cell3_MultiGEE.xlsx

# %%
# ╔══════════════════════════════════════════════════════════════╗
# ║  CELL 4 — Uni-Cox Proportional Hazards Regression           ║
# ║  [Revised] removed _net -> unified to _trend + added HL/LH Skewness_trend║
# ║  Input : df_imp (implant-level)                              ║
# ║  Output: cox_res, cox_sig_only, sig_cox                     ║
# ╚══════════════════════════════════════════════════════════════╝

cat("\n[CELL 4] Uni-Cox analysis...\n")
cat(sprintf("  Duration range: %.0f ~ %.0f days\n",
            min(df_imp$Duration), max(df_imp$Duration)))
cat(sprintf("  N=%d | MRONJ=%d | Control=%d\n\n",
            nrow(df_imp), sum(df_imp$PI_MRONJ),
            sum(df_imp$PI_MRONJ==0)))

suppressPackageStartupMessages({
  library(survival)
  library(dplyr)
  library(writexl)
})
# ══════════════════════════════════════════════════════════════
# ★ Auto-extract D2 forward set — rule A + most-significant dynamic representative per family
#   (based on CELL 3's multi_gee_detail + YES models)
# ══════════════════════════════════════════════════════════════
yes_models <- multi_gee_res %>% filter(All_p10 == "YES") %>% pull(Model)
yd <- multi_gee_detail %>% filter(Model %in% yes_models)

# dynamic (_change/_delta/_slope) features appearing in YES models
dyn_in_yes <- unique(yd$Feature[grepl("_(change|delta|slope)$", yd$Feature)])

# determine family
fam_of <- function(x){
  b <- sub("_(change|delta|slope)$","",x)
  if (grepl("^Wav_LL_",b)) return("Wav_LL")
  if (grepl("^Wav_LH_",b)) return("Wav_LH")
  if (grepl("^Wav_HL_",b)) return("Wav_HL")
  if (grepl("^Wav_HH_",b)) return("Wav_HH")
  sub("_.*$","",b)
}

# pick the most-significant representative per family, using the UniGEE p-value (gee_d2)
dyn_df <- data.frame(Feature = dyn_in_yes, stringsAsFactors = FALSE) %>%
  mutate(Family = vapply(Feature, fam_of, ""),
         UniGEE_p = gee_d2$p_value[match(Feature, gee_d2$Feature)]) %>%
  group_by(Family) %>% arrange(UniGEE_p, .by_group = TRUE) %>%
  slice(1) %>% ungroup()

# convert to _trend -> Cox forward list
d2_all <- sub("_(change|delta|slope)$","_trend", dyn_df$Feature)
d2_all <- d2_all[d2_all %in% names(df_imp)]   # keep only columns that actually exist in df_imp

cat(sprintf("  Cox forward _trend (rule A, family representative): %d\n", length(d2_all)))
print(data.frame(trend = d2_all, rep = dyn_df$Feature, UniGEE_p = round(dyn_df$UniGEE_p,4)))

# the original code's primary/exploratory split varies by basis, so it is merged here
d2_primary     <- d2_all
d2_exploratory <- character(0)
# ══════════════════════════════════════════════════════════════


# ── D1 features (same as before: 3 clinical variables + all static radiomics) ──────
# (note: features that passed Multi-GEE, e.g. Wav_LH_FO_Skewness_first, are included in d1_features and pass through to Cox)
d1_features <- c(clin_cols, imp_radio_first)

# ── Full feature pool ─────────────────────────────────────────
all_features <- c(d1_features, d2_all)

cat(sprintf("  D1 features (_first + clinical):    %d\n",
            length(d1_features)))
cat(sprintf("  D2 features (_trend, primary):      %d\n",
            length(d2_primary)))
cat(sprintf("  D2 features (_trend, exploratory†): %d\n",
            length(d2_exploratory)))
cat(sprintf("  Total to test in Uni-Cox:           %d\n\n",
            length(all_features)))

# check: confirm _net features are fully removed
net_check <- intersect(all_features,
                       grep("_net$", names(df_imp), value=TRUE))
if(length(net_check) > 0){
  cat(sprintf("  ⚠️ _net features remaining: %s\n",
              paste(net_check, collapse=", ")))
} else {
  cat("  ✅ no _net features — unified to _trend\n\n")
}

# ── Uni-Cox execution function ──────────────────────────────
run_cox_uni <- function(vars, data) {
  results <- lapply(vars, function(v) {
    tryCatch({
      df_tmp <- data[, c("Duration", "Event",
                         "Patient_ID", v), drop = FALSE]
      df_tmp <- df_tmp[complete.cases(df_tmp), ]
      df_tmp[[v]] <- scale(df_tmp[[v]])[, 1]  # standardize

      fit <- coxph(Surv(Duration, Event) ~ get(v) +
                   cluster(Patient_ID),
                   data = df_tmp)

      s <- summary(fit)
      coef_row <- s$coefficients[1, ]
      ci <- s$conf.int[1, ]

      data.frame(
        Feature  = v,
        HR       = round(exp(coef_row["coef"]), 3),
        CI_lo    = round(ci["lower .95"], 3),
        CI_hi    = round(ci["upper .95"], 3),
        # use robust p-value (cluster-adjusted)
        p_value  = round(coef_row["Pr(>|z|)"], 4),
        Sig      = ifelse(coef_row["Pr(>|z|)"] < 0.001, "***",
                   ifelse(coef_row["Pr(>|z|)"] < 0.01,  "**",
                   ifelse(coef_row["Pr(>|z|)"] < 0.05,  "*",
                   ifelse(coef_row["Pr(>|z|)"] < 0.10,  "†", "ns")))),
        stringsAsFactors = FALSE
      )
    }, error = function(e) NULL)
  })
  do.call(rbind, results)
}

# ── Main run ──────────────────────────────────────────────
cat("  Running Uni-Cox...\n")
cox_res <- bind_rows(lapply(all_features, run_cox_uni,
                            data = df_imp)) %>%
  arrange(p_value)

# ── Summarize results ────────────────────────────────────────
d2_label <- case_when(
  cox_res$Feature %in% d2_primary  ~ "D2_primary",
  cox_res$Feature %in% d2_exploratory ~ "D2_exploratory†",
  TRUE ~ "D1"
)
cox_res$Type <- d2_label

cat(sprintf("\n  D1 features tested:            %d\n",
            sum(cox_res$Feature %in% d1_features)))
cat(sprintf("  D2 _trend features tested:     %d\n",
            sum(cox_res$Feature %in% d2_all)))
cat(sprintf("  Total tested:                  %d\n",
            nrow(cox_res)))

cox_sig_only <- cox_res %>% filter(p_value < 0.05)
cat(sprintf("\n  Significant (p<0.05):          %d\n",
            nrow(cox_sig_only)))

# check significance among D2 exploratory
d2_exp_sig <- cox_sig_only %>%
  filter(Feature %in% d2_exploratory)
cat(sprintf("  → D2 exploratory† sig:        %d\n",
            nrow(d2_exp_sig)))

cat("\n===== Uni-Cox p<0.05 results =====\n")
print(cox_sig_only %>%
        select(Feature, HR, CI_lo, CI_hi, p_value, Sig, Type))

# individually check HL/LH Skewness_trend
cat("\n===== HL/LH Skewness_trend results =====\n")
skew_res <- cox_res %>%
  filter(grepl("Skewness_trend", Feature)) %>%
  select(Feature, HR, CI_lo, CI_hi, p_value, Sig)
print(skew_res)


# ── Save to Excel ─────────────────────────────────────────────
save_name_c5 <- sprintf("%s/%dM_Cell4_UniCox.xlsx",SAVE_DIR, SENS_CUTOFF_MONTHS)

write_xlsx(
  list(
    "UniCox_All"          = cox_res,
    "UniCox_Sig_p05"      = cox_sig_only,
    "D2_Primary_trend"    = cox_res %>%
                              filter(Feature %in% d2_primary),
    "D2_Exploratory_trend"= cox_res %>%
                              filter(Feature %in% d2_exploratory)
  ),
  path = save_name_c5
)
cat(sprintf("\n[SAVE] %s\n", save_name_c5))
# Out:
# [CELL 4] Uni-Cox analysis...
#   Duration range: 35 ~ 1843 days
#   N=58 | MRONJ=19 | Control=39
#
#   Cox forward _trend (rule A, family representative): 5
#                    trend                    rep UniGEE_p
# 1           FO_IQR_trend           FO_IQR_slope   0.0448
# 2      GLRLM_LRLGE_trend     GLRLM_LRLGE_change   0.0606
# 3   NGTDM_Contrast_trend  NGTDM_Contrast_change   0.0445
# 4 Wav_HH_FO_Median_trend Wav_HH_FO_Median_slope   0.0352
# 5    Wav_LL_FO_IQR_trend    Wav_LL_FO_IQR_slope   0.0536
#   D1 features (_first + clinical):    134
#   D2 features (_trend, primary):      5
#   D2 features (_trend, exploratory†): 0
#   Total to test in Uni-Cox:           139
#
#   ✅ no _net features — unified to _trend
#
#   Running Uni-Cox...
#
#   D1 features tested:            134
#   D2 _trend features tested:     5
#   Total tested:                  139
#
#   Significant (p<0.05):          79
#   → D2 exploratory† sig:        0
#
# ===== Uni-Cox p<0.05 results =====
#                                Feature    HR CI_lo  CI_hi p_value Sig
# coef...1                      Jaw_Code 1.494 1.263  1.767  0.0000 ***
# coef...2                 FO_Mean_first 1.846 1.494  2.280  0.0000 ***
# coef...3                  FO_P75_first 1.755 1.423  2.163  0.0000 ***
# coef...4                  FO_RMS_first 1.857 1.589  2.170  0.0000 ***
# coef...5         GLCM_SumAverage_first 1.856 1.494  2.305  0.0000 ***
# coef...6              GLSZM_HGZE_first 1.893 1.537  2.331  0.0000 ***
# coef...7          Wav_LL_FO_Mean_first 1.835 1.492  2.258  0.0000 ***
# coef...8           Wav_LL_FO_P75_first 1.740 1.407  2.152  0.0000 ***
# coef...9           Wav_LL_FO_RMS_first 1.847 1.586  2.152  0.0000 ***
# coef...10          Wav_HH_FO_Std_first 2.289 1.649  3.177  0.0000 ***
# coef...11       Wav_HH_FO_Energy_first 0.261 0.138  0.492  0.0000 ***
# coef...12          Wav_HH_FO_P10_first 0.407 0.276  0.599  0.0000 ***
# coef...13          Wav_HH_FO_P25_first 0.412 0.275  0.618  0.0000 ***
# coef...14          Wav_HH_FO_P75_first 2.629 1.788  3.867  0.0000 ***
# coef...15          Wav_HH_FO_P90_first 2.480 1.721  3.572  0.0000 ***
# coef...16          Wav_HH_FO_IQR_first 2.538 1.711  3.762  0.0000 ***
# coef...17        Wav_HH_FO_Range_first 1.664 1.398  1.980  0.0000 ***
# coef...18          Wav_HH_FO_MAD_first 2.426 1.689  3.485  0.0000 ***
# coef...19          Wav_HH_FO_RMS_first 2.288 1.648  3.177  0.0000 ***
# coef...20   Wav_HH_FO_Uniformity_first 0.261 0.138  0.492  0.0000 ***
# coef...21                 FO_IQR_trend 4.797 2.287 10.066  0.0000 ***
# coef...22       Wav_HH_FO_Median_trend 3.854 2.428  6.117  0.0000 ***
# coef...23          Wav_LL_FO_IQR_trend 4.704 2.338  9.468  0.0000 ***
# coef...24           Insertion_Depth_mm 0.354 0.211  0.593  0.0001 ***
# coef...25                 FO_Std_first 1.516 1.224  1.876  0.0001 ***
# coef...26          Wav_LL_FO_Std_first 1.518 1.236  1.865  0.0001 ***
# coef...27     Wav_HH_FO_Kurtosis_first 0.129 0.046  0.363  0.0001 ***
# coef...28              FO_Median_first 2.074 1.417  3.034  0.0002 ***
# coef...29       Wav_LL_FO_Median_first 2.075 1.414  3.045  0.0002 ***
# coef...30          Wav_LL_FO_P90_first 1.563 1.227  1.993  0.0003 ***
# coef...31      Wav_HH_FO_Entropy_first 2.985 1.655  5.383  0.0003 ***
# coef...32                 FO_P90_first 1.565 1.224  2.002  0.0004 ***
# coef...33            GLRLM_SRHGE_first 2.031 1.372  3.008  0.0004 ***
# coef...34          Wav_HL_FO_IQR_first 1.620 1.222  2.147  0.0008 ***
# coef...35     Wav_HH_FO_Variance_first 2.148 1.365  3.381  0.0009 ***
# coef...36     Wav_LL_FO_Variance_first 1.448 1.163  1.804  0.0010 ***
# coef...37            FO_Variance_first 1.445 1.152  1.812  0.0014  **
# coef...38              GLRLM_RLN_first 1.984 1.265  3.111  0.0028  **
# coef...39             GLRLM_RLNU_first 1.984 1.265  3.111  0.0028  **
# coef...40      Wav_LH_FO_Entropy_first 2.534 1.371  4.684  0.0030  **
# coef...41         NGTDM_Busyness_first 0.639 0.473  0.862  0.0034  **
# coef...42          Wav_LL_FO_MAD_first 1.404 1.113  1.771  0.0042  **
# coef...43           Wav_HH_FO_CV_first 1.465 1.128  1.902  0.0042  **
# coef...44             GLSZM_GLNU_first 1.533 1.141  2.059  0.0045  **
# coef...45                 FO_MAD_first 1.403 1.107  1.779  0.0051  **
# coef...46                 FO_P25_first 1.842 1.195  2.841  0.0057  **
# coef...47          Wav_LL_FO_P25_first 1.838 1.192  2.834  0.0059  **
# coef...48              GLRLM_LRE_first 0.411 0.217  0.779  0.0064  **
# coef...49          Wav_HL_FO_P90_first 1.461 1.112  1.921  0.0066  **
# coef...50          Wav_HL_FO_P75_first 1.770 1.171  2.676  0.0067  **
# coef...51          Wav_LH_FO_P25_first 0.355 0.167  0.757  0.0074  **
# coef...52       Wav_LH_FO_Energy_first 0.359 0.167  0.774  0.0090  **
# coef...53   Wav_LH_FO_Uniformity_first 0.359 0.167  0.774  0.0090  **
# coef...54          Wav_LH_FO_P10_first 0.393 0.194  0.796  0.0095  **
# coef...55          Wav_LH_FO_IQR_first 2.302 1.224  4.332  0.0097  **
# coef...56         Is_Single_Prosthesis 1.443 1.087  1.914  0.0111   *
# coef...57               GLRLM_RP_first 1.968 1.158  3.344  0.0124   *
# coef...58       GLCM_Homogeneity_first 0.521 0.311  0.874  0.0134   *
# coef...59              GLRLM_SRE_first 1.724 1.117  2.660  0.0138   *
# coef...60        GLCM_SumEntropy_first 1.546 1.090  2.194  0.0145   *
# coef...61       GLCM_DiffEntropy_first 1.760 1.114  2.780  0.0153   *
# coef...62     GLCM_Dissimilarity_first 1.831 1.111  3.017  0.0176   *
# coef...63             FO_Entropy_first 1.473 1.068  2.033  0.0184   *
# coef...64          Wav_LH_FO_MAD_first 2.150 1.136  4.071  0.0187   *
# coef...65           GLCM_Entropy_first 1.740 1.095  2.764  0.0190   *
# coef...66          Wav_HL_FO_MAD_first 1.319 1.037  1.679  0.0242   *
# coef...67         NGTDM_Contrast_first 1.314 1.028  1.680  0.0293   *
# coef...68          Wav_LH_FO_RMS_first 1.949 1.067  3.560  0.0300   *
# coef...69          Wav_LH_FO_Std_first 1.954 1.066  3.580  0.0302   *
# coef...70 GLCM_ClusterProminence_first 1.486 1.033  2.137  0.0329   *
# coef...71          Wav_LH_FO_P90_first 1.886 1.052  3.381  0.0331   *
# coef...72          Wav_LH_FO_P75_first 1.777 1.037  3.044  0.0363   *
# coef...73      GLCM_ClusterShade_first 0.610 0.383  0.970  0.0367   *
# coef...74               GLCM_IDM_first 0.608 0.380  0.973  0.0379   *
# coef...75          GLCM_Contrast_first 1.643 1.027  2.628  0.0385   *
# coef...76      GLCM_DiffVariance_first 1.643 1.027  2.628  0.0385   *
# coef...77       GLCM_Correlation_first 1.289 1.013  1.639  0.0386   *
# coef...78      Wav_LL_FO_Entropy_first 1.494 1.011  2.208  0.0441   *
# coef...79               GLSZM_ZP_first 1.592 1.003  2.527  0.0487   *
#                 Type
# coef...1          D1
# coef...2          D1
# coef...3          D1
# coef...4          D1
# coef...5          D1
# coef...6          D1
# coef...7          D1
# coef...8          D1
# coef...9          D1
# coef...10         D1
# coef...11         D1
# coef...12         D1
# coef...13         D1
# coef...14         D1
# coef...15         D1
# coef...16         D1
# coef...17         D1
# coef...18         D1
# coef...19         D1
# coef...20         D1
# coef...21 D2_primary
# coef...22 D2_primary
# coef...23 D2_primary
# coef...24         D1
# coef...25         D1
# coef...26         D1
# coef...27         D1
# coef...28         D1
# coef...29         D1
# coef...30         D1
# coef...31         D1
# coef...32         D1
# coef...33         D1
# coef...34         D1
# coef...35         D1
# coef...36         D1
# coef...37         D1
# coef...38         D1
# coef...39         D1
# coef...40         D1
# coef...41         D1
# coef...42         D1
# coef...43         D1
# coef...44         D1
# coef...45         D1
# coef...46         D1
# coef...47         D1
# coef...48         D1
# coef...49         D1
# coef...50         D1
# coef...51         D1
# coef...52         D1
# coef...53         D1
# coef...54         D1
# coef...55         D1
# coef...56         D1
# coef...57         D1
# coef...58         D1
# coef...59         D1
# coef...60         D1
# coef...61         D1
# coef...62         D1
# coef...63         D1
# coef...64         D1
# coef...65         D1
# coef...66         D1
# coef...67         D1
# coef...68         D1
# coef...69         D1
# coef...70         D1
# coef...71         D1
# coef...72         D1
# coef...73         D1
# coef...74         D1
# coef...75         D1
# coef...76         D1
# coef...77         D1
# coef...78         D1
# coef...79         D1
#
# ===== HL/LH Skewness_trend results =====
# [1] Feature HR      CI_lo   CI_hi   p_value Sig
# <0 rows> (or 0-length row.names)
#
# [SAVE] /content/Results_R/0M_Cell4_UniCox.xlsx

# %%
# ╔══════════════════════════════════════════════════════════════╗
# ║  CELL 5 (mRMR ver.) — Feature Selection → MultiCox          ║
# ║  Gate: ICC>=0.75 & UniCox p<0.05                              ║
# ║  Select: mRMR (MID = relevance - redundancy) + |r|<0.70 constraint║
# ║  relevance = |Cox z| (derived from HR/CI), redundancy = |Spearman|║
# ╚══════════════════════════════════════════════════════════════╝
cat("\n[CELL 5 / mRMR] relevance-redundancy based representative selection...\n")

ICC_GATE        <- 0.75
CROSS_THRESHOLD <- 0.75

unicox  <- cox_res
icc_tab <- read_xlsx(file.path("/content/ICC_radiomics_evaluation.xlsx"),
                     sheet = "ICC_all_features")

get_p   <- function(f){ v <- unicox$p_value[unicox$Feature==f]; if(length(v)) v[1] else 1 }
get_icc <- function(f){ key <- sub("_(first|trend)$","",f)
                        v <- icc_tab$ICC_Inter[icc_tab$Feature==key]; if(length(v)) v[1] else NA }
# relevance = |z| = |log(HR)| / SE,  SE=(log(CIhi)-log(CIlo))/(2*1.96)
get_z   <- function(f){ r <- unicox[unicox$Feature==f, ]
  if(nrow(r)==0) return(0)
  se <- (log(r$CI_hi[1]) - log(r$CI_lo[1])) / (2*1.96)
  if(is.na(se) || se<=0) return(0)
  abs(log(r$HR[1])) / se }

# ── mRMR forward selection (MID) + independence constraint ──
mrmr_select <- function(feat_vec, tag){
  v <- feat_vec[sapply(feat_vec, function(f){
         p<-get_p(f); ic<-get_icc(f); !is.na(ic) && ic>=ICC_GATE && p<0.05 })]
  v <- v[v %in% colnames(df_imp)]
  if(length(v) < 2) return(list(sel=v, drop=data.frame()))

  z   <- sapply(v, get_z)
  rel <- (z - min(z)) / (max(z) - min(z) + 1e-9)   # normalize to [0,1]
  names(rel) <- v
  R   <- abs(cor(df_imp[, v], use="complete.obs", method="spearman"))

  sel <- character(0); drop_log <- data.frame(); rem <- v
  cat(sprintf("\n  [%s] mRMR forward (%d candidates):\n", tag, length(v)))
  while(length(rem) > 0){
    if(length(sel) == 0){
      fstar <- rem[which.max(rel[rem])]; sc <- rel[fstar]
    } else {
      redun <- sapply(rem, function(f) mean(R[f, sel]))
      score <- rel[rem] - redun
      fstar <- rem[which.max(score)]; sc <- max(score)
    }
    maxr <- if(length(sel)) max(R[fstar, sel]) else 0
    if(maxr < CROSS_THRESHOLD){
      sel <- c(sel, fstar)
      cat(sprintf("   +KEEP %-26s relN=%.2f MID=%+.2f max|r|=%.2f\n",
                  fstar, rel[fstar], sc, maxr))
    } else {
      partner <- sel[which.max(R[fstar, sel])]
      drop_log <- rbind(drop_log, data.frame(
        Dropped=fstar, Redundant_with=partner,
        Spearman_r=round(R[fstar, partner],3),
        Dropped_z=round(z[fstar],3), Dropped_p=round(get_p(fstar),4)))
      cat(sprintf("   -drop %-26s (r=%.2f with %s)\n", fstar, R[fstar,partner], partner))
    }
    rem <- setdiff(rem, fstar)
  }
  list(sel=sel, drop=drop_log)
}

static_sig  <- unicox$Feature[grepl("_first$", unicox$Feature)]
dynamic_sig <- unicox$Feature[grepl("_trend$", unicox$Feature)]

st <- mrmr_select(static_sig,  "STATIC")
dy <- mrmr_select(dynamic_sig, "DYNAMIC")
static_reps  <- st$sel
dynamic_reps <- dy$sel

# ── Final combined guard (checks incidental static x dynamic collinearity; usually a no-op) ──
union_reps <- c(static_reps, dynamic_reps)
Rall <- abs(cor(df_imp[, union_reps], use="complete.obs", method="spearman"))
keep <- character(0); guard_log <- data.frame()
ord  <- union_reps[order(-sapply(union_reps, get_z))]   # sorted by relevance, descending
for(f in ord){
  if(length(keep)==0){ keep<-f; next }
  if(max(Rall[f, keep]) < CROSS_THRESHOLD) keep <- c(keep, f)
  else { p2 <- keep[which.max(Rall[f,keep])]
         guard_log <- rbind(guard_log, data.frame(Dropped=f, With=p2,
                       r=round(Rall[f,p2],3))) }
}
cox_candidates <- keep

# clinical variables go through the same Cox-significance gate (they bypass only GEE; Cox p<0.05 is still required)
clin_sig <- clin_cols[sapply(clin_cols, function(c) get_p(c) < 0.05)]
multicox_pool <- c(clin_sig, cox_candidates)
cat("\n  Clinical significant (p<0.05):", paste(clin_sig, collapse=", "), "\n")
cat("\n  ★ Final MultiCox candidates (clinical + radiomics):\n"); print(multicox_pool)
if(nrow(guard_log)) { cat("\n  Removed by combined guard:\n"); print(guard_log) }

# ── Save ──
write_xlsx(list(
  "Static_Reps"          = data.frame(Feature=static_reps, z=sapply(static_reps,get_z),
                                       p=sapply(static_reps,get_p), ICC=sapply(static_reps,get_icc)),
  "Dynamic_Reps"         = data.frame(Feature=dynamic_reps, z=sapply(dynamic_reps,get_z),
                                       p=sapply(dynamic_reps,get_p), ICC=sapply(dynamic_reps,get_icc)),
  "Dropped_Static"       = st$drop,
  "Dropped_Dynamic"      = dy$drop,
  "Final_Cox_Candidates" = data.frame(Feature=cox_candidates)
), path = file.path(SAVE_DIR, sprintf("%dM_Cell5_Pruning.xlsx", SENS_CUTOFF_MONTHS)))
cat("\n  Saved mRMR pruning results.\n")
# Out:
# [CELL 5 / mRMR] relevance-redundancy based representative selection...
#
#   [STATIC] mRMR forward (54 candidates):
#    +KEEP Wav_LL_FO_RMS_first        relN=1.00 MID=+1.00 max|r|=0.00
#    +KEEP Wav_HH_FO_Range_first      relN=0.63 MID=+0.21 max|r|=0.42
#    -drop FO_RMS_first               (r=1.00 with Wav_LL_FO_RMS_first)
#    -drop GLSZM_HGZE_first           (r=0.98 with Wav_LL_FO_RMS_first)
#    -drop Wav_LL_FO_Mean_first       (r=0.99 with Wav_LL_FO_RMS_first)
#    -drop FO_Mean_first              (r=0.99 with Wav_LL_FO_RMS_first)
#    -drop GLCM_SumAverage_first      (r=0.99 with Wav_LL_FO_RMS_first)
#    +KEEP Wav_HH_FO_Energy_first     relN=0.36 MID=-0.11 max|r|=0.56
#    +KEEP Wav_LL_FO_Std_first        relN=0.33 MID=-0.05 max|r|=0.54
#    -drop FO_P75_first               (r=0.97 with Wav_LL_FO_RMS_first)
#    -drop Wav_LL_FO_P75_first        (r=0.97 with Wav_LL_FO_RMS_first)
#    -drop Wav_HH_FO_Std_first        (r=0.82 with Wav_HH_FO_Range_first)
#    -drop Wav_HH_FO_RMS_first        (r=0.82 with Wav_HH_FO_Range_first)
#    -drop Wav_HH_FO_Uniformity_first (r=1.00 with Wav_HH_FO_Energy_first)
#    -drop Wav_HH_FO_P90_first        (r=0.81 with Wav_HH_FO_Energy_first)
#    -drop Wav_HH_FO_P75_first        (r=0.82 with Wav_HH_FO_Energy_first)
#    -drop Wav_HH_FO_MAD_first        (r=0.80 with Wav_HH_FO_Energy_first)
#    -drop Wav_HH_FO_IQR_first        (r=0.83 with Wav_HH_FO_Energy_first)
#    -drop Wav_HH_FO_P10_first        (r=0.82 with Wav_HH_FO_Energy_first)
#    -drop FO_Std_first               (r=1.00 with Wav_LL_FO_Std_first)
#    -drop Wav_HH_FO_Entropy_first    (r=0.99 with Wav_HH_FO_Energy_first)
#    +KEEP Wav_HL_FO_IQR_first        relN=0.22 MID=-0.26 max|r|=0.62
#    -drop Wav_LL_FO_Variance_first   (r=1.00 with Wav_LL_FO_Std_first)
#    -drop FO_Median_first            (r=0.96 with Wav_LL_FO_RMS_first)
#    -drop FO_Variance_first          (r=1.00 with Wav_LL_FO_Std_first)
#    -drop Wav_LL_FO_Median_first     (r=0.96 with Wav_LL_FO_RMS_first)
#    -drop Wav_LL_FO_MAD_first        (r=0.97 with Wav_LL_FO_Std_first)
#    -drop Wav_HH_FO_P25_first        (r=0.84 with Wav_HH_FO_Energy_first)
#    -drop FO_MAD_first               (r=0.97 with Wav_LL_FO_Std_first)
#    -drop GLCM_Correlation_first     (r=0.85 with Wav_LL_FO_Std_first)
#    +KEEP GLSZM_GLNU_first           relN=0.13 MID=-0.32 max|r|=0.67
#    -drop Wav_LL_FO_P90_first        (r=0.90 with Wav_LL_FO_RMS_first)
#    -drop FO_P90_first               (r=0.90 with Wav_LL_FO_RMS_first)
#    -drop GLCM_SumEntropy_first      (r=0.91 with Wav_LL_FO_Std_first)
#    -drop FO_P25_first               (r=0.91 with Wav_LL_FO_RMS_first)
#    -drop Wav_LL_FO_P25_first        (r=0.91 with Wav_LL_FO_RMS_first)
#    -drop GLRLM_SRHGE_first          (r=0.96 with Wav_LL_FO_RMS_first)
#    -drop GLCM_Entropy_first         (r=0.84 with Wav_LL_FO_Std_first)
#    -drop NGTDM_Contrast_first       (r=0.95 with Wav_LL_FO_Std_first)
#    -drop GLCM_ClusterProminence_first (r=0.95 with Wav_LL_FO_Std_first)
#    +KEEP GLCM_ClusterShade_first    relN=0.00 MID=-0.45 max|r|=0.71
#    -drop GLRLM_RLN_first            (r=0.80 with Wav_HL_FO_IQR_first)
#    -drop GLRLM_RLNU_first           (r=0.80 with Wav_HL_FO_IQR_first)
#    -drop Wav_HL_FO_P75_first        (r=0.86 with Wav_HL_FO_IQR_first)
#    -drop Wav_HH_FO_Variance_first   (r=0.82 with Wav_HH_FO_Range_first)
#    -drop GLRLM_LRE_first            (r=0.87 with Wav_HL_FO_IQR_first)
#    -drop GLRLM_RP_first             (r=0.87 with Wav_HL_FO_IQR_first)
#    -drop GLCM_Homogeneity_first     (r=0.87 with Wav_HL_FO_IQR_first)
#    +KEEP Wav_LH_FO_P25_first        relN=0.11 MID=-0.52 max|r|=0.74
#    -drop Wav_LH_FO_P10_first        (r=0.98 with Wav_LH_FO_P25_first)
#    -drop Wav_LH_FO_IQR_first        (r=0.92 with Wav_LH_FO_P25_first)
#    -drop Wav_LH_FO_P75_first        (r=0.80 with Wav_HL_FO_IQR_first)
#    -drop Wav_LH_FO_MAD_first        (r=0.91 with Wav_LH_FO_P25_first)
#    -drop Wav_LH_FO_P90_first        (r=0.83 with Wav_LH_FO_P25_first)
#
#   [DYNAMIC] mRMR forward (3 candidates):
#    +KEEP Wav_HH_FO_Median_trend     relN=1.00 MID=+1.00 max|r|=0.00
#    +KEEP Wav_LL_FO_IQR_trend        relN=0.12 MID=-0.03 max|r|=0.15
#    -drop FO_IQR_trend               (r=1.00 with Wav_LL_FO_IQR_trend)
#
#   Clinical significant (p<0.05): Insertion_Depth_mm, Is_Single_Prosthesis, Jaw_Code
#
#   ★ Final MultiCox candidates (clinical + radiomics):
#  [1] "Insertion_Depth_mm"      "Is_Single_Prosthesis"
#  [3] "Jaw_Code"                "Wav_LL_FO_RMS_first"
#  [5] "Wav_HH_FO_Range_first"   "Wav_HH_FO_Median_trend"
#  [7] "Wav_LL_FO_IQR_trend"     "Wav_HH_FO_Energy_first"
#  [9] "Wav_LL_FO_Std_first"     "Wav_HL_FO_IQR_first"
# [11] "GLSZM_GLNU_first"        "Wav_LH_FO_P25_first"
# [13] "GLCM_ClusterShade_first"
#
#   Saved mRMR pruning results.

# %%
# ╔══════════════════════════════════════════════════════════════╗
# ║  CELL 6 — Multi-Cox (Systematic Combinatorial Matrix)        ║
# ║  Input : df_imp, sig_cox (Cell 4 output)                     ║
# ║  Output: multi_cox_res, cox_final (best model)               ║
# ╚══════════════════════════════════════════════════════════════╝

cat("\n[CELL 6] Multi-Cox analysis...\n")

# ══════════════════════════════════════════════════════════════
# CELL 6 — MultiCox feat_sets (AUTO from Cell4.5 pruning)
#   input: Cell5_Pruning.xlsx -> Final_Cox_Candidates (radiomics)
#   3 clinical + cross-family-passing radiomics -> all 2-feature combinations
# ══════════════════════════════════════════════════════════════
cat("\n[CELL 6] MultiCox — auto feat_sets from pruning result...\n")

# ── Load pruning results (auto-received) ──
prune_file <- sprintf("%s/%dM_Cell5_Pruning.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS)
cox_candidates <- read_xlsx(prune_file, sheet = "Final_Cox_Candidates")$Feature

# clinical: exempt from ICC/family pruning, only requires UniCox p<0.05 (goes straight to Cox)
clin_sig <- unicox$Feature[unicox$Feature %in% clin_cols & unicox$p_value < 0.05]
# radiomics: Cell4.5 pruning result
cox_candidates <- read_xlsx(prune_file, sheet="Final_Cox_Candidates")$Feature
multicox_pool  <- c(clin_sig, cox_candidates)   # 3 + 5 = 8
cat(sprintf("MultiCox candidates: %d (clinical %d + radiomics %d)\n",
            length(multicox_pool), length(clin_sig), length(cox_candidates)))

# ── Short-name mapping (for auto-generating model IDs) ──
abbrev <- function(f){
  f <- sub("_first$","", f); f <- sub("_trend$","T", f)
  f <- gsub("Wav_","", f);   f <- gsub("_FO_","", f); f <- gsub("FO_","FO", f)
  f <- gsub("Insertion_Depth_mm","Depth", f)
  f <- gsub("Is_Single_Prosthesis","SP", f)
  f <- gsub("Jaw_Code","Jaw", f)
  gsub("_","", f)
}

is_clin <- function(f) f %in% clin_cols
cat_of  <- function(a,b){ n <- is_clin(a)+is_clin(b)
  if(n==2) "CM" else if(n==1) "CRM" else "RM" }

# ── Auto-generate all 2-feature combinations ──
pairs <- combn(multicox_pool, 2, simplify = FALSE)
feat_sets <- list()
for(pr in pairs){
  a <- pr[1]; b <- pr[2]
  nm <- sprintf("%s_%s_%s", cat_of(a,b), abbrev(a), abbrev(b))
  feat_sets[[nm]] <- c(a, b)
}

# ── Summary ──
n_cm  <- sum(sapply(pairs, function(p) cat_of(p[1],p[2])=="CM"))
n_crm <- sum(sapply(pairs, function(p) cat_of(p[1],p[2])=="CRM"))
n_rm  <- sum(sapply(pairs, function(p) cat_of(p[1],p[2])=="RM"))
cat(sprintf("  Combinations generated: %d  (CM=%d, CRM=%d, RM=%d)\n",
            length(feat_sets), n_cm, n_crm, n_rm))
# 8 candidates -> CM 3 / CRM 15 / RM 10 = 28

# ── Multi-Cox execution function ────────────────────────────
run_cox_multi <- function(feat_name, feat_cols, data) {
  cols <- feat_cols[feat_cols %in% names(data)]
  if (length(cols) < 2) {
    cat(sprintf("  [%s] skipped: fewer than 2 valid features\n", feat_name))
    return(NULL)
  }

  df_sub <- data %>%
    mutate(across(all_of(cols), ~scale(.x)[,1])) %>%
    select(Duration, Event, Patient_ID, all_of(cols)) %>%  # ★ add Patient_ID
    na.omit()

  fit <- tryCatch(
    coxph(as.formula(paste("Surv(Duration,Event) ~",
                           paste(cols, collapse="+"),
                           "+ cluster(Patient_ID)")),       # ★ add cluster
          data=df_sub),
    error=function(e) { cat(sprintf("  [%s] error: %s\n", feat_name, e$message)); NULL }
  )
  if (is.null(fit)) return(NULL)

  coef_tbl <- summary(fit)$coefficients
  ci_tbl   <- summary(fit)$conf.int
  c_idx    <- fit$concordance["concordance"]
  all_sig  <- all(coef_tbl[,"Pr(>|z|)"] < 0.05)  # robust p-value is used automatically ✅

  var_rows <- data.frame(
    Model      = feat_name,
    Feature    = rownames(coef_tbl),
    HR         = round(ci_tbl[,"exp(coef)"],  3),
    CI_lo      = round(ci_tbl[,"lower .95"],  3),
    CI_hi      = round(ci_tbl[,"upper .95"],  3),
    p_value    = round(coef_tbl[,"Pr(>|z|)"], 4),
    Sig        = ifelse(coef_tbl[,"Pr(>|z|)"]<0.001,"***",
                 ifelse(coef_tbl[,"Pr(>|z|)"]<0.01, "**",
                 ifelse(coef_tbl[,"Pr(>|z|)"]<0.05, "*",
                 ifelse(coef_tbl[,"Pr(>|z|)"]<0.10, "†","ns")))),
    C_index    = round(c_idx, 3),
    All_p05    = ifelse(all_sig, "YES", "NO"),
    stringsAsFactors = FALSE
  )
  var_rows
}

# ── Run all ───────────────────────────────────────────────────
cat(strrep("=", 60), "\n")
multi_cox_detail <- do.call(rbind, mapply(
  run_cox_multi,
  names(feat_sets), feat_sets,
  MoreArgs = list(data=df_imp),
  SIMPLIFY = FALSE
))

# ── Print results ─────────────────────────────────────────────
cat("\n===== Multi-Cox: variable-level detail =====\n")
print(multi_cox_detail)

# per-model summary
multi_cox_res <- multi_cox_detail %>%
  group_by(Model, C_index, All_p05) %>%
  summarise(
    Features = paste(Feature, collapse=" + "),
    .groups = "drop"
  ) %>%
  arrange(desc(C_index))

cat("\n===== Multi-Cox: model summary =====\n")
print(multi_cox_res)

cat("\n  Hint: All_p05=YES means all variables significant (p<0.05)\n")

# ── Save best model (highest C-index among All_p05=YES) ──────
best_row <- multi_cox_res %>%
  filter(All_p05 == "YES") %>%
  slice(1)

if (nrow(best_row) > 0) {
  best_name <- best_row$Model
  best_cols <- feat_sets[[best_name]]
  best_cols <- best_cols[best_cols %in% names(df_imp)]

  df_best <- df_imp %>%
    mutate(across(all_of(best_cols), ~scale(.x)[,1])) %>%
    select(Duration, Event, Patient_ID, all_of(best_cols)) %>%  # ★ add Patient_ID
    na.omit()

  cox_final <- coxph(
    as.formula(paste("Surv(Duration,Event) ~",
                     paste(best_cols, collapse="+"),
                     "+ cluster(Patient_ID)")),                  # ★ add cluster
    data=df_best)

  cat(sprintf("\n★ Best model (All_p05=YES, highest C-index): %s\n", best_name))
  cat(sprintf("  C-index = %.3f\n", best_row$C_index))

  coef_tbl <- summary(cox_final)$coefficients
  ci_tbl   <- summary(cox_final)$conf.int
  best_print <- data.frame(
    HR      = ci_tbl[, "exp(coef)"],
    CI_lo   = ci_tbl[, "lower .95"],
    CI_hi   = ci_tbl[, "upper .95"],
    p_value = coef_tbl[, "Pr(>|z|)"]
  )
  print(round(best_print, 4))

} else {
  cat("\n⚠ No model with all p<0.05. Check multi_cox_res above.\n")
  cox_final <- NULL
}

# ── Save to Excel ─────────────────────────────────────────────
save_name_c6 <- sprintf("%s/%dM_Cell6_MultiCox.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS)
write_xlsx(
  list(
    "MultiCox_Detail"  = multi_cox_detail,
    "MultiCox_Summary" = multi_cox_res
  ),
  path = save_name_c6
)
cat(sprintf("Saved: %s\n", save_name_c6))
# Out:
# [CELL 6] Multi-Cox analysis...
#
# [CELL 6] MultiCox — auto feat_sets from pruning result...
# MultiCox candidates: 13 (clinical 3 + radiomics 10)
#   Combinations generated: 78  (CM=3, CRM=30, RM=45)
# ============================================================
#
# ===== Multi-Cox: variable-level detail =====
#                                                                               Model
# CM_Jaw_Depth.Jaw_Code                                                  CM_Jaw_Depth
# CM_Jaw_Depth.Insertion_Depth_mm                                        CM_Jaw_Depth
# CM_Jaw_SP.Jaw_Code                                                        CM_Jaw_SP
# CM_Jaw_SP.Is_Single_Prosthesis                                            CM_Jaw_SP
# CRM_Jaw_LLRMS.Jaw_Code                                                CRM_Jaw_LLRMS
# CRM_Jaw_LLRMS.Wav_LL_FO_RMS_first                                     CRM_Jaw_LLRMS
# CRM_Jaw_HHRange.Jaw_Code                                            CRM_Jaw_HHRange
# CRM_Jaw_HHRange.Wav_HH_FO_Range_first                               CRM_Jaw_HHRange
# CRM_Jaw_HHMedianT.Jaw_Code                                        CRM_Jaw_HHMedianT
# CRM_Jaw_HHMedianT.Wav_HH_FO_Median_trend                          CRM_Jaw_HHMedianT
# CRM_Jaw_LLIQRT.Jaw_Code                                              CRM_Jaw_LLIQRT
# CRM_Jaw_LLIQRT.Wav_LL_FO_IQR_trend                                   CRM_Jaw_LLIQRT
# CRM_Jaw_HHEnergy.Jaw_Code                                          CRM_Jaw_HHEnergy
# CRM_Jaw_HHEnergy.Wav_HH_FO_Energy_first                            CRM_Jaw_HHEnergy
# CRM_Jaw_LLStd.Jaw_Code                                                CRM_Jaw_LLStd
# CRM_Jaw_LLStd.Wav_LL_FO_Std_first                                     CRM_Jaw_LLStd
# CRM_Jaw_HLIQR.Jaw_Code                                                CRM_Jaw_HLIQR
# CRM_Jaw_HLIQR.Wav_HL_FO_IQR_first                                     CRM_Jaw_HLIQR
# CRM_Jaw_GLSZMGLNU.Jaw_Code                                        CRM_Jaw_GLSZMGLNU
# CRM_Jaw_GLSZMGLNU.GLSZM_GLNU_first                                CRM_Jaw_GLSZMGLNU
# CRM_Jaw_LHP25.Jaw_Code                                                CRM_Jaw_LHP25
# CRM_Jaw_LHP25.Wav_LH_FO_P25_first                                     CRM_Jaw_LHP25
# CRM_Jaw_GLCMClusterShade.Jaw_Code                          CRM_Jaw_GLCMClusterShade
# CRM_Jaw_GLCMClusterShade.GLCM_ClusterShade_first           CRM_Jaw_GLCMClusterShade
# CM_Depth_SP.Insertion_Depth_mm                                          CM_Depth_SP
# CM_Depth_SP.Is_Single_Prosthesis                                        CM_Depth_SP
# CRM_Depth_LLRMS.Insertion_Depth_mm                                  CRM_Depth_LLRMS
# CRM_Depth_LLRMS.Wav_LL_FO_RMS_first                                 CRM_Depth_LLRMS
# CRM_Depth_HHRange.Insertion_Depth_mm                              CRM_Depth_HHRange
# CRM_Depth_HHRange.Wav_HH_FO_Range_first                           CRM_Depth_HHRange
# CRM_Depth_HHMedianT.Insertion_Depth_mm                          CRM_Depth_HHMedianT
# CRM_Depth_HHMedianT.Wav_HH_FO_Median_trend                      CRM_Depth_HHMedianT
# CRM_Depth_LLIQRT.Insertion_Depth_mm                                CRM_Depth_LLIQRT
# CRM_Depth_LLIQRT.Wav_LL_FO_IQR_trend                               CRM_Depth_LLIQRT
# CRM_Depth_HHEnergy.Insertion_Depth_mm                            CRM_Depth_HHEnergy
# CRM_Depth_HHEnergy.Wav_HH_FO_Energy_first                        CRM_Depth_HHEnergy
# CRM_Depth_LLStd.Insertion_Depth_mm                                  CRM_Depth_LLStd
# CRM_Depth_LLStd.Wav_LL_FO_Std_first                                 CRM_Depth_LLStd
# CRM_Depth_HLIQR.Insertion_Depth_mm                                  CRM_Depth_HLIQR
# CRM_Depth_HLIQR.Wav_HL_FO_IQR_first                                 CRM_Depth_HLIQR
# CRM_Depth_GLSZMGLNU.Insertion_Depth_mm                          CRM_Depth_GLSZMGLNU
# CRM_Depth_GLSZMGLNU.GLSZM_GLNU_first                            CRM_Depth_GLSZMGLNU
# CRM_Depth_LHP25.Insertion_Depth_mm                                  CRM_Depth_LHP25
# CRM_Depth_LHP25.Wav_LH_FO_P25_first                                 CRM_Depth_LHP25
# CRM_Depth_GLCMClusterShade.Insertion_Depth_mm            CRM_Depth_GLCMClusterShade
# CRM_Depth_GLCMClusterShade.GLCM_ClusterShade_first       CRM_Depth_GLCMClusterShade
# CRM_SP_LLRMS.Is_Single_Prosthesis                                      CRM_SP_LLRMS
# CRM_SP_LLRMS.Wav_LL_FO_RMS_first                                       CRM_SP_LLRMS
# CRM_SP_HHRange.Is_Single_Prosthesis                                  CRM_SP_HHRange
# CRM_SP_HHRange.Wav_HH_FO_Range_first                                 CRM_SP_HHRange
# CRM_SP_HHMedianT.Is_Single_Prosthesis                              CRM_SP_HHMedianT
# CRM_SP_HHMedianT.Wav_HH_FO_Median_trend                            CRM_SP_HHMedianT
# CRM_SP_LLIQRT.Is_Single_Prosthesis                                    CRM_SP_LLIQRT
# CRM_SP_LLIQRT.Wav_LL_FO_IQR_trend                                     CRM_SP_LLIQRT
# CRM_SP_HHEnergy.Is_Single_Prosthesis                                CRM_SP_HHEnergy
# CRM_SP_HHEnergy.Wav_HH_FO_Energy_first                              CRM_SP_HHEnergy
# CRM_SP_LLStd.Is_Single_Prosthesis                                      CRM_SP_LLStd
# CRM_SP_LLStd.Wav_LL_FO_Std_first                                       CRM_SP_LLStd
# CRM_SP_HLIQR.Is_Single_Prosthesis                                      CRM_SP_HLIQR
# CRM_SP_HLIQR.Wav_HL_FO_IQR_first                                       CRM_SP_HLIQR
# CRM_SP_GLSZMGLNU.Is_Single_Prosthesis                              CRM_SP_GLSZMGLNU
# CRM_SP_GLSZMGLNU.GLSZM_GLNU_first                                  CRM_SP_GLSZMGLNU
# CRM_SP_LHP25.Is_Single_Prosthesis                                      CRM_SP_LHP25
# CRM_SP_LHP25.Wav_LH_FO_P25_first                                       CRM_SP_LHP25
# CRM_SP_GLCMClusterShade.Is_Single_Prosthesis                CRM_SP_GLCMClusterShade
# CRM_SP_GLCMClusterShade.GLCM_ClusterShade_first             CRM_SP_GLCMClusterShade
# RM_LLRMS_HHRange.Wav_LL_FO_RMS_first                               RM_LLRMS_HHRange
# RM_LLRMS_HHRange.Wav_HH_FO_Range_first                             RM_LLRMS_HHRange
# RM_LLRMS_HHMedianT.Wav_LL_FO_RMS_first                           RM_LLRMS_HHMedianT
# RM_LLRMS_HHMedianT.Wav_HH_FO_Median_trend                        RM_LLRMS_HHMedianT
# RM_LLRMS_LLIQRT.Wav_LL_FO_RMS_first                                 RM_LLRMS_LLIQRT
# RM_LLRMS_LLIQRT.Wav_LL_FO_IQR_trend                                 RM_LLRMS_LLIQRT
# RM_LLRMS_HHEnergy.Wav_LL_FO_RMS_first                             RM_LLRMS_HHEnergy
# RM_LLRMS_HHEnergy.Wav_HH_FO_Energy_first                          RM_LLRMS_HHEnergy
# RM_LLRMS_LLStd.Wav_LL_FO_RMS_first                                   RM_LLRMS_LLStd
# RM_LLRMS_LLStd.Wav_LL_FO_Std_first                                   RM_LLRMS_LLStd
# RM_LLRMS_HLIQR.Wav_LL_FO_RMS_first                                   RM_LLRMS_HLIQR
# RM_LLRMS_HLIQR.Wav_HL_FO_IQR_first                                   RM_LLRMS_HLIQR
# RM_LLRMS_GLSZMGLNU.Wav_LL_FO_RMS_first                           RM_LLRMS_GLSZMGLNU
# RM_LLRMS_GLSZMGLNU.GLSZM_GLNU_first                              RM_LLRMS_GLSZMGLNU
# RM_LLRMS_LHP25.Wav_LL_FO_RMS_first                                   RM_LLRMS_LHP25
# RM_LLRMS_LHP25.Wav_LH_FO_P25_first                                   RM_LLRMS_LHP25
# RM_LLRMS_GLCMClusterShade.Wav_LL_FO_RMS_first             RM_LLRMS_GLCMClusterShade
# RM_LLRMS_GLCMClusterShade.GLCM_ClusterShade_first         RM_LLRMS_GLCMClusterShade
# RM_HHRange_HHMedianT.Wav_HH_FO_Range_first                     RM_HHRange_HHMedianT
# RM_HHRange_HHMedianT.Wav_HH_FO_Median_trend                    RM_HHRange_HHMedianT
# RM_HHRange_LLIQRT.Wav_HH_FO_Range_first                           RM_HHRange_LLIQRT
# RM_HHRange_LLIQRT.Wav_LL_FO_IQR_trend                             RM_HHRange_LLIQRT
# RM_HHRange_HHEnergy.Wav_HH_FO_Range_first                       RM_HHRange_HHEnergy
# RM_HHRange_HHEnergy.Wav_HH_FO_Energy_first                      RM_HHRange_HHEnergy
# RM_HHRange_LLStd.Wav_HH_FO_Range_first                             RM_HHRange_LLStd
# RM_HHRange_LLStd.Wav_LL_FO_Std_first                               RM_HHRange_LLStd
# RM_HHRange_HLIQR.Wav_HH_FO_Range_first                             RM_HHRange_HLIQR
# RM_HHRange_HLIQR.Wav_HL_FO_IQR_first                               RM_HHRange_HLIQR
# RM_HHRange_GLSZMGLNU.Wav_HH_FO_Range_first                     RM_HHRange_GLSZMGLNU
# RM_HHRange_GLSZMGLNU.GLSZM_GLNU_first                          RM_HHRange_GLSZMGLNU
# RM_HHRange_LHP25.Wav_HH_FO_Range_first                             RM_HHRange_LHP25
# RM_HHRange_LHP25.Wav_LH_FO_P25_first                               RM_HHRange_LHP25
# RM_HHRange_GLCMClusterShade.Wav_HH_FO_Range_first       RM_HHRange_GLCMClusterShade
# RM_HHRange_GLCMClusterShade.GLCM_ClusterShade_first     RM_HHRange_GLCMClusterShade
# RM_HHMedianT_LLIQRT.Wav_HH_FO_Median_trend                      RM_HHMedianT_LLIQRT
# RM_HHMedianT_LLIQRT.Wav_LL_FO_IQR_trend                         RM_HHMedianT_LLIQRT
# RM_HHMedianT_HHEnergy.Wav_HH_FO_Median_trend                  RM_HHMedianT_HHEnergy
# RM_HHMedianT_HHEnergy.Wav_HH_FO_Energy_first                  RM_HHMedianT_HHEnergy
# RM_HHMedianT_LLStd.Wav_HH_FO_Median_trend                        RM_HHMedianT_LLStd
# RM_HHMedianT_LLStd.Wav_LL_FO_Std_first                           RM_HHMedianT_LLStd
# RM_HHMedianT_HLIQR.Wav_HH_FO_Median_trend                        RM_HHMedianT_HLIQR
# RM_HHMedianT_HLIQR.Wav_HL_FO_IQR_first                           RM_HHMedianT_HLIQR
# RM_HHMedianT_GLSZMGLNU.Wav_HH_FO_Median_trend                RM_HHMedianT_GLSZMGLNU
# RM_HHMedianT_GLSZMGLNU.GLSZM_GLNU_first                      RM_HHMedianT_GLSZMGLNU
# RM_HHMedianT_LHP25.Wav_HH_FO_Median_trend                        RM_HHMedianT_LHP25
# RM_HHMedianT_LHP25.Wav_LH_FO_P25_first                           RM_HHMedianT_LHP25
# RM_HHMedianT_GLCMClusterShade.Wav_HH_FO_Median_trend  RM_HHMedianT_GLCMClusterShade
# RM_HHMedianT_GLCMClusterShade.GLCM_ClusterShade_first RM_HHMedianT_GLCMClusterShade
# RM_LLIQRT_HHEnergy.Wav_LL_FO_IQR_trend                           RM_LLIQRT_HHEnergy
# RM_LLIQRT_HHEnergy.Wav_HH_FO_Energy_first                        RM_LLIQRT_HHEnergy
# RM_LLIQRT_LLStd.Wav_LL_FO_IQR_trend                                 RM_LLIQRT_LLStd
# RM_LLIQRT_LLStd.Wav_LL_FO_Std_first                                 RM_LLIQRT_LLStd
# RM_LLIQRT_HLIQR.Wav_LL_FO_IQR_trend                                 RM_LLIQRT_HLIQR
# RM_LLIQRT_HLIQR.Wav_HL_FO_IQR_first                                 RM_LLIQRT_HLIQR
# RM_LLIQRT_GLSZMGLNU.Wav_LL_FO_IQR_trend                         RM_LLIQRT_GLSZMGLNU
# RM_LLIQRT_GLSZMGLNU.GLSZM_GLNU_first                            RM_LLIQRT_GLSZMGLNU
# RM_LLIQRT_LHP25.Wav_LL_FO_IQR_trend                                 RM_LLIQRT_LHP25
# RM_LLIQRT_LHP25.Wav_LH_FO_P25_first                                 RM_LLIQRT_LHP25
# RM_LLIQRT_GLCMClusterShade.Wav_LL_FO_IQR_trend           RM_LLIQRT_GLCMClusterShade
# RM_LLIQRT_GLCMClusterShade.GLCM_ClusterShade_first       RM_LLIQRT_GLCMClusterShade
# RM_HHEnergy_LLStd.Wav_HH_FO_Energy_first                          RM_HHEnergy_LLStd
# RM_HHEnergy_LLStd.Wav_LL_FO_Std_first                             RM_HHEnergy_LLStd
# RM_HHEnergy_HLIQR.Wav_HH_FO_Energy_first                          RM_HHEnergy_HLIQR
# RM_HHEnergy_HLIQR.Wav_HL_FO_IQR_first                             RM_HHEnergy_HLIQR
# RM_HHEnergy_GLSZMGLNU.Wav_HH_FO_Energy_first                  RM_HHEnergy_GLSZMGLNU
# RM_HHEnergy_GLSZMGLNU.GLSZM_GLNU_first                        RM_HHEnergy_GLSZMGLNU
# RM_HHEnergy_LHP25.Wav_HH_FO_Energy_first                          RM_HHEnergy_LHP25
# RM_HHEnergy_LHP25.Wav_LH_FO_P25_first                             RM_HHEnergy_LHP25
# RM_HHEnergy_GLCMClusterShade.Wav_HH_FO_Energy_first    RM_HHEnergy_GLCMClusterShade
# RM_HHEnergy_GLCMClusterShade.GLCM_ClusterShade_first   RM_HHEnergy_GLCMClusterShade
# RM_LLStd_HLIQR.Wav_LL_FO_Std_first                                   RM_LLStd_HLIQR
# RM_LLStd_HLIQR.Wav_HL_FO_IQR_first                                   RM_LLStd_HLIQR
# RM_LLStd_GLSZMGLNU.Wav_LL_FO_Std_first                           RM_LLStd_GLSZMGLNU
# RM_LLStd_GLSZMGLNU.GLSZM_GLNU_first                              RM_LLStd_GLSZMGLNU
# RM_LLStd_LHP25.Wav_LL_FO_Std_first                                   RM_LLStd_LHP25
# RM_LLStd_LHP25.Wav_LH_FO_P25_first                                   RM_LLStd_LHP25
# RM_LLStd_GLCMClusterShade.Wav_LL_FO_Std_first             RM_LLStd_GLCMClusterShade
# RM_LLStd_GLCMClusterShade.GLCM_ClusterShade_first         RM_LLStd_GLCMClusterShade
# RM_HLIQR_GLSZMGLNU.Wav_HL_FO_IQR_first                           RM_HLIQR_GLSZMGLNU
# RM_HLIQR_GLSZMGLNU.GLSZM_GLNU_first                              RM_HLIQR_GLSZMGLNU
# RM_HLIQR_LHP25.Wav_HL_FO_IQR_first                                   RM_HLIQR_LHP25
# RM_HLIQR_LHP25.Wav_LH_FO_P25_first                                   RM_HLIQR_LHP25
# RM_HLIQR_GLCMClusterShade.Wav_HL_FO_IQR_first             RM_HLIQR_GLCMClusterShade
# RM_HLIQR_GLCMClusterShade.GLCM_ClusterShade_first         RM_HLIQR_GLCMClusterShade
# RM_GLSZMGLNU_LHP25.GLSZM_GLNU_first                              RM_GLSZMGLNU_LHP25
# RM_GLSZMGLNU_LHP25.Wav_LH_FO_P25_first                           RM_GLSZMGLNU_LHP25
# RM_GLSZMGLNU_GLCMClusterShade.GLSZM_GLNU_first        RM_GLSZMGLNU_GLCMClusterShade
# RM_GLSZMGLNU_GLCMClusterShade.GLCM_ClusterShade_first RM_GLSZMGLNU_GLCMClusterShade
# RM_LHP25_GLCMClusterShade.Wav_LH_FO_P25_first             RM_LHP25_GLCMClusterShade
# RM_LHP25_GLCMClusterShade.GLCM_ClusterShade_first         RM_LHP25_GLCMClusterShade
#                                                                       Feature
# CM_Jaw_Depth.Jaw_Code                                                Jaw_Code
# CM_Jaw_Depth.Insertion_Depth_mm                            Insertion_Depth_mm
# CM_Jaw_SP.Jaw_Code                                                   Jaw_Code
# CM_Jaw_SP.Is_Single_Prosthesis                           Is_Single_Prosthesis
# CRM_Jaw_LLRMS.Jaw_Code                                               Jaw_Code
# CRM_Jaw_LLRMS.Wav_LL_FO_RMS_first                         Wav_LL_FO_RMS_first
# CRM_Jaw_HHRange.Jaw_Code                                             Jaw_Code
# CRM_Jaw_HHRange.Wav_HH_FO_Range_first                   Wav_HH_FO_Range_first
# CRM_Jaw_HHMedianT.Jaw_Code                                           Jaw_Code
# CRM_Jaw_HHMedianT.Wav_HH_FO_Median_trend               Wav_HH_FO_Median_trend
# CRM_Jaw_LLIQRT.Jaw_Code                                              Jaw_Code
# CRM_Jaw_LLIQRT.Wav_LL_FO_IQR_trend                        Wav_LL_FO_IQR_trend
# CRM_Jaw_HHEnergy.Jaw_Code                                            Jaw_Code
# CRM_Jaw_HHEnergy.Wav_HH_FO_Energy_first                Wav_HH_FO_Energy_first
# CRM_Jaw_LLStd.Jaw_Code                                               Jaw_Code
# CRM_Jaw_LLStd.Wav_LL_FO_Std_first                         Wav_LL_FO_Std_first
# CRM_Jaw_HLIQR.Jaw_Code                                               Jaw_Code
# CRM_Jaw_HLIQR.Wav_HL_FO_IQR_first                         Wav_HL_FO_IQR_first
# CRM_Jaw_GLSZMGLNU.Jaw_Code                                           Jaw_Code
# CRM_Jaw_GLSZMGLNU.GLSZM_GLNU_first                           GLSZM_GLNU_first
# CRM_Jaw_LHP25.Jaw_Code                                               Jaw_Code
# CRM_Jaw_LHP25.Wav_LH_FO_P25_first                         Wav_LH_FO_P25_first
# CRM_Jaw_GLCMClusterShade.Jaw_Code                                    Jaw_Code
# CRM_Jaw_GLCMClusterShade.GLCM_ClusterShade_first      GLCM_ClusterShade_first
# CM_Depth_SP.Insertion_Depth_mm                             Insertion_Depth_mm
# CM_Depth_SP.Is_Single_Prosthesis                         Is_Single_Prosthesis
# CRM_Depth_LLRMS.Insertion_Depth_mm                         Insertion_Depth_mm
# CRM_Depth_LLRMS.Wav_LL_FO_RMS_first                       Wav_LL_FO_RMS_first
# CRM_Depth_HHRange.Insertion_Depth_mm                       Insertion_Depth_mm
# CRM_Depth_HHRange.Wav_HH_FO_Range_first                 Wav_HH_FO_Range_first
# CRM_Depth_HHMedianT.Insertion_Depth_mm                     Insertion_Depth_mm
# CRM_Depth_HHMedianT.Wav_HH_FO_Median_trend             Wav_HH_FO_Median_trend
# CRM_Depth_LLIQRT.Insertion_Depth_mm                        Insertion_Depth_mm
# CRM_Depth_LLIQRT.Wav_LL_FO_IQR_trend                      Wav_LL_FO_IQR_trend
# CRM_Depth_HHEnergy.Insertion_Depth_mm                      Insertion_Depth_mm
# CRM_Depth_HHEnergy.Wav_HH_FO_Energy_first              Wav_HH_FO_Energy_first
# CRM_Depth_LLStd.Insertion_Depth_mm                         Insertion_Depth_mm
# CRM_Depth_LLStd.Wav_LL_FO_Std_first                       Wav_LL_FO_Std_first
# CRM_Depth_HLIQR.Insertion_Depth_mm                         Insertion_Depth_mm
# CRM_Depth_HLIQR.Wav_HL_FO_IQR_first                       Wav_HL_FO_IQR_first
# CRM_Depth_GLSZMGLNU.Insertion_Depth_mm                     Insertion_Depth_mm
# CRM_Depth_GLSZMGLNU.GLSZM_GLNU_first                         GLSZM_GLNU_first
# CRM_Depth_LHP25.Insertion_Depth_mm                         Insertion_Depth_mm
# CRM_Depth_LHP25.Wav_LH_FO_P25_first                       Wav_LH_FO_P25_first
# CRM_Depth_GLCMClusterShade.Insertion_Depth_mm              Insertion_Depth_mm
# CRM_Depth_GLCMClusterShade.GLCM_ClusterShade_first    GLCM_ClusterShade_first
# CRM_SP_LLRMS.Is_Single_Prosthesis                        Is_Single_Prosthesis
# CRM_SP_LLRMS.Wav_LL_FO_RMS_first                          Wav_LL_FO_RMS_first
# CRM_SP_HHRange.Is_Single_Prosthesis                      Is_Single_Prosthesis
# CRM_SP_HHRange.Wav_HH_FO_Range_first                    Wav_HH_FO_Range_first
# CRM_SP_HHMedianT.Is_Single_Prosthesis                    Is_Single_Prosthesis
# CRM_SP_HHMedianT.Wav_HH_FO_Median_trend                Wav_HH_FO_Median_trend
# CRM_SP_LLIQRT.Is_Single_Prosthesis                       Is_Single_Prosthesis
# CRM_SP_LLIQRT.Wav_LL_FO_IQR_trend                         Wav_LL_FO_IQR_trend
# CRM_SP_HHEnergy.Is_Single_Prosthesis                     Is_Single_Prosthesis
# CRM_SP_HHEnergy.Wav_HH_FO_Energy_first                 Wav_HH_FO_Energy_first
# CRM_SP_LLStd.Is_Single_Prosthesis                        Is_Single_Prosthesis
# CRM_SP_LLStd.Wav_LL_FO_Std_first                          Wav_LL_FO_Std_first
# CRM_SP_HLIQR.Is_Single_Prosthesis                        Is_Single_Prosthesis
# CRM_SP_HLIQR.Wav_HL_FO_IQR_first                          Wav_HL_FO_IQR_first
# CRM_SP_GLSZMGLNU.Is_Single_Prosthesis                    Is_Single_Prosthesis
# CRM_SP_GLSZMGLNU.GLSZM_GLNU_first                            GLSZM_GLNU_first
# CRM_SP_LHP25.Is_Single_Prosthesis                        Is_Single_Prosthesis
# CRM_SP_LHP25.Wav_LH_FO_P25_first                          Wav_LH_FO_P25_first
# CRM_SP_GLCMClusterShade.Is_Single_Prosthesis             Is_Single_Prosthesis
# CRM_SP_GLCMClusterShade.GLCM_ClusterShade_first       GLCM_ClusterShade_first
# RM_LLRMS_HHRange.Wav_LL_FO_RMS_first                      Wav_LL_FO_RMS_first
# RM_LLRMS_HHRange.Wav_HH_FO_Range_first                  Wav_HH_FO_Range_first
# RM_LLRMS_HHMedianT.Wav_LL_FO_RMS_first                    Wav_LL_FO_RMS_first
# RM_LLRMS_HHMedianT.Wav_HH_FO_Median_trend              Wav_HH_FO_Median_trend
# RM_LLRMS_LLIQRT.Wav_LL_FO_RMS_first                       Wav_LL_FO_RMS_first
# RM_LLRMS_LLIQRT.Wav_LL_FO_IQR_trend                       Wav_LL_FO_IQR_trend
# RM_LLRMS_HHEnergy.Wav_LL_FO_RMS_first                     Wav_LL_FO_RMS_first
# RM_LLRMS_HHEnergy.Wav_HH_FO_Energy_first               Wav_HH_FO_Energy_first
# RM_LLRMS_LLStd.Wav_LL_FO_RMS_first                        Wav_LL_FO_RMS_first
# RM_LLRMS_LLStd.Wav_LL_FO_Std_first                        Wav_LL_FO_Std_first
# RM_LLRMS_HLIQR.Wav_LL_FO_RMS_first                        Wav_LL_FO_RMS_first
# RM_LLRMS_HLIQR.Wav_HL_FO_IQR_first                        Wav_HL_FO_IQR_first
# RM_LLRMS_GLSZMGLNU.Wav_LL_FO_RMS_first                    Wav_LL_FO_RMS_first
# RM_LLRMS_GLSZMGLNU.GLSZM_GLNU_first                          GLSZM_GLNU_first
# RM_LLRMS_LHP25.Wav_LL_FO_RMS_first                        Wav_LL_FO_RMS_first
# RM_LLRMS_LHP25.Wav_LH_FO_P25_first                        Wav_LH_FO_P25_first
# RM_LLRMS_GLCMClusterShade.Wav_LL_FO_RMS_first             Wav_LL_FO_RMS_first
# RM_LLRMS_GLCMClusterShade.GLCM_ClusterShade_first     GLCM_ClusterShade_first
# RM_HHRange_HHMedianT.Wav_HH_FO_Range_first              Wav_HH_FO_Range_first
# RM_HHRange_HHMedianT.Wav_HH_FO_Median_trend            Wav_HH_FO_Median_trend
# RM_HHRange_LLIQRT.Wav_HH_FO_Range_first                 Wav_HH_FO_Range_first
# RM_HHRange_LLIQRT.Wav_LL_FO_IQR_trend                     Wav_LL_FO_IQR_trend
# RM_HHRange_HHEnergy.Wav_HH_FO_Range_first               Wav_HH_FO_Range_first
# RM_HHRange_HHEnergy.Wav_HH_FO_Energy_first             Wav_HH_FO_Energy_first
# RM_HHRange_LLStd.Wav_HH_FO_Range_first                  Wav_HH_FO_Range_first
# RM_HHRange_LLStd.Wav_LL_FO_Std_first                      Wav_LL_FO_Std_first
# RM_HHRange_HLIQR.Wav_HH_FO_Range_first                  Wav_HH_FO_Range_first
# RM_HHRange_HLIQR.Wav_HL_FO_IQR_first                      Wav_HL_FO_IQR_first
# RM_HHRange_GLSZMGLNU.Wav_HH_FO_Range_first              Wav_HH_FO_Range_first
# RM_HHRange_GLSZMGLNU.GLSZM_GLNU_first                        GLSZM_GLNU_first
# RM_HHRange_LHP25.Wav_HH_FO_Range_first                  Wav_HH_FO_Range_first
# RM_HHRange_LHP25.Wav_LH_FO_P25_first                      Wav_LH_FO_P25_first
# RM_HHRange_GLCMClusterShade.Wav_HH_FO_Range_first       Wav_HH_FO_Range_first
# RM_HHRange_GLCMClusterShade.GLCM_ClusterShade_first   GLCM_ClusterShade_first
# RM_HHMedianT_LLIQRT.Wav_HH_FO_Median_trend             Wav_HH_FO_Median_trend
# RM_HHMedianT_LLIQRT.Wav_LL_FO_IQR_trend                   Wav_LL_FO_IQR_trend
# RM_HHMedianT_HHEnergy.Wav_HH_FO_Median_trend           Wav_HH_FO_Median_trend
# RM_HHMedianT_HHEnergy.Wav_HH_FO_Energy_first           Wav_HH_FO_Energy_first
# RM_HHMedianT_LLStd.Wav_HH_FO_Median_trend              Wav_HH_FO_Median_trend
# RM_HHMedianT_LLStd.Wav_LL_FO_Std_first                    Wav_LL_FO_Std_first
# RM_HHMedianT_HLIQR.Wav_HH_FO_Median_trend              Wav_HH_FO_Median_trend
# RM_HHMedianT_HLIQR.Wav_HL_FO_IQR_first                    Wav_HL_FO_IQR_first
# RM_HHMedianT_GLSZMGLNU.Wav_HH_FO_Median_trend          Wav_HH_FO_Median_trend
# RM_HHMedianT_GLSZMGLNU.GLSZM_GLNU_first                      GLSZM_GLNU_first
# RM_HHMedianT_LHP25.Wav_HH_FO_Median_trend              Wav_HH_FO_Median_trend
# RM_HHMedianT_LHP25.Wav_LH_FO_P25_first                    Wav_LH_FO_P25_first
# RM_HHMedianT_GLCMClusterShade.Wav_HH_FO_Median_trend   Wav_HH_FO_Median_trend
# RM_HHMedianT_GLCMClusterShade.GLCM_ClusterShade_first GLCM_ClusterShade_first
# RM_LLIQRT_HHEnergy.Wav_LL_FO_IQR_trend                    Wav_LL_FO_IQR_trend
# RM_LLIQRT_HHEnergy.Wav_HH_FO_Energy_first              Wav_HH_FO_Energy_first
# RM_LLIQRT_LLStd.Wav_LL_FO_IQR_trend                       Wav_LL_FO_IQR_trend
# RM_LLIQRT_LLStd.Wav_LL_FO_Std_first                       Wav_LL_FO_Std_first
# RM_LLIQRT_HLIQR.Wav_LL_FO_IQR_trend                       Wav_LL_FO_IQR_trend
# RM_LLIQRT_HLIQR.Wav_HL_FO_IQR_first                       Wav_HL_FO_IQR_first
# RM_LLIQRT_GLSZMGLNU.Wav_LL_FO_IQR_trend                   Wav_LL_FO_IQR_trend
# RM_LLIQRT_GLSZMGLNU.GLSZM_GLNU_first                         GLSZM_GLNU_first
# RM_LLIQRT_LHP25.Wav_LL_FO_IQR_trend                       Wav_LL_FO_IQR_trend
# RM_LLIQRT_LHP25.Wav_LH_FO_P25_first                       Wav_LH_FO_P25_first
# RM_LLIQRT_GLCMClusterShade.Wav_LL_FO_IQR_trend            Wav_LL_FO_IQR_trend
# RM_LLIQRT_GLCMClusterShade.GLCM_ClusterShade_first    GLCM_ClusterShade_first
# RM_HHEnergy_LLStd.Wav_HH_FO_Energy_first               Wav_HH_FO_Energy_first
# RM_HHEnergy_LLStd.Wav_LL_FO_Std_first                     Wav_LL_FO_Std_first
# RM_HHEnergy_HLIQR.Wav_HH_FO_Energy_first               Wav_HH_FO_Energy_first
# RM_HHEnergy_HLIQR.Wav_HL_FO_IQR_first                     Wav_HL_FO_IQR_first
# RM_HHEnergy_GLSZMGLNU.Wav_HH_FO_Energy_first           Wav_HH_FO_Energy_first
# RM_HHEnergy_GLSZMGLNU.GLSZM_GLNU_first                       GLSZM_GLNU_first
# RM_HHEnergy_LHP25.Wav_HH_FO_Energy_first               Wav_HH_FO_Energy_first
# RM_HHEnergy_LHP25.Wav_LH_FO_P25_first                     Wav_LH_FO_P25_first
# RM_HHEnergy_GLCMClusterShade.Wav_HH_FO_Energy_first    Wav_HH_FO_Energy_first
# RM_HHEnergy_GLCMClusterShade.GLCM_ClusterShade_first  GLCM_ClusterShade_first
# RM_LLStd_HLIQR.Wav_LL_FO_Std_first                        Wav_LL_FO_Std_first
# RM_LLStd_HLIQR.Wav_HL_FO_IQR_first                        Wav_HL_FO_IQR_first
# RM_LLStd_GLSZMGLNU.Wav_LL_FO_Std_first                    Wav_LL_FO_Std_first
# RM_LLStd_GLSZMGLNU.GLSZM_GLNU_first                          GLSZM_GLNU_first
# RM_LLStd_LHP25.Wav_LL_FO_Std_first                        Wav_LL_FO_Std_first
# RM_LLStd_LHP25.Wav_LH_FO_P25_first                        Wav_LH_FO_P25_first
# RM_LLStd_GLCMClusterShade.Wav_LL_FO_Std_first             Wav_LL_FO_Std_first
# RM_LLStd_GLCMClusterShade.GLCM_ClusterShade_first     GLCM_ClusterShade_first
# RM_HLIQR_GLSZMGLNU.Wav_HL_FO_IQR_first                    Wav_HL_FO_IQR_first
# RM_HLIQR_GLSZMGLNU.GLSZM_GLNU_first                          GLSZM_GLNU_first
# RM_HLIQR_LHP25.Wav_HL_FO_IQR_first                        Wav_HL_FO_IQR_first
# RM_HLIQR_LHP25.Wav_LH_FO_P25_first                        Wav_LH_FO_P25_first
# RM_HLIQR_GLCMClusterShade.Wav_HL_FO_IQR_first             Wav_HL_FO_IQR_first
# RM_HLIQR_GLCMClusterShade.GLCM_ClusterShade_first     GLCM_ClusterShade_first
# RM_GLSZMGLNU_LHP25.GLSZM_GLNU_first                          GLSZM_GLNU_first
# RM_GLSZMGLNU_LHP25.Wav_LH_FO_P25_first                    Wav_LH_FO_P25_first
# RM_GLSZMGLNU_GLCMClusterShade.GLSZM_GLNU_first               GLSZM_GLNU_first
# RM_GLSZMGLNU_GLCMClusterShade.GLCM_ClusterShade_first GLCM_ClusterShade_first
# RM_LHP25_GLCMClusterShade.Wav_LH_FO_P25_first             Wav_LH_FO_P25_first
# RM_LHP25_GLCMClusterShade.GLCM_ClusterShade_first     GLCM_ClusterShade_first
#                                                          HR CI_lo  CI_hi
# CM_Jaw_Depth.Jaw_Code                                 1.438 1.135  1.821
# CM_Jaw_Depth.Insertion_Depth_mm                       0.342 0.210  0.555
# CM_Jaw_SP.Jaw_Code                                    1.351 1.051  1.735
# CM_Jaw_SP.Is_Single_Prosthesis                        1.341 0.903  1.992
# CRM_Jaw_LLRMS.Jaw_Code                                1.274 1.008  1.609
# CRM_Jaw_LLRMS.Wav_LL_FO_RMS_first                     1.719 1.469  2.012
# CRM_Jaw_HHRange.Jaw_Code                              1.558 1.184  2.050
# CRM_Jaw_HHRange.Wav_HH_FO_Range_first                 1.739 1.378  2.195
# CRM_Jaw_HHMedianT.Jaw_Code                            1.470 1.234  1.750
# CRM_Jaw_HHMedianT.Wav_HH_FO_Median_trend              3.993 2.419  6.591
# CRM_Jaw_LLIQRT.Jaw_Code                               1.429 1.104  1.850
# CRM_Jaw_LLIQRT.Wav_LL_FO_IQR_trend                    3.890 1.961  7.717
# CRM_Jaw_HHEnergy.Jaw_Code                             1.242 0.817  1.889
# CRM_Jaw_HHEnergy.Wav_HH_FO_Energy_first               0.272 0.144  0.514
# CRM_Jaw_LLStd.Jaw_Code                                1.585 1.252  2.006
# CRM_Jaw_LLStd.Wav_LL_FO_Std_first                     1.665 1.431  1.937
# CRM_Jaw_HLIQR.Jaw_Code                                1.744 1.272  2.391
# CRM_Jaw_HLIQR.Wav_HL_FO_IQR_first                     1.899 1.218  2.960
# CRM_Jaw_GLSZMGLNU.Jaw_Code                            1.488 1.083  2.044
# CRM_Jaw_GLSZMGLNU.GLSZM_GLNU_first                    1.488 0.966  2.293
# CRM_Jaw_LHP25.Jaw_Code                                1.281 0.860  1.907
# CRM_Jaw_LHP25.Wav_LH_FO_P25_first                     0.371 0.165  0.837
# CRM_Jaw_GLCMClusterShade.Jaw_Code                     1.264 1.124  1.421
# CRM_Jaw_GLCMClusterShade.GLCM_ClusterShade_first      0.669 0.423  1.060
# CM_Depth_SP.Insertion_Depth_mm                        0.383 0.199  0.739
# CM_Depth_SP.Is_Single_Prosthesis                      1.233 0.905  1.678
# CRM_Depth_LLRMS.Insertion_Depth_mm                    0.399 0.217  0.735
# CRM_Depth_LLRMS.Wav_LL_FO_RMS_first                   1.280 0.890  1.840
# CRM_Depth_HHRange.Insertion_Depth_mm                  0.397 0.217  0.726
# CRM_Depth_HHRange.Wav_HH_FO_Range_first               1.316 0.955  1.811
# CRM_Depth_HHMedianT.Insertion_Depth_mm                0.457 0.239  0.874
# CRM_Depth_HHMedianT.Wav_HH_FO_Median_trend            2.593 1.794  3.749
# CRM_Depth_LLIQRT.Insertion_Depth_mm                   0.367 0.214  0.632
# CRM_Depth_LLIQRT.Wav_LL_FO_IQR_trend                  2.724 1.260  5.891
# CRM_Depth_HHEnergy.Insertion_Depth_mm                 0.547 0.333  0.900
# CRM_Depth_HHEnergy.Wav_HH_FO_Energy_first             0.372 0.230  0.600
# CRM_Depth_LLStd.Insertion_Depth_mm                    0.368 0.204  0.664
# CRM_Depth_LLStd.Wav_LL_FO_Std_first                   1.065 0.759  1.495
# CRM_Depth_HLIQR.Insertion_Depth_mm                    0.388 0.233  0.647
# CRM_Depth_HLIQR.Wav_HL_FO_IQR_first                   1.408 1.031  1.923
# CRM_Depth_GLSZMGLNU.Insertion_Depth_mm                0.361 0.222  0.588
# CRM_Depth_GLSZMGLNU.GLSZM_GLNU_first                  1.598 1.331  1.920
# CRM_Depth_LHP25.Insertion_Depth_mm                    0.498 0.295  0.842
# CRM_Depth_LHP25.Wav_LH_FO_P25_first                   0.458 0.253  0.831
# CRM_Depth_GLCMClusterShade.Insertion_Depth_mm         0.399 0.227  0.701
# CRM_Depth_GLCMClusterShade.GLCM_ClusterShade_first    0.732 0.489  1.097
# CRM_SP_LLRMS.Is_Single_Prosthesis                     1.300 0.906  1.865
# CRM_SP_LLRMS.Wav_LL_FO_RMS_first                      1.711 1.405  2.084
# CRM_SP_HHRange.Is_Single_Prosthesis                   1.440 1.214  1.708
# CRM_SP_HHRange.Wav_HH_FO_Range_first                  1.639 1.358  1.978
# CRM_SP_HHMedianT.Is_Single_Prosthesis                 1.323 0.922  1.898
# CRM_SP_HHMedianT.Wav_HH_FO_Median_trend               3.771 2.257  6.302
# CRM_SP_LLIQRT.Is_Single_Prosthesis                    1.387 1.079  1.782
# CRM_SP_LLIQRT.Wav_LL_FO_IQR_trend                     3.293 1.365  7.944
# CRM_SP_HHEnergy.Is_Single_Prosthesis                  1.538 1.112  2.128
# CRM_SP_HHEnergy.Wav_HH_FO_Energy_first                0.242 0.109  0.535
# CRM_SP_LLStd.Is_Single_Prosthesis                     1.309 0.907  1.888
# CRM_SP_LLStd.Wav_LL_FO_Std_first                      1.356 0.959  1.916
# CRM_SP_HLIQR.Is_Single_Prosthesis                     1.739 1.498  2.019
# CRM_SP_HLIQR.Wav_HL_FO_IQR_first                      1.985 1.452  2.714
# CRM_SP_GLSZMGLNU.Is_Single_Prosthesis                 1.683 1.448  1.956
# CRM_SP_GLSZMGLNU.GLSZM_GLNU_first                     1.784 1.150  2.768
# CRM_SP_LHP25.Is_Single_Prosthesis                     1.487 1.283  1.723
# CRM_SP_LHP25.Wav_LH_FO_P25_first                      0.334 0.149  0.752
# CRM_SP_GLCMClusterShade.Is_Single_Prosthesis          1.278 0.893  1.830
# CRM_SP_GLCMClusterShade.GLCM_ClusterShade_first       0.688 0.357  1.325
# RM_LLRMS_HHRange.Wav_LL_FO_RMS_first                  1.613 1.377  1.888
# RM_LLRMS_HHRange.Wav_HH_FO_Range_first                1.395 1.197  1.625
# RM_LLRMS_HHMedianT.Wav_LL_FO_RMS_first                1.494 1.147  1.947
# RM_LLRMS_HHMedianT.Wav_HH_FO_Median_trend             3.183 2.273  4.457
# RM_LLRMS_LLIQRT.Wav_LL_FO_RMS_first                   1.959 1.603  2.394
# RM_LLRMS_LLIQRT.Wav_LL_FO_IQR_trend                   5.154 2.532 10.491
# RM_LLRMS_HHEnergy.Wav_LL_FO_RMS_first                 1.029 0.668  1.586
# RM_LLRMS_HHEnergy.Wav_HH_FO_Energy_first              0.265 0.119  0.589
# RM_LLRMS_LLStd.Wav_LL_FO_RMS_first                    1.670 1.185  2.354
# RM_LLRMS_LLStd.Wav_LL_FO_Std_first                    1.145 0.776  1.688
# RM_LLRMS_HLIQR.Wav_LL_FO_RMS_first                    1.681 1.373  2.057
# RM_LLRMS_HLIQR.Wav_HL_FO_IQR_first                    1.352 1.018  1.795
# RM_LLRMS_GLSZMGLNU.Wav_LL_FO_RMS_first                1.802 1.336  2.431
# RM_LLRMS_GLSZMGLNU.GLSZM_GLNU_first                   1.486 0.890  2.482
# RM_LLRMS_LHP25.Wav_LL_FO_RMS_first                    1.062 0.671  1.679
# RM_LLRMS_LHP25.Wav_LH_FO_P25_first                    0.369 0.140  0.970
# RM_LLRMS_GLCMClusterShade.Wav_LL_FO_RMS_first         1.554 1.242  1.943
# RM_LLRMS_GLCMClusterShade.GLCM_ClusterShade_first     0.733 0.442  1.218
# RM_HHRange_HHMedianT.Wav_HH_FO_Range_first            1.369 1.128  1.662
# RM_HHRange_HHMedianT.Wav_HH_FO_Median_trend           3.485 2.244  5.414
# RM_HHRange_LLIQRT.Wav_HH_FO_Range_first               1.594 1.329  1.911
# RM_HHRange_LLIQRT.Wav_LL_FO_IQR_trend                 3.607 2.020  6.441
# RM_HHRange_HHEnergy.Wav_HH_FO_Range_first             1.007 0.560  1.811
# RM_HHRange_HHEnergy.Wav_HH_FO_Energy_first            0.262 0.109  0.627
# RM_HHRange_LLStd.Wav_HH_FO_Range_first                1.476 1.190  1.832
# RM_HHRange_LLStd.Wav_LL_FO_Std_first                  1.358 1.044  1.766
# RM_HHRange_HLIQR.Wav_HH_FO_Range_first                1.446 1.112  1.881
# RM_HHRange_HLIQR.Wav_HL_FO_IQR_first                  1.333 0.930  1.911
# RM_HHRange_GLSZMGLNU.Wav_HH_FO_Range_first            1.556 1.358  1.783
# RM_HHRange_GLSZMGLNU.GLSZM_GLNU_first                 1.467 0.988  2.178
# RM_HHRange_LHP25.Wav_HH_FO_Range_first                0.976 0.598  1.595
# RM_HHRange_LHP25.Wav_LH_FO_P25_first                  0.351 0.127  0.965
# RM_HHRange_GLCMClusterShade.Wav_HH_FO_Range_first     1.468 1.279  1.685
# RM_HHRange_GLCMClusterShade.GLCM_ClusterShade_first   0.676 0.412  1.108
# RM_HHMedianT_LLIQRT.Wav_HH_FO_Median_trend            4.837 2.247 10.411
# RM_HHMedianT_LLIQRT.Wav_LL_FO_IQR_trend               2.134 1.572  2.896
# RM_HHMedianT_HHEnergy.Wav_HH_FO_Median_trend          2.915 2.319  3.663
# RM_HHMedianT_HHEnergy.Wav_HH_FO_Energy_first          0.301 0.152  0.596
# RM_HHMedianT_LLStd.Wav_HH_FO_Median_trend             3.466 2.406  4.993
# RM_HHMedianT_LLStd.Wav_LL_FO_Std_first                1.342 1.110  1.622
# RM_HHMedianT_HLIQR.Wav_HH_FO_Median_trend             3.796 2.423  5.946
# RM_HHMedianT_HLIQR.Wav_HL_FO_IQR_first                1.022 0.654  1.599
# RM_HHMedianT_GLSZMGLNU.Wav_HH_FO_Median_trend         3.581 2.307  5.558
# RM_HHMedianT_GLSZMGLNU.GLSZM_GLNU_first               1.421 1.017  1.987
# RM_HHMedianT_LHP25.Wav_HH_FO_Median_trend             2.810 1.839  4.294
# RM_HHMedianT_LHP25.Wav_LH_FO_P25_first                0.419 0.178  0.988
# RM_HHMedianT_GLCMClusterShade.Wav_HH_FO_Median_trend  3.791 2.529  5.683
# RM_HHMedianT_GLCMClusterShade.GLCM_ClusterShade_first 0.545 0.328  0.906
# RM_LLIQRT_HHEnergy.Wav_LL_FO_IQR_trend                4.867 2.180 10.864
# RM_LLIQRT_HHEnergy.Wav_HH_FO_Energy_first             0.244 0.131  0.453
# RM_LLIQRT_LLStd.Wav_LL_FO_IQR_trend                   4.954 2.474  9.919
# RM_LLIQRT_LLStd.Wav_LL_FO_Std_first                   1.673 1.343  2.084
# RM_LLIQRT_HLIQR.Wav_LL_FO_IQR_trend                   4.191 2.331  7.537
# RM_LLIQRT_HLIQR.Wav_HL_FO_IQR_first                   1.664 1.231  2.247
# RM_LLIQRT_GLSZMGLNU.Wav_LL_FO_IQR_trend               3.601 1.788  7.253
# RM_LLIQRT_GLSZMGLNU.GLSZM_GLNU_first                  1.398 1.040  1.880
# RM_LLIQRT_LHP25.Wav_LL_FO_IQR_trend                   3.061 1.603  5.844
# RM_LLIQRT_LHP25.Wav_LH_FO_P25_first                   0.366 0.162  0.828
# RM_LLIQRT_GLCMClusterShade.Wav_LL_FO_IQR_trend        3.569 1.874  6.799
# RM_LLIQRT_GLCMClusterShade.GLCM_ClusterShade_first    0.643 0.399  1.038
# RM_HHEnergy_LLStd.Wav_HH_FO_Energy_first              0.270 0.141  0.518
# RM_HHEnergy_LLStd.Wav_LL_FO_Std_first                 1.242 0.809  1.908
# RM_HHEnergy_HLIQR.Wav_HH_FO_Energy_first              0.278 0.133  0.577
# RM_HHEnergy_HLIQR.Wav_HL_FO_IQR_first                 1.148 0.755  1.746
# RM_HHEnergy_GLSZMGLNU.Wav_HH_FO_Energy_first          0.280 0.149  0.529
# RM_HHEnergy_GLSZMGLNU.GLSZM_GLNU_first                1.146 0.756  1.738
# RM_HHEnergy_LHP25.Wav_HH_FO_Energy_first              0.354 0.150  0.834
# RM_HHEnergy_LHP25.Wav_LH_FO_P25_first                 0.678 0.352  1.305
# RM_HHEnergy_GLCMClusterShade.Wav_HH_FO_Energy_first   0.272 0.140  0.527
# RM_HHEnergy_GLCMClusterShade.GLCM_ClusterShade_first  0.697 0.449  1.085
# RM_LLStd_HLIQR.Wav_LL_FO_Std_first                    1.460 1.193  1.787
# RM_LLStd_HLIQR.Wav_HL_FO_IQR_first                    1.490 1.204  1.844
# RM_LLStd_GLSZMGLNU.Wav_LL_FO_Std_first                2.033 1.307  3.160
# RM_LLStd_GLSZMGLNU.GLSZM_GLNU_first                   2.081 1.286  3.367
# RM_LLStd_LHP25.Wav_LL_FO_Std_first                    1.287 0.873  1.899
# RM_LLStd_LHP25.Wav_LH_FO_P25_first                    0.378 0.185  0.769
# RM_LLStd_GLCMClusterShade.Wav_LL_FO_Std_first         1.478 1.154  1.894
# RM_LLStd_GLCMClusterShade.GLCM_ClusterShade_first     0.656 0.409  1.054
# RM_HLIQR_GLSZMGLNU.Wav_HL_FO_IQR_first                1.390 1.043  1.852
# RM_HLIQR_GLSZMGLNU.GLSZM_GLNU_first                   1.343 0.907  1.989
# RM_HLIQR_LHP25.Wav_HL_FO_IQR_first                    0.752 0.371  1.526
# RM_HLIQR_LHP25.Wav_LH_FO_P25_first                    0.290 0.095  0.882
# RM_HLIQR_GLCMClusterShade.Wav_HL_FO_IQR_first         1.559 1.213  2.005
# RM_HLIQR_GLCMClusterShade.GLCM_ClusterShade_first     0.618 0.361  1.058
# RM_GLSZMGLNU_LHP25.GLSZM_GLNU_first                   0.731 0.471  1.133
# RM_GLSZMGLNU_LHP25.Wav_LH_FO_P25_first                0.278 0.129  0.599
# RM_GLSZMGLNU_GLCMClusterShade.GLSZM_GLNU_first        1.408 1.063  1.863
# RM_GLSZMGLNU_GLCMClusterShade.GLCM_ClusterShade_first 0.649 0.408  1.031
# RM_LHP25_GLCMClusterShade.Wav_LH_FO_P25_first         0.382 0.181  0.810
# RM_LHP25_GLCMClusterShade.GLCM_ClusterShade_first     0.763 0.452  1.288
#                                                       p_value Sig C_index
# CM_Jaw_Depth.Jaw_Code                                  0.0026  **   0.767
# CM_Jaw_Depth.Insertion_Depth_mm                        0.0000 ***   0.767
# CM_Jaw_SP.Jaw_Code                                     0.0187   *   0.668
# CM_Jaw_SP.Is_Single_Prosthesis                         0.1455  ns   0.668
# CRM_Jaw_LLRMS.Jaw_Code                                 0.0424   *   0.704
# CRM_Jaw_LLRMS.Wav_LL_FO_RMS_first                      0.0000 ***   0.704
# CRM_Jaw_HHRange.Jaw_Code                               0.0015  **   0.700
# CRM_Jaw_HHRange.Wav_HH_FO_Range_first                  0.0000 ***   0.700
# CRM_Jaw_HHMedianT.Jaw_Code                             0.0000 ***   0.736
# CRM_Jaw_HHMedianT.Wav_HH_FO_Median_trend               0.0000 ***   0.736
# CRM_Jaw_LLIQRT.Jaw_Code                                0.0067  **   0.590
# CRM_Jaw_LLIQRT.Wav_LL_FO_IQR_trend                     0.0001 ***   0.590
# CRM_Jaw_HHEnergy.Jaw_Code                              0.3110  ns   0.782
# CRM_Jaw_HHEnergy.Wav_HH_FO_Energy_first                0.0001 ***   0.782
# CRM_Jaw_LLStd.Jaw_Code                                 0.0001 ***   0.711
# CRM_Jaw_LLStd.Wav_LL_FO_Std_first                      0.0000 ***   0.711
# CRM_Jaw_HLIQR.Jaw_Code                                 0.0005 ***   0.704
# CRM_Jaw_HLIQR.Wav_HL_FO_IQR_first                      0.0046  **   0.704
# CRM_Jaw_GLSZMGLNU.Jaw_Code                             0.0143   *   0.665
# CRM_Jaw_GLSZMGLNU.GLSZM_GLNU_first                     0.0714   †   0.665
# CRM_Jaw_LHP25.Jaw_Code                                 0.2225  ns   0.798
# CRM_Jaw_LHP25.Wav_LH_FO_P25_first                      0.0168   *   0.798
# CRM_Jaw_GLCMClusterShade.Jaw_Code                      0.0001 ***   0.723
# CRM_Jaw_GLCMClusterShade.GLCM_ClusterShade_first       0.0867   †   0.723
# CM_Depth_SP.Insertion_Depth_mm                         0.0042  **   0.757
# CM_Depth_SP.Is_Single_Prosthesis                       0.1845  ns   0.757
# CRM_Depth_LLRMS.Insertion_Depth_mm                     0.0032  **   0.773
# CRM_Depth_LLRMS.Wav_LL_FO_RMS_first                    0.1826  ns   0.773
# CRM_Depth_HHRange.Insertion_Depth_mm                   0.0027  **   0.794
# CRM_Depth_HHRange.Wav_HH_FO_Range_first                0.0928   †   0.794
# CRM_Depth_HHMedianT.Insertion_Depth_mm                 0.0178   *   0.828
# CRM_Depth_HHMedianT.Wav_HH_FO_Median_trend             0.0000 ***   0.828
# CRM_Depth_LLIQRT.Insertion_Depth_mm                    0.0003 ***   0.750
# CRM_Depth_LLIQRT.Wav_LL_FO_IQR_trend                   0.0109   *   0.750
# CRM_Depth_HHEnergy.Insertion_Depth_mm                  0.0176   *   0.800
# CRM_Depth_HHEnergy.Wav_HH_FO_Energy_first              0.0001 ***   0.800
# CRM_Depth_LLStd.Insertion_Depth_mm                     0.0009 ***   0.777
# CRM_Depth_LLStd.Wav_LL_FO_Std_first                    0.7142  ns   0.777
# CRM_Depth_HLIQR.Insertion_Depth_mm                     0.0003 ***   0.793
# CRM_Depth_HLIQR.Wav_HL_FO_IQR_first                    0.0313   *   0.793
# CRM_Depth_GLSZMGLNU.Insertion_Depth_mm                 0.0000 ***   0.782
# CRM_Depth_GLSZMGLNU.GLSZM_GLNU_first                   0.0000 ***   0.782
# CRM_Depth_LHP25.Insertion_Depth_mm                     0.0092  **   0.828
# CRM_Depth_LHP25.Wav_LH_FO_P25_first                    0.0102   *   0.828
# CRM_Depth_GLCMClusterShade.Insertion_Depth_mm          0.0014  **   0.764
# CRM_Depth_GLCMClusterShade.GLCM_ClusterShade_first     0.1312  ns   0.764
# CRM_SP_LLRMS.Is_Single_Prosthesis                      0.1550  ns   0.729
# CRM_SP_LLRMS.Wav_LL_FO_RMS_first                       0.0000 ***   0.729
# CRM_SP_HHRange.Is_Single_Prosthesis                    0.0000 ***   0.695
# CRM_SP_HHRange.Wav_HH_FO_Range_first                   0.0000 ***   0.695
# CRM_SP_HHMedianT.Is_Single_Prosthesis                  0.1282  ns   0.683
# CRM_SP_HHMedianT.Wav_HH_FO_Median_trend                0.0000 ***   0.683
# CRM_SP_LLIQRT.Is_Single_Prosthesis                     0.0108   *   0.605
# CRM_SP_LLIQRT.Wav_LL_FO_IQR_trend                      0.0080  **   0.605
# CRM_SP_HHEnergy.Is_Single_Prosthesis                   0.0092  **   0.805
# CRM_SP_HHEnergy.Wav_HH_FO_Energy_first                 0.0005 ***   0.805
# CRM_SP_LLStd.Is_Single_Prosthesis                      0.1498  ns   0.709
# CRM_SP_LLStd.Wav_LL_FO_Std_first                       0.0848   †   0.709
# CRM_SP_HLIQR.Is_Single_Prosthesis                      0.0000 ***   0.707
# CRM_SP_HLIQR.Wav_HL_FO_IQR_first                       0.0000 ***   0.707
# CRM_SP_GLSZMGLNU.Is_Single_Prosthesis                  0.0000 ***   0.695
# CRM_SP_GLSZMGLNU.GLSZM_GLNU_first                      0.0097  **   0.695
# CRM_SP_LHP25.Is_Single_Prosthesis                      0.0000 ***   0.803
# CRM_SP_LHP25.Wav_LH_FO_P25_first                       0.0081  **   0.803
# CRM_SP_GLCMClusterShade.Is_Single_Prosthesis           0.1797  ns   0.771
# CRM_SP_GLCMClusterShade.GLCM_ClusterShade_first        0.2632  ns   0.771
# RM_LLRMS_HHRange.Wav_LL_FO_RMS_first                   0.0000 ***   0.727
# RM_LLRMS_HHRange.Wav_HH_FO_Range_first                 0.0000 ***   0.727
# RM_LLRMS_HHMedianT.Wav_LL_FO_RMS_first                 0.0029  **   0.729
# RM_LLRMS_HHMedianT.Wav_HH_FO_Median_trend              0.0000 ***   0.729
# RM_LLRMS_LLIQRT.Wav_LL_FO_RMS_first                    0.0000 ***   0.674
# RM_LLRMS_LLIQRT.Wav_LL_FO_IQR_trend                    0.0000 ***   0.674
# RM_LLRMS_HHEnergy.Wav_LL_FO_RMS_first                  0.8954  ns   0.762
# RM_LLRMS_HHEnergy.Wav_HH_FO_Energy_first               0.0011  **   0.762
# RM_LLRMS_LLStd.Wav_LL_FO_RMS_first                     0.0034  **   0.704
# RM_LLRMS_LLStd.Wav_LL_FO_Std_first                     0.4955  ns   0.704
# RM_LLRMS_HLIQR.Wav_LL_FO_RMS_first                     0.0000 ***   0.722
# RM_LLRMS_HLIQR.Wav_HL_FO_IQR_first                     0.0373   *   0.722
# RM_LLRMS_GLSZMGLNU.Wav_LL_FO_RMS_first                 0.0001 ***   0.727
# RM_LLRMS_GLSZMGLNU.GLSZM_GLNU_first                    0.1302  ns   0.727
# RM_LLRMS_LHP25.Wav_LL_FO_RMS_first                     0.7987  ns   0.803
# RM_LLRMS_LHP25.Wav_LH_FO_P25_first                     0.0432   *   0.803
# RM_LLRMS_GLCMClusterShade.Wav_LL_FO_RMS_first          0.0001 ***   0.699
# RM_LLRMS_GLCMClusterShade.GLCM_ClusterShade_first      0.2309  ns   0.699
# RM_HHRange_HHMedianT.Wav_HH_FO_Range_first             0.0015  **   0.748
# RM_HHRange_HHMedianT.Wav_HH_FO_Median_trend            0.0000 ***   0.748
# RM_HHRange_LLIQRT.Wav_HH_FO_Range_first                0.0000 ***   0.647
# RM_HHRange_LLIQRT.Wav_LL_FO_IQR_trend                  0.0000 ***   0.647
# RM_HHRange_HHEnergy.Wav_HH_FO_Range_first              0.9803  ns   0.764
# RM_HHRange_HHEnergy.Wav_HH_FO_Energy_first             0.0026  **   0.764
# RM_HHRange_LLStd.Wav_HH_FO_Range_first                 0.0004 ***   0.723
# RM_HHRange_LLStd.Wav_LL_FO_Std_first                   0.0226   *   0.723
# RM_HHRange_HLIQR.Wav_HH_FO_Range_first                 0.0060  **   0.716
# RM_HHRange_HLIQR.Wav_HL_FO_IQR_first                   0.1181  ns   0.716
# RM_HHRange_GLSZMGLNU.Wav_HH_FO_Range_first             0.0000 ***   0.699
# RM_HHRange_GLSZMGLNU.GLSZM_GLNU_first                  0.0572   †   0.699
# RM_HHRange_LHP25.Wav_HH_FO_Range_first                 0.9241  ns   0.800
# RM_HHRange_LHP25.Wav_LH_FO_P25_first                   0.0425   *   0.800
# RM_HHRange_GLCMClusterShade.Wav_HH_FO_Range_first      0.0000 ***   0.746
# RM_HHRange_GLCMClusterShade.GLCM_ClusterShade_first    0.1205  ns   0.746
# RM_HHMedianT_LLIQRT.Wav_HH_FO_Median_trend             0.0001 ***   0.688
# RM_HHMedianT_LLIQRT.Wav_LL_FO_IQR_trend                0.0000 ***   0.688
# RM_HHMedianT_HHEnergy.Wav_HH_FO_Median_trend           0.0000 ***   0.821
# RM_HHMedianT_HHEnergy.Wav_HH_FO_Energy_first           0.0006 ***   0.821
# RM_HHMedianT_LLStd.Wav_HH_FO_Median_trend              0.0000 ***   0.695
# RM_HHMedianT_LLStd.Wav_LL_FO_Std_first                 0.0024  **   0.695
# RM_HHMedianT_HLIQR.Wav_HH_FO_Median_trend              0.0000 ***   0.656
# RM_HHMedianT_HLIQR.Wav_HL_FO_IQR_first                 0.9226  ns   0.656
# RM_HHMedianT_GLSZMGLNU.Wav_HH_FO_Median_trend          0.0000 ***   0.707
# RM_HHMedianT_GLSZMGLNU.GLSZM_GLNU_first                0.0397   *   0.707
# RM_HHMedianT_LHP25.Wav_HH_FO_Median_trend              0.0000 ***   0.844
# RM_HHMedianT_LHP25.Wav_LH_FO_P25_first                 0.0468   *   0.844
# RM_HHMedianT_GLCMClusterShade.Wav_HH_FO_Median_trend   0.0000 ***   0.777
# RM_HHMedianT_GLCMClusterShade.GLCM_ClusterShade_first  0.0192   *   0.777
# RM_LLIQRT_HHEnergy.Wav_LL_FO_IQR_trend                 0.0001 ***   0.787
# RM_LLIQRT_HHEnergy.Wav_HH_FO_Energy_first              0.0000 ***   0.787
# RM_LLIQRT_LLStd.Wav_LL_FO_IQR_trend                    0.0000 ***   0.676
# RM_LLIQRT_LLStd.Wav_LL_FO_Std_first                    0.0000 ***   0.676
# RM_LLIQRT_HLIQR.Wav_LL_FO_IQR_trend                    0.0000 ***   0.629
# RM_LLIQRT_HLIQR.Wav_HL_FO_IQR_first                    0.0009 ***   0.629
# RM_LLIQRT_GLSZMGLNU.Wav_LL_FO_IQR_trend                0.0003 ***   0.610
# RM_LLIQRT_GLSZMGLNU.GLSZM_GLNU_first                   0.0266   *   0.610
# RM_LLIQRT_LHP25.Wav_LL_FO_IQR_trend                    0.0007 ***   0.770
# RM_LLIQRT_LHP25.Wav_LH_FO_P25_first                    0.0157   *   0.770
# RM_LLIQRT_GLCMClusterShade.Wav_LL_FO_IQR_trend         0.0001 ***   0.679
# RM_LLIQRT_GLCMClusterShade.GLCM_ClusterShade_first     0.0707   †   0.679
# RM_HHEnergy_LLStd.Wav_HH_FO_Energy_first               0.0001 ***   0.778
# RM_HHEnergy_LLStd.Wav_LL_FO_Std_first                  0.3220  ns   0.778
# RM_HHEnergy_HLIQR.Wav_HH_FO_Energy_first               0.0006 ***   0.778
# RM_HHEnergy_HLIQR.Wav_HL_FO_IQR_first                  0.5186  ns   0.778
# RM_HHEnergy_GLSZMGLNU.Wav_HH_FO_Energy_first           0.0001 ***   0.770
# RM_HHEnergy_GLSZMGLNU.GLSZM_GLNU_first                 0.5197  ns   0.770
# RM_HHEnergy_LHP25.Wav_HH_FO_Energy_first               0.0176   *   0.787
# RM_HHEnergy_LHP25.Wav_LH_FO_P25_first                  0.2444  ns   0.787
# RM_HHEnergy_GLCMClusterShade.Wav_HH_FO_Energy_first    0.0001 ***   0.784
# RM_HHEnergy_GLCMClusterShade.GLCM_ClusterShade_first   0.1097  ns   0.784
# RM_LLStd_HLIQR.Wav_LL_FO_Std_first                     0.0002 ***   0.716
# RM_LLStd_HLIQR.Wav_HL_FO_IQR_first                     0.0002 ***   0.716
# RM_LLStd_GLSZMGLNU.Wav_LL_FO_Std_first                 0.0016  **   0.752
# RM_LLStd_GLSZMGLNU.GLSZM_GLNU_first                    0.0028  **   0.752
# RM_LLStd_LHP25.Wav_LL_FO_Std_first                     0.2031  ns   0.810
# RM_LLStd_LHP25.Wav_LH_FO_P25_first                     0.0073  **   0.810
# RM_LLStd_GLCMClusterShade.Wav_LL_FO_Std_first          0.0020  **   0.766
# RM_LLStd_GLCMClusterShade.GLCM_ClusterShade_first      0.0817   †   0.766
# RM_HLIQR_GLSZMGLNU.Wav_HL_FO_IQR_first                 0.0245   *   0.670
# RM_HLIQR_GLSZMGLNU.GLSZM_GLNU_first                    0.1408  ns   0.670
# RM_HLIQR_LHP25.Wav_HL_FO_IQR_first                     0.4301  ns   0.780
# RM_HLIQR_LHP25.Wav_LH_FO_P25_first                     0.0292   *   0.780
# RM_HLIQR_GLCMClusterShade.Wav_HL_FO_IQR_first          0.0005 ***   0.727
# RM_HLIQR_GLCMClusterShade.GLCM_ClusterShade_first      0.0792   †   0.727
# RM_GLSZMGLNU_LHP25.GLSZM_GLNU_first                    0.1612  ns   0.805
# RM_GLSZMGLNU_LHP25.Wav_LH_FO_P25_first                 0.0011  **   0.805
# RM_GLSZMGLNU_GLCMClusterShade.GLSZM_GLNU_first         0.0169   *   0.715
# RM_GLSZMGLNU_GLCMClusterShade.GLCM_ClusterShade_first  0.0673   †   0.715
# RM_LHP25_GLCMClusterShade.Wav_LH_FO_P25_first          0.0121   *   0.814
# RM_LHP25_GLCMClusterShade.GLCM_ClusterShade_first      0.3111  ns   0.814
#                                                       All_p05
# CM_Jaw_Depth.Jaw_Code                                     YES
# CM_Jaw_Depth.Insertion_Depth_mm                           YES
# CM_Jaw_SP.Jaw_Code                                         NO
# CM_Jaw_SP.Is_Single_Prosthesis                             NO
# CRM_Jaw_LLRMS.Jaw_Code                                    YES
# CRM_Jaw_LLRMS.Wav_LL_FO_RMS_first                         YES
# CRM_Jaw_HHRange.Jaw_Code                                  YES
# CRM_Jaw_HHRange.Wav_HH_FO_Range_first                     YES
# CRM_Jaw_HHMedianT.Jaw_Code                                YES
# CRM_Jaw_HHMedianT.Wav_HH_FO_Median_trend                  YES
# CRM_Jaw_LLIQRT.Jaw_Code                                   YES
# CRM_Jaw_LLIQRT.Wav_LL_FO_IQR_trend                        YES
# CRM_Jaw_HHEnergy.Jaw_Code                                  NO
# CRM_Jaw_HHEnergy.Wav_HH_FO_Energy_first                    NO
# CRM_Jaw_LLStd.Jaw_Code                                    YES
# CRM_Jaw_LLStd.Wav_LL_FO_Std_first                         YES
# CRM_Jaw_HLIQR.Jaw_Code                                    YES
# CRM_Jaw_HLIQR.Wav_HL_FO_IQR_first                         YES
# CRM_Jaw_GLSZMGLNU.Jaw_Code                                 NO
# CRM_Jaw_GLSZMGLNU.GLSZM_GLNU_first                         NO
# CRM_Jaw_LHP25.Jaw_Code                                     NO
# CRM_Jaw_LHP25.Wav_LH_FO_P25_first                          NO
# CRM_Jaw_GLCMClusterShade.Jaw_Code                          NO
# CRM_Jaw_GLCMClusterShade.GLCM_ClusterShade_first           NO
# CM_Depth_SP.Insertion_Depth_mm                             NO
# CM_Depth_SP.Is_Single_Prosthesis                           NO
# CRM_Depth_LLRMS.Insertion_Depth_mm                         NO
# CRM_Depth_LLRMS.Wav_LL_FO_RMS_first                        NO
# CRM_Depth_HHRange.Insertion_Depth_mm                       NO
# CRM_Depth_HHRange.Wav_HH_FO_Range_first                    NO
# CRM_Depth_HHMedianT.Insertion_Depth_mm                    YES
# CRM_Depth_HHMedianT.Wav_HH_FO_Median_trend                YES
# CRM_Depth_LLIQRT.Insertion_Depth_mm                       YES
# CRM_Depth_LLIQRT.Wav_LL_FO_IQR_trend                      YES
# CRM_Depth_HHEnergy.Insertion_Depth_mm                     YES
# CRM_Depth_HHEnergy.Wav_HH_FO_Energy_first                 YES
# CRM_Depth_LLStd.Insertion_Depth_mm                         NO
# CRM_Depth_LLStd.Wav_LL_FO_Std_first                        NO
# CRM_Depth_HLIQR.Insertion_Depth_mm                        YES
# CRM_Depth_HLIQR.Wav_HL_FO_IQR_first                       YES
# CRM_Depth_GLSZMGLNU.Insertion_Depth_mm                    YES
# CRM_Depth_GLSZMGLNU.GLSZM_GLNU_first                      YES
# CRM_Depth_LHP25.Insertion_Depth_mm                        YES
# CRM_Depth_LHP25.Wav_LH_FO_P25_first                       YES
# CRM_Depth_GLCMClusterShade.Insertion_Depth_mm              NO
# CRM_Depth_GLCMClusterShade.GLCM_ClusterShade_first         NO
# CRM_SP_LLRMS.Is_Single_Prosthesis                          NO
# CRM_SP_LLRMS.Wav_LL_FO_RMS_first                           NO
# CRM_SP_HHRange.Is_Single_Prosthesis                       YES
# CRM_SP_HHRange.Wav_HH_FO_Range_first                      YES
# CRM_SP_HHMedianT.Is_Single_Prosthesis                      NO
# CRM_SP_HHMedianT.Wav_HH_FO_Median_trend                    NO
# CRM_SP_LLIQRT.Is_Single_Prosthesis                        YES
# CRM_SP_LLIQRT.Wav_LL_FO_IQR_trend                         YES
# CRM_SP_HHEnergy.Is_Single_Prosthesis                      YES
# CRM_SP_HHEnergy.Wav_HH_FO_Energy_first                    YES
# CRM_SP_LLStd.Is_Single_Prosthesis                          NO
# CRM_SP_LLStd.Wav_LL_FO_Std_first                           NO
# CRM_SP_HLIQR.Is_Single_Prosthesis                         YES
# CRM_SP_HLIQR.Wav_HL_FO_IQR_first                          YES
# CRM_SP_GLSZMGLNU.Is_Single_Prosthesis                     YES
# CRM_SP_GLSZMGLNU.GLSZM_GLNU_first                         YES
# CRM_SP_LHP25.Is_Single_Prosthesis                         YES
# CRM_SP_LHP25.Wav_LH_FO_P25_first                          YES
# CRM_SP_GLCMClusterShade.Is_Single_Prosthesis               NO
# CRM_SP_GLCMClusterShade.GLCM_ClusterShade_first            NO
# RM_LLRMS_HHRange.Wav_LL_FO_RMS_first                      YES
# RM_LLRMS_HHRange.Wav_HH_FO_Range_first                    YES
# RM_LLRMS_HHMedianT.Wav_LL_FO_RMS_first                    YES
# RM_LLRMS_HHMedianT.Wav_HH_FO_Median_trend                 YES
# RM_LLRMS_LLIQRT.Wav_LL_FO_RMS_first                       YES
# RM_LLRMS_LLIQRT.Wav_LL_FO_IQR_trend                       YES
# RM_LLRMS_HHEnergy.Wav_LL_FO_RMS_first                      NO
# RM_LLRMS_HHEnergy.Wav_HH_FO_Energy_first                   NO
# RM_LLRMS_LLStd.Wav_LL_FO_RMS_first                         NO
# RM_LLRMS_LLStd.Wav_LL_FO_Std_first                         NO
# RM_LLRMS_HLIQR.Wav_LL_FO_RMS_first                        YES
# RM_LLRMS_HLIQR.Wav_HL_FO_IQR_first                        YES
# RM_LLRMS_GLSZMGLNU.Wav_LL_FO_RMS_first                     NO
# RM_LLRMS_GLSZMGLNU.GLSZM_GLNU_first                        NO
# RM_LLRMS_LHP25.Wav_LL_FO_RMS_first                         NO
# RM_LLRMS_LHP25.Wav_LH_FO_P25_first                         NO
# RM_LLRMS_GLCMClusterShade.Wav_LL_FO_RMS_first              NO
# RM_LLRMS_GLCMClusterShade.GLCM_ClusterShade_first          NO
# RM_HHRange_HHMedianT.Wav_HH_FO_Range_first                YES
# RM_HHRange_HHMedianT.Wav_HH_FO_Median_trend               YES
# RM_HHRange_LLIQRT.Wav_HH_FO_Range_first                   YES
# RM_HHRange_LLIQRT.Wav_LL_FO_IQR_trend                     YES
# RM_HHRange_HHEnergy.Wav_HH_FO_Range_first                  NO
# RM_HHRange_HHEnergy.Wav_HH_FO_Energy_first                 NO
# RM_HHRange_LLStd.Wav_HH_FO_Range_first                    YES
# RM_HHRange_LLStd.Wav_LL_FO_Std_first                      YES
# RM_HHRange_HLIQR.Wav_HH_FO_Range_first                     NO
# RM_HHRange_HLIQR.Wav_HL_FO_IQR_first                       NO
# RM_HHRange_GLSZMGLNU.Wav_HH_FO_Range_first                 NO
# RM_HHRange_GLSZMGLNU.GLSZM_GLNU_first                      NO
# RM_HHRange_LHP25.Wav_HH_FO_Range_first                     NO
# RM_HHRange_LHP25.Wav_LH_FO_P25_first                       NO
# RM_HHRange_GLCMClusterShade.Wav_HH_FO_Range_first          NO
# RM_HHRange_GLCMClusterShade.GLCM_ClusterShade_first        NO
# RM_HHMedianT_LLIQRT.Wav_HH_FO_Median_trend                YES
# RM_HHMedianT_LLIQRT.Wav_LL_FO_IQR_trend                   YES
# RM_HHMedianT_HHEnergy.Wav_HH_FO_Median_trend              YES
# RM_HHMedianT_HHEnergy.Wav_HH_FO_Energy_first              YES
# RM_HHMedianT_LLStd.Wav_HH_FO_Median_trend                 YES
# RM_HHMedianT_LLStd.Wav_LL_FO_Std_first                    YES
# RM_HHMedianT_HLIQR.Wav_HH_FO_Median_trend                  NO
# RM_HHMedianT_HLIQR.Wav_HL_FO_IQR_first                     NO
# RM_HHMedianT_GLSZMGLNU.Wav_HH_FO_Median_trend             YES
# RM_HHMedianT_GLSZMGLNU.GLSZM_GLNU_first                   YES
# RM_HHMedianT_LHP25.Wav_HH_FO_Median_trend                 YES
# RM_HHMedianT_LHP25.Wav_LH_FO_P25_first                    YES
# RM_HHMedianT_GLCMClusterShade.Wav_HH_FO_Median_trend      YES
# RM_HHMedianT_GLCMClusterShade.GLCM_ClusterShade_first     YES
# RM_LLIQRT_HHEnergy.Wav_LL_FO_IQR_trend                    YES
# RM_LLIQRT_HHEnergy.Wav_HH_FO_Energy_first                 YES
# RM_LLIQRT_LLStd.Wav_LL_FO_IQR_trend                       YES
# RM_LLIQRT_LLStd.Wav_LL_FO_Std_first                       YES
# RM_LLIQRT_HLIQR.Wav_LL_FO_IQR_trend                       YES
# RM_LLIQRT_HLIQR.Wav_HL_FO_IQR_first                       YES
# RM_LLIQRT_GLSZMGLNU.Wav_LL_FO_IQR_trend                   YES
# RM_LLIQRT_GLSZMGLNU.GLSZM_GLNU_first                      YES
# RM_LLIQRT_LHP25.Wav_LL_FO_IQR_trend                       YES
# RM_LLIQRT_LHP25.Wav_LH_FO_P25_first                       YES
# RM_LLIQRT_GLCMClusterShade.Wav_LL_FO_IQR_trend             NO
# RM_LLIQRT_GLCMClusterShade.GLCM_ClusterShade_first         NO
# RM_HHEnergy_LLStd.Wav_HH_FO_Energy_first                   NO
# RM_HHEnergy_LLStd.Wav_LL_FO_Std_first                      NO
# RM_HHEnergy_HLIQR.Wav_HH_FO_Energy_first                   NO
# RM_HHEnergy_HLIQR.Wav_HL_FO_IQR_first                      NO
# RM_HHEnergy_GLSZMGLNU.Wav_HH_FO_Energy_first               NO
# RM_HHEnergy_GLSZMGLNU.GLSZM_GLNU_first                     NO
# RM_HHEnergy_LHP25.Wav_HH_FO_Energy_first                   NO
# RM_HHEnergy_LHP25.Wav_LH_FO_P25_first                      NO
# RM_HHEnergy_GLCMClusterShade.Wav_HH_FO_Energy_first        NO
# RM_HHEnergy_GLCMClusterShade.GLCM_ClusterShade_first       NO
# RM_LLStd_HLIQR.Wav_LL_FO_Std_first                        YES
# RM_LLStd_HLIQR.Wav_HL_FO_IQR_first                        YES
# RM_LLStd_GLSZMGLNU.Wav_LL_FO_Std_first                    YES
# RM_LLStd_GLSZMGLNU.GLSZM_GLNU_first                       YES
# RM_LLStd_LHP25.Wav_LL_FO_Std_first                         NO
# RM_LLStd_LHP25.Wav_LH_FO_P25_first                         NO
# RM_LLStd_GLCMClusterShade.Wav_LL_FO_Std_first              NO
# RM_LLStd_GLCMClusterShade.GLCM_ClusterShade_first          NO
# RM_HLIQR_GLSZMGLNU.Wav_HL_FO_IQR_first                     NO
# RM_HLIQR_GLSZMGLNU.GLSZM_GLNU_first                        NO
# RM_HLIQR_LHP25.Wav_HL_FO_IQR_first                         NO
# RM_HLIQR_LHP25.Wav_LH_FO_P25_first                         NO
# RM_HLIQR_GLCMClusterShade.Wav_HL_FO_IQR_first              NO
# RM_HLIQR_GLCMClusterShade.GLCM_ClusterShade_first          NO
# RM_GLSZMGLNU_LHP25.GLSZM_GLNU_first                        NO
# RM_GLSZMGLNU_LHP25.Wav_LH_FO_P25_first                     NO
# RM_GLSZMGLNU_GLCMClusterShade.GLSZM_GLNU_first             NO
# RM_GLSZMGLNU_GLCMClusterShade.GLCM_ClusterShade_first      NO
# RM_LHP25_GLCMClusterShade.Wav_LH_FO_P25_first              NO
# RM_LHP25_GLCMClusterShade.GLCM_ClusterShade_first          NO
#
# ===== Multi-Cox: model summary =====
# # A tibble: 78 × 4
#    Model                     C_index All_p05 Features
#    <chr>                       <dbl> <chr>   <chr>
#  1 RM_HHMedianT_LHP25          0.844 YES     Wav_HH_FO_Median_trend + Wav_LH_FO…
#  2 CRM_Depth_HHMedianT         0.828 YES     Insertion_Depth_mm + Wav_HH_FO_Med…
#  3 CRM_Depth_LHP25             0.828 YES     Insertion_Depth_mm + Wav_LH_FO_P25…
#  4 RM_HHMedianT_HHEnergy       0.821 YES     Wav_HH_FO_Median_trend + Wav_HH_FO…
#  5 RM_LHP25_GLCMClusterShade   0.814 NO      Wav_LH_FO_P25_first + GLCM_Cluster…
#  6 RM_LLStd_LHP25              0.81  NO      Wav_LL_FO_Std_first + Wav_LH_FO_P2…
#  7 CRM_SP_HHEnergy             0.805 YES     Is_Single_Prosthesis + Wav_HH_FO_E…
#  8 RM_GLSZMGLNU_LHP25          0.805 NO      GLSZM_GLNU_first + Wav_LH_FO_P25_f…
#  9 CRM_SP_LHP25                0.803 YES     Is_Single_Prosthesis + Wav_LH_FO_P…
# 10 RM_LLRMS_LHP25              0.803 NO      Wav_LL_FO_RMS_first + Wav_LH_FO_P2…
# # ℹ 68 more rows
#
#   Hint: All_p05=YES means all variables significant (p<0.05)
#
# ★ Best model (All_p05=YES, highest C-index): RM_HHMedianT_LHP25
#   C-index = 0.844
#                            HR CI_lo  CI_hi p_value
# Wav_HH_FO_Median_trend 2.8100 1.839 4.2936  0.0000
# Wav_LH_FO_P25_first    0.4193 0.178 0.9877  0.0468
# Saved: /content/Results_R/0M_Cell6_MultiCox.xlsx

# %%
# ==============================================================================
# [CELL 7] Statistical Defense: Correlation, VIF, Cox PH, EPV, ESS  (AUTO)
# ==============================================================================
cat("\n[CELL 7] Statistical Validations (auto from MultiCox YES)...\n")

# ── Auto-receive MultiCox YES ──
mcox <- read_xlsx(sprintf("%s/%dM_Cell6_MultiCox.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS),
                  sheet = "MultiCox_Summary")
yes_models      <- mcox$Model[mcox$All_p05 == "YES"]
feat_sets_cox   <- feat_sets[names(feat_sets) %in% yes_models]   # reuse Cell6's feat_sets(28)
surviving_models<- names(feat_sets_cox)
cat(sprintf("  VIF/PH validation targets: %d (MultiCox YES)\n", length(feat_sets_cox)))

# ── Correlation plot — auto-receive pruning-passed candidates ──
cox_candidates <- read_xlsx(sprintf("%s/%dM_Cell5_Pruning.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS),
                            sheet = "Final_Cox_Candidates")$Feature
top_vars <- cox_candidates[cox_candidates %in% names(df_imp)]


# auto-generate display labels (raw -> manuscript-style short label)
make_label <- function(f){

  # first record whether it's a trend feature
  is_trend <- grepl("_trend$", f)

  # strip suffix
  f <- sub("_first$", "", f)
  f <- sub("_trend$", "", f)

  # raw feature names → manuscript-style labels
  f <- gsub("Wav_LL_FO_", "WavLL-", f)
  f <- gsub("Wav_LH_FO_", "WavLH-", f)
  f <- gsub("Wav_HL_FO_", "WavHL-", f)
  f <- gsub("Wav_HH_FO_", "WavHH-", f)

  f <- gsub("GLCM_", "GLCM-", f)
  f <- gsub("GLRLM_", "GLRLM-", f)
  f <- gsub("GLSZM_", "GLSZM-", f)
  f <- gsub("NGTDM_", "NGTDM-", f)
  f <- gsub("FO_", "FO-", f)

  # manuscript style: prepend Δ
  if (is_trend) {
    f <- paste0("\u0394", f)   # \u0394 = Greek capital delta, Δ
  }

  return(f)
}

top_vars_labeled <- sapply(top_vars, make_label)

if(length(top_vars) > 1){
  corr_mat_top <- cor(df_imp[, top_vars], use="complete.obs", method="spearman")
  rownames(corr_mat_top) <- top_vars_labeled; colnames(corr_mat_top) <- top_vars_labeled
  tiff_name <- sprintf("%s/FigureS1_%dM_Correlation_Plot.tiff", SAVE_DIR, SENS_CUTOFF_MONTHS)
  tiff(filename=tiff_name, width=10, height=10, units="in", res=300, compression="lzw")
  par(family="sans")
  corrplot::corrplot(corr_mat_top, method="ellipse", type="lower", order="original",
    tl.col="black", tl.srt=45, tl.cex=1.2, addCoef.col="black", number.cex=1.0,
    col=RColorBrewer::brewer.pal(n=8, name="RdYlBu"),
    title="Feature Correlation (Spearman)", mar=c(0,0,3.5,0), cex.main=2.5)
  dev.off()
  cat(sprintf("  Correlation plot saved: %s\n", tiff_name))
}

# ── [EPV/VIF/PH loop below is unchanged; uses the auto-received surviving_models] ──
df_stat_defense <- data.frame(); df_ph_detail <- data.frame(); df_vif_detail <- data.frame()
for (m_name in surviving_models) {
  cols <- feat_sets_cox[[m_name]]; cols <- cols[cols %in% names(df_imp)]
  if(length(cols)==0) next
  n_events <- sum(df_imp$PI_MRONJ==1); n_vars <- length(cols); epv_val <- n_events/n_vars
  max_vif <- 1.000
  if(n_vars>1){
    vif_model <- tryCatch(glm(as.formula(paste("PI_MRONJ ~",paste(cols,collapse="+"))),
                              data=df_imp, family=binomial), error=function(e) NULL)
    if(!is.null(vif_model)){
      vif_vals <- car::vif(vif_model); max_vif <- max(as.numeric(vif_vals), na.rm=TRUE)
      df_vif_detail <- rbind(df_vif_detail, data.frame(Model=m_name, Variable=names(vif_vals),
                                                       VIF_Value=round(as.numeric(vif_vals),3)))
    }
  }
  df_cox_temp <- df_imp
  for(c in cols) if(is.numeric(df_cox_temp[[c]])) df_cox_temp[[c]] <- as.numeric(scale(df_cox_temp[[c]]))
  cox_fit <- tryCatch(coxph(as.formula(paste("Surv(Duration, PI_MRONJ) ~",paste(cols,collapse=" + "))),
                            data=df_cox_temp), error=function(e) NULL)
  global_ph_p <- NA
  if(!is.null(cox_fit)){
    ph_test <- tryCatch(cox.zph(cox_fit), error=function(e) NULL)
    if(!is.null(ph_test)){ pt <- as.data.frame(ph_test$table); global_ph_p <- pt["GLOBAL","p"]
      pt$Variable <- rownames(pt); pt$Model <- m_name; df_ph_detail <- rbind(df_ph_detail, pt) }
  }
  status_flag <- "PASS"
  if(!is.na(max_vif) && max_vif>=5) status_flag <- "FAIL (VIF High)"
  if(!is.na(global_ph_p) && global_ph_p<0.05) status_flag <- "FAIL (PH Violated)"
  c_index_val <- mcox$C_index[mcox$Model==m_name][1]
  df_stat_defense <- rbind(df_stat_defense, data.frame(Model=m_name, C_index=c_index_val,
    Num_Predictors=n_vars, EPV=round(epv_val,2), Max_VIF=round(max_vif,3),
    Global_PH_pvalue=round(global_ph_p,4), Status=status_flag, stringsAsFactors=FALSE))
}
if(!all(is.na(df_stat_defense$C_index))) df_stat_defense <- df_stat_defense[order(-df_stat_defense$C_index),]

# ── ESS + save (unchanged) ──
n_total <- nrow(df_imp); n_clusters <- length(unique(df_imp$Patient_ID)); m <- n_total/n_clusters
rho <- if(exists("gee_final") && !is.null(gee_final)) summary(gee_final)$corr[1,1] else 0.5
df_ess <- data.frame(Total_N=n_total, Num_Patients=n_clusters, Avg_m=round(m,2),
                     Rho_Correlation=round(rho,3), ESS=round(n_total/(1+(m-1)*rho),2))
writexl::write_xlsx(list("Defense_Summary"=df_stat_defense, "VIF_Detail"=df_vif_detail,
  "PH_Detail"=df_ph_detail, "ESS_Check"=df_ess),
  path=sprintf("%s/%dM_Cell7_Defense.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS))
cat("\n  Saved Cell7 defense.\n")
# Out:
# [CELL 7] Statistical Validations (auto from MultiCox YES)...
#   VIF/PH validation targets: 39 (MultiCox YES)
#   Correlation plot saved: /content/Results_R/FigureS1_0M_Correlation_Plot.tiff
#
#   Saved Cell7 defense.

# %% [markdown]
# ## 4. Offset sensitivity validation (Cells 8–10 only)
# The model pool is frozen at 0M (read from the 0M files inside each function). Only bootstrap / LOGO-CV / calibration re-run per offset.

# %%
# ==============================================================================
# Validation functions (wrap Cell 8 / 8b / 9). Logic verbatim from the original;
# only: (i) df_imp rebuilt per offset, (ii) Cell 9 plot blocks removed (data kept).
# feat_sets is read from the FROZEN 0-month selection inside each function.
# ==============================================================================

run_bootstrap <- function(months) {
  SENS_CUTOFF_MONTHS <- months
  raw_m  <- apply_sensitivity_cutoff(raw_full, months)
  df_imp <- build_df_imp(raw_m, clin_cols, radio_all)

# ==============================================================================
# ★ [CELL 8] Exhaustive Bootstrap Internal Validation & Multi-Category Export
# - retains high-speed computation (fast_auc, XGBoost hist)
# - forces the full model set to be assigned (blocks stale variable names)
# - saves category-split Excel sheets
# ==============================================================================

# check required packages are loaded
if(!require(pROC)) install.packages("pROC")
if(!require(writexl)) install.packages("writexl")
if(!require(dplyr)) install.packages("dplyr")
if(!require(xgboost)) install.packages("xgboost")
library(pROC)
library(writexl)
library(dplyr)
library(xgboost)

# ── Bootstrap/LOGO feat_sets — AUTO ──────────────────────────
# single: pruning-passed candidates (clinical sig + radiomics) / 2-feature: Cell7 PASS
cat("\n[CELL 8] Auto feat_sets (singles + Cell7 PASS)...\n")

# 1) single candidates: 3 clinical sig + 5 cross-family-passing radiomics
unicox   <- read_xlsx(sprintf("%s/%dM_Cell4_UniCox.xlsx", SAVE_DIR, 0), sheet="UniCox_All")
clin_sig <- unicox$Feature[unicox$Feature %in% clin_cols & unicox$p_value < 0.05]
cox_cand <- read_xlsx(sprintf("%s/%dM_Cell5_Pruning.xlsx", SAVE_DIR, 0),
                      sheet="Final_Cox_Candidates")$Feature

abbrev <- function(f){
  lab <- sub("_first$","",f); lab <- sub("_trend$","T",lab)
  lab <- gsub("Insertion_Depth_mm","Depth",lab)
  lab <- gsub("Is_Single_Prosthesis","SP",lab); lab <- gsub("Jaw_Code","Jaw",lab)
  lab <- gsub("Wav_","",lab); lab <- gsub("_FO_","",lab); lab <- gsub("_","",lab)
  if(lab=="") lab <- f
  lab
}

# ★ category prefix: clinical-only = CM_, radiomics-only = SRM_
single_sets <- list()
for (f in clin_sig) {                       # clinical-only -> CM_
  single_sets[[paste0("CM_", abbrev(f))]] <- f
}
for (f in cox_cand) {                        # radiomics-only -> SRM_
  single_sets[[paste0("SRM_", abbrev(f))]] <- f
}
cat(sprintf("  single: %d (CM %d + SRM %d)\n",
            length(single_sets), length(clin_sig), length(cox_cand)))
print(names(single_sets))



# 2-feature: Cell7 PASS (based on 0M; original feature set retained)

defense <- read_xlsx(
  sprintf("%s/%dM_Cell7_Defense.xlsx", SAVE_DIR, 0),
  sheet="Defense_Summary"
)

pass_models <- defense$Model[defense$Status == "PASS"]

two_sets <- feat_sets_cox[
  names(feat_sets_cox) %in% pass_models
]



# final pool
feat_sets <- c(single_sets, two_sets)
cat(sprintf("  Bootstrap pool: %d (single %d + 2-feature %d)\n",
            length(feat_sets), length(single_sets), length(two_sets)))

            cat("two_sets:", length(two_sets), "\n")

# ── 1. High-speed AUC function (eliminates the pROC bottleneck) ──
fast_auc <- function(y, prob) {
  n1 <- sum(y == 1)
  n0 <- sum(y == 0)
  if (n1 == 0 || n0 == 0) return(NA)
  r <- rank(prob)
  s1 <- sum(r[y == 1])
  return((s1 - n1 * (n1 + 1) / 2) / (n1 * n0))
}

# ── 2. Single train/predict wrapper (TRIPOD-compliant + high-speed) ──────────
fit_and_predict <- function(train_df, test_boot, test_orig) {
  # 1) LR (Logistic Regression)
  fit_lr <- suppressWarnings(glm(y ~ ., data=train_df, family=binomial(), control = list(maxit = 25)))
  p_lr_boot <- predict(fit_lr, newdata=test_boot, type="response")
  p_lr_orig <- predict(fit_lr, newdata=test_orig, type="response")

  # 2) XGBoost
  train_x <- as.matrix(train_df %>% select(-y))
  train_y <- as.numeric(as.character(train_df$y))
  test_boot_x <- as.matrix(test_boot %>% select(-y))
  test_orig_x <- as.matrix(test_orig %>% select(-y))

  dtr <- xgb.DMatrix(data = train_x, label = train_y)
  dte_boot <- xgb.DMatrix(data = test_boot_x)
  dte_orig <- xgb.DMatrix(data = test_orig_x)

  xgb_params <- list(
    objective        = "binary:logistic",
    eval_metric      = "auc",
    max_depth        = 2,
    eta              = 0.05,
    tree_method      = "hist",
    nthread          = 2
  )

  suppressWarnings({
    fit_xgb <- xgb.train(params = xgb_params, data = dtr, nrounds = 50, verbose = 0)
    p_xgb_boot <- predict(fit_xgb, newdata = dte_boot)
    p_xgb_orig <- predict(fit_xgb, newdata = dte_orig)
  })

  return(list(
    LR_boot = p_lr_boot, LR_orig = p_lr_orig,
    XGB_boot = p_xgb_boot, XGB_orig = p_xgb_orig
  ))
}

# ── 3. Multi-algorithm bootstrap function ───────────────────────
algo_list <- c("LR", "XGB")

optimism_boot_all <- function(X, y, pts, B = 1000, seed = SEED) {
  set.seed(seed)
  df_full <- data.frame(y = factor(y, levels=c(0,1)), X)
  y_num_full <- as.numeric(as.character(df_full$y))

  # apparent predictions from a model trained on the full data
  preds_app <- fit_and_predict(df_full, df_full, df_full)
  auc_app <- list()
  for(algo in algo_list) {
    auc_app[[algo]] <- fast_auc(y_num_full, preds_app[[paste0(algo, "_boot")]])
  }

  opt_list <- setNames(lapply(algo_list, function(x) numeric(B)), algo_list)
  unique_pts <- unique(pts)

  # B bootstrap iterations
  for (i in 1:B) {
    boot_pts <- sample(unique_pts, replace = TRUE)
    boot_idx <- unlist(lapply(boot_pts, function(p) which(pts == p)))
    df_boot <- df_full[boot_idx, ]
    y_num_boot <- as.numeric(as.character(df_boot$y))

    tryCatch({
      preds <- fit_and_predict(df_boot, df_boot, df_full)
      for(algo in algo_list) {
        auc_b_b <- fast_auc(y_num_boot, preds[[paste0(algo, "_boot")]])
        auc_b_o <- fast_auc(y_num_full, preds[[paste0(algo, "_orig")]])
        opt_list[[algo]][i] <- auc_b_b - auc_b_o
      }
    }, error = function(e) {})
  }

  res <- list()
  for(algo in algo_list) {
    mean_opt <- mean(opt_list[[algo]], na.rm = TRUE)
    auc_adj <- auc_app[[algo]] - mean_opt
    ci_lo <- auc_app[[algo]] - quantile(opt_list[[algo]], 0.975, na.rm=TRUE)
    ci_hi <- auc_app[[algo]] - quantile(opt_list[[algo]], 0.025, na.rm=TRUE)

    roc_obj <- roc(df_full$y, preds_app[[paste0(algo, "_boot")]], quiet=TRUE, direction="<")
    coords <- coords(roc_obj, "best", best.method="youden", ret=c("sensitivity","specificity"))

    res[[algo]] <- list(
      auc_app = round(auc_app[[algo]], 3),
      optimism = round(mean_opt, 3),
      auc_adj = round(auc_adj, 3),
      ci_lo    = round(ci_lo, 3),
      ci_hi    = round(ci_hi, 3),
      sens = round(coords$sensitivity[1], 3),
      spec = round(coords$specificity[1], 3),
      probs_app = preds_app[[paste0(algo, "_boot")]]
    )
  }
  return(res)
}

# ── 4. Main execution loop ───────────────────────────────────
boot_res <- data.frame()

# target variable and identifier mapping
y_all   <- as.numeric(as.character(df_imp$PI_MRONJ))
pts_all <- df_imp$Patient_ID

# initialize the master data frame that accumulates predicted probabilities for all models
df_roc_data <- data.frame(
  Patient_ID = df_imp$Patient_ID,
  Implant_ID = df_imp$Implant_ID,
  Event      = y_all,
  stringsAsFactors = FALSE
)

cat("\n🚀 Running 2-Algorithm Bootstrapping (LR, XGB - B=1000)...\n")
cat(sprintf("   %-22s %-4s %7s %7s %7s %5s %5s\n", "Feature Set", "Algo", "App.AUC", "Optim", "Adj.AUC", "Sens", "Spec"))
cat("   ", strrep("-", 68), "\n")

for (fname in names(feat_sets)) {
  fcols <- feat_sets[[fname]]
  fcols <- fcols[fcols %in% names(df_imp)]
  if (length(fcols) == 0) next

  Xmat <- as.matrix(df_imp[, fcols, drop=FALSE])

  # run bootstrap
  res_all <- optimism_boot_all(Xmat, y_all, pts_all, B=1000)

  for(algo in algo_list) {
    r <- res_all[[algo]]

    mark <- if(r$auc_adj >= 0.80) "★★" else if(r$auc_adj >= 0.75) "★ " else "  "
    cat(sprintf("   %s %-20s %-4s %.3f   %.3f   %.3f   %.2f  %.2f\n",
                mark, fname, algo, r$auc_app, r$optimism, r$auc_adj, r$sens, r$spec))

    boot_res <- rbind(boot_res, data.frame(
      Feature_Set  = fname,
      Algorithm    = algo,
      AUC_Apparent = r$auc_app,
      Optimism     = r$optimism,
      AUC_Adjusted = r$auc_adj,
      CI_lo_95     = r$ci_lo,
      CI_hi_95     = r$ci_hi,
      Sensitivity  = r$sens,
      Specificity  = r$spec,
      Features     = paste(fcols, collapse=" + "),
      stringsAsFactors = FALSE
    ))

    # save explicitly under the new name
    col_name <- paste0(fname, "_", algo)
    df_roc_data[[col_name]] <- r$probs_app
  }
}

# ── 5. Split by category and save to Excel ───────────────────────
boot_res <- boot_res %>% arrange(desc(AUC_Adjusted))

df_cm_res  <- boot_res[grepl("^CM_",  boot_res$Feature_Set), ]
df_crm_res <- boot_res[grepl("^CRM_", boot_res$Feature_Set), ]
df_rm_res  <- boot_res[grepl("^RM_",  boot_res$Feature_Set), ]
df_srm_res <- boot_res[grepl("^SRM_", boot_res$Feature_Set), ]

cat("\n===== Top 10 Models (Overall Adjusted AUC) =====\n")
print(head(boot_res, 10))

save_name_c8 <- sprintf("%s/%dM_Cell8_2Algo_Boot_Categorized.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS)
write_xlsx(
  list(
    "All_Results"   = boot_res,
    "CM_Results"    = df_cm_res,
    "CRM_Results"   = df_crm_res,
    "RM_Results"    = df_rm_res,
    "SRM_Results"   = df_srm_res,
    "ROC_Plot_Data" = df_roc_data
  ),
  path = save_name_c8
)
cat(sprintf("\n✅ [Success] Data completely saved to: %s\n", save_name_c8))
}

run_logo <- function(months) {
  SENS_CUTOFF_MONTHS <- months
  raw_m  <- apply_sensitivity_cutoff(raw_full, months)
  df_imp <- build_df_imp(raw_m, clin_cols, radio_all)

# ╔══════════════════════════════════════════════════════════════╗
# ║  CELL 9 — Leave-One-Group-Out Cross-Validation (LOGO-CV)   ║
# ║  Algorithms: LR (Linear Baseline), XGBoost (Non-linear Ace)  ║
# ║  Input : df_imp (implant-level summary data)                 ║
# ║  Output: predicted probabilities (ROC Data) for all models, saved by category║
# ╚══════════════════════════════════════════════════════════════╝

cat("\n[CELL 9] LOGO-CV (Leave-One-Patient-Out) for LR & XGB...\n")
cat(sprintf("   N=%d | MRONJ=%d | Control=%d | Patients=%d\n",
            nrow(df_imp), sum(df_imp$PI_MRONJ),
            sum(df_imp$PI_MRONJ==0),
            length(unique(df_imp$Patient_ID))))

# load required packages
suppressPackageStartupMessages({
  library(pROC)
  library(caret)
  library(writexl)
  library(dplyr)
  library(xgboost)
})

y_all   <- df_imp$PI_MRONJ
pts_all <- df_imp$Patient_ID

# ══════════════════════════════════════════════════════════════
# [1] feature sets (100% identical to Cell 8_a; the full PH-validated model set)
# ══════════════════════════════════════════════════════════════
# ── Bootstrap/LOGO feat_sets — AUTO ──────────────────────────
# single: pruning-passed candidates (clinical sig + radiomics) / 2-feature: Cell7 PASS
cat("\n[CELL 8] Auto feat_sets (singles + Cell7 PASS)...\n")

# 1) single candidates: 3 clinical sig + 5 cross-family-passing radiomics
unicox   <- read_xlsx(sprintf("%s/%dM_Cell4_UniCox.xlsx", SAVE_DIR, 0), sheet="UniCox_All")
clin_sig <- unicox$Feature[unicox$Feature %in% clin_cols & unicox$p_value < 0.05]
cox_cand <- read_xlsx(sprintf("%s/%dM_Cell5_Pruning.xlsx", SAVE_DIR, 0),
                      sheet="Final_Cox_Candidates")$Feature

abbrev <- function(f){
  lab <- sub("_first$","",f); lab <- sub("_trend$","T",lab)
  lab <- gsub("Insertion_Depth_mm","Depth",lab)
  lab <- gsub("Is_Single_Prosthesis","SP",lab); lab <- gsub("Jaw_Code","Jaw",lab)
  lab <- gsub("Wav_","",lab); lab <- gsub("_FO_","",lab); lab <- gsub("_","",lab)
  if(lab=="") lab <- f
  lab
}

# ★ category prefix: clinical-only = CM_, radiomics-only = SRM_
single_sets <- list()
for (f in clin_sig) {                       # clinical-only -> CM_
  single_sets[[paste0("CM_", abbrev(f))]] <- f
}
for (f in cox_cand) {                        # radiomics-only -> SRM_
  single_sets[[paste0("SRM_", abbrev(f))]] <- f
}
cat(sprintf("  single: %d (CM %d + SRM %d)\n",
            length(single_sets), length(clin_sig), length(cox_cand)))
print(names(single_sets))

# 2-feature: Cell7 PASS (based on 0M; original feature set retained)

defense <- read_xlsx(
  sprintf("%s/%dM_Cell7_Defense.xlsx", SAVE_DIR, 0),
  sheet="Defense_Summary"
)

pass_models <- defense$Model[defense$Status == "PASS"]

two_sets <- feat_sets_cox[
  names(feat_sets_cox) %in% pass_models
]

# final pool
feat_sets <- c(single_sets, two_sets)
cat(sprintf("  Bootstrap pool: %d (single %d + 2-feature %d)\n",
            length(feat_sets), length(single_sets), length(two_sets)))

            cat("two_sets:", length(two_sets), "\n")

# ══════════════════════════════════════════════════════════════
# [2] LOGO-CV core computation function
# ══════════════════════════════════════════════════════════════

algo_list <- c("LR", "XGB")

run_logocv_core <- function(X_full, y_full, pts_full) {
  unique_pts <- unique(pts_full)
  n_samples <- length(y_full)

  preds_out <- list(
    LR  = rep(NA_real_, n_samples),
    XGB = rep(NA_real_, n_samples)
  )

  # patient-level cross-validation loop
  for (pt in unique_pts) {
    te_idx <- which(pts_full == pt)
    tr_idx <- which(pts_full != pt)

    X_tr <- X_full[tr_idx, , drop=FALSE]
    y_tr <- y_full[tr_idx]
    X_te <- X_full[te_idx, , drop=FALSE]

    # ── 1. LR train & predict ──
    df_tr_lr <- data.frame(y = factor(y_tr, levels=c(0,1)), X_tr)
    df_te_lr <- data.frame(X_te)

    tryCatch({
      fit_lr <- suppressWarnings(glm(y ~ ., data=df_tr_lr, family=binomial(), control = list(maxit = 25)))
      preds_out$LR[te_idx] <- predict(fit_lr, newdata=df_te_lr, type="response")
    }, error = function(e) {
      preds_out$LR[te_idx] <<- mean(y_tr)
    })

    # ── 2. XGBoost train & predict ──
    dtr <- xgb.DMatrix(data = as.matrix(X_tr), label = as.numeric(as.character(y_tr)))
    dte <- xgb.DMatrix(data = as.matrix(X_te))

    xgb_params <- list(
      objective   = "binary:logistic",
      eval_metric = "auc",
      max_depth   = 2,
      eta         = 0.05,
      tree_method = "hist",
      nthread     = 2
    )

    tryCatch({
      fit_xgb <- suppressWarnings(xgb.train(params = xgb_params, data = dtr, nrounds = 50, verbose = 0))
      preds_out$XGB[te_idx] <- predict(fit_xgb, newdata = dte)
    }, error = function(e) {
      preds_out$XGB[te_idx] <<- mean(y_tr)
    })
  }

  return(preds_out)
}

# ══════════════════════════════════════════════════════════════
# [3] Main execution loop
# ══════════════════════════════════════════════════════════════
cv_res_df <- data.frame()

# 🚨 initialize the master data frame that stores predicted probabilities for all models
df_cv_roc_data <- data.frame(
  Patient_ID = df_imp$Patient_ID,
  Implant_ID = df_imp$Implant_ID,
  Event      = y_all,
  stringsAsFactors = FALSE
)

cat("\n 🚀 Running LOGO-CV for ALL Models...\n")
cat(sprintf("   %-22s %-4s %7s %7s %7s %5s %5s\n", "Feature Set", "Algo", "CV.AUC", "CI.Lo", "CI.Hi", "Sens", "Spec"))
cat("   ", strrep("-", 68), "\n")

for (fname in names(feat_sets)) {
  fcols <- feat_sets[[fname]]
  fcols <- fcols[fcols %in% names(df_imp)]
  if (length(fcols) == 0) next

  Xmat <- as.matrix(df_imp[, fcols, drop=FALSE])

  # run LOGO-CV predictions (returns out-of-fold probabilities for every sample)
  cv_preds <- run_logocv_core(Xmat, y_all, pts_all)

  for(algo in algo_list) {
    probs <- cv_preds[[algo]]

    # compute evaluation metrics (pROC)
    roc_obj <- suppressMessages(roc(y_all, probs, quiet=TRUE, direction="<"))
    auc_val <- as.numeric(auc(roc_obj))
    ci_vals <- as.numeric(ci.auc(roc_obj, method="delong"))
    coords  <- coords(roc_obj, "best", best.method="youden", ret=c("sensitivity","specificity"))

    # console output (all models shown)
    mark <- if(auc_val >= 0.80) "★★" else if(auc_val >= 0.75) "★ " else "  "
    cat(sprintf("   %s %-20s %-4s %.3f   %.3f   %.3f   %.2f  %.2f\n",
                mark, fname, algo, auc_val, ci_vals[1], ci_vals[3], coords$sensitivity[1], coords$specificity[1]))

    cv_res_df <- rbind(cv_res_df, data.frame(
      Feature_Set  = fname,
      Algorithm    = algo,
      CV_AUC       = round(auc_val, 3),
      CI_lo_95     = round(ci_vals[1], 3),
      CI_hi_95     = round(ci_vals[3], 3),
      Sensitivity  = round(coords$sensitivity[1], 3),
      Specificity  = round(coords$specificity[1], 3),
      Features     = paste(fcols, collapse=" + "),
      stringsAsFactors = FALSE
    ))

    # 🚨 hardcoded restriction fully lifted: accumulate predicted probabilities for every model into the ROC data
    col_name <- paste0(fname, "_", algo)
    df_cv_roc_data[[col_name]] <- probs
  }
}

# ══════════════════════════════════════════════════════════════
# [4] Split by category and save to Excel
# ══════════════════════════════════════════════════════════════
# 1) sort all results in descending order
cv_res_df <- cv_res_df %>% arrange(desc(CV_AUC))

# 2) auto-split into category sheets based on model-name prefix
df_cm_res  <- cv_res_df[grepl("^CM_",  cv_res_df$Feature_Set), ]
df_crm_res <- cv_res_df[grepl("^CRM_", cv_res_df$Feature_Set), ]
df_rm_res  <- cv_res_df[grepl("^RM_",  cv_res_df$Feature_Set), ]
df_srm_res <- cv_res_df[grepl("^SRM_", cv_res_df$Feature_Set), ]

cat("\n===== LOGO-CV Top 10 Models (Overall CV AUC) =====\n")
print(head(cv_res_df, 10))

# 3) export multi-sheet Excel
save_name_cv <- sprintf("%s/%dM_Cell9_LOGO_CV_Categorized.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS)
write_xlsx(
  list(
    "All_Results"        = cv_res_df,
    "CM_Results"         = df_cm_res,
    "CRM_Results"        = df_crm_res,
    "RM_Results"         = df_rm_res,
    "SRM_Results"        = df_srm_res,
    "CV_ROC_Plot_Data"   = df_cv_roc_data
  ),
  path = save_name_cv
)
cat(sprintf("\n✅ [Success] All category-specific LOGO-CV results and complete ROC data saved to:\n➡️ %s\n", save_name_cv))
}

run_calibration <- function(months) {
  SENS_CUTOFF_MONTHS <- months

# ==============================================================================
# [CELL 10] Clinical Defense: Calibration, DCA, and HL Test (TRIPOD Compliance)
# - Input: loads the _Categorized.xlsx file output by Cell 8 directly (runs independently)
# - Computation: outputs Calibration metrics & HL test for all models to Excel
# - Output: calibration metrics (AUC/Brier/slope/HL) + Probabilities to xlsx (no plots)
# ==============================================================================
cat("\n[CELL 10] Running Clinical Utility Validations...\n")

suppressPackageStartupMessages({
  library(pROC)
  library(ResourceSelection)
  library(rms)
  library(dcurves)
  library(ggplot2)
  library(writexl)
  library(readxl)
})

# --- [prerequisite] specify the path where files are saved ---
if(!exists("SAVE_DIR")) SAVE_DIR <- "/content/Results_R"
if(!exists("SENS_CUTOFF_MONTHS")) SENS_CUTOFF_MONTHS <- 0

# ------------------------------------------------------------------------------
# 0. read the Cell 8 Excel result directly (avoids in-memory state confusion)
# ------------------------------------------------------------------------------
file_c8 <- sprintf("%s/%dM_Cell8_2Algo_Boot_Categorized.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS)

if (!file.exists(file_c8)) {
  stop(sprintf("🚨 File not found: %s\nPlease run Cell 8 first.", file_c8))
}

# accurately load the sheet containing the ROC data from Excel
df_roc_data <- as.data.frame(read_excel(file_c8, sheet = "ROC_Plot_Data"))
df_roc_data$Event <- as.numeric(df_roc_data$Event) # ensure type stability


# ------------------------------------------------------------------------------
# 2. run Calibration & HL Test for **all models (every column)**
# ------------------------------------------------------------------------------
results_summary <- list()

pred_cols <- setdiff(names(df_roc_data), c("Patient_ID", "Implant_ID", "Event"))
cat(sprintf("\n[1] Evaluating Calibration Metrics for ALL %d Models...\n", length(pred_cols)))

for (m_name in pred_cols) {
  probs <- as.numeric(df_roc_data[[m_name]])

  roc_obj <- suppressMessages(roc(df_roc_data$Event, probs, quiet=TRUE, direction="<"))
  auc_val <- as.numeric(auc(roc_obj))
  brier <- mean((probs - df_roc_data$Event)^2)

  v_stats <- invisible(capture.output(tryCatch({val.prob(probs, df_roc_data$Event, pl=FALSE)}, error=function(e){rep(NA, 10)})))
  v_stats <- val.prob(probs, df_roc_data$Event, pl=FALSE)
  cal_slope <- round(v_stats["Slope"], 3)

  hl_test <- suppressWarnings(tryCatch({
    result <- hoslem.test(df_roc_data$Event, probs, g=5)$p.value
    if (is.nan(result) || is.na(result)) {
        result2 <- tryCatch(hoslem.test(df_roc_data$Event, probs, g=4)$p.value, error=function(e) NA)
        ifelse(is.nan(result2), NA, result2)
    } else { result }
  }, error=function(e){ NA }))

  results_summary[[m_name]] <- data.frame(
    Model_Name    = m_name,
    AUC_Apparent  = round(auc_val, 3),
    Brier_Score   = round(brier, 3),
    Calib_Slope   = cal_slope,
    HL_p_value    = round(hl_test, 3)
  )
}

df_summary_final <- do.call(rbind, results_summary)
rownames(df_summary_final) <- NULL


# ------------------------------------------------------------------------------
# 5. [final merge] split by category and save Excel data (for all models)
# ------------------------------------------------------------------------------
df_summary_final <- df_summary_final[order(-df_summary_final$AUC_Apparent), ]

df_calib_cm  <- df_summary_final[grepl("^CM_",  df_summary_final$Model_Name), ]
df_calib_crm <- df_summary_final[grepl("^CRM_", df_summary_final$Model_Name), ]
df_calib_rm  <- df_summary_final[grepl("^RM_",  df_summary_final$Model_Name), ]
df_calib_srm <- df_summary_final[grepl("^SRM_", df_summary_final$Model_Name), ]

save_name_c9 <- sprintf("%s/%dM_Cell10_ClinicalDefense_Categorized.xlsx", SAVE_DIR, SENS_CUTOFF_MONTHS)
write_xlsx(
  list(
    "Calib_All"    = df_summary_final,
    "Calib_CM"     = df_calib_cm,
    "Calib_CRM"    = df_calib_crm,
    "Calib_RM"     = df_calib_rm,
    "Calib_SRM"    = df_calib_srm,
    "Probabilities"= df_roc_data
  ),
  path = save_name_c9
)

cat(sprintf("\n🎉 [All Tasks Completed] Analysis successfully finished! Results saved to: %s\n", save_name_c9))
}

# %%
# ==============================================================================
# Run all offsets. 0M model selection (above) is frozen; here only Cell 8/8b/9
# re-run per offset on offset-filtered data, reusing the 0M model pool.
# ==============================================================================
for (m in OFFSETS) {
  cat(sprintf("\n\n########## OFFSET %dM — validation ##########\n", m))
  run_bootstrap(m)
  run_logo(m)
  run_calibration(m)
}
cat("\n\n\u2705 All offsets complete.\n")
# Out:
# ########## OFFSET 0M — validation ##########
#
# [CELL 8] Auto feat_sets (singles + Cell7 PASS)...
#   single: 13 (CM 3 + SRM 10)
#  [1] "CM_Jaw"               "CM_Depth"             "CM_SP"
#  [4] "SRM_LLRMS"            "SRM_HHRange"          "SRM_HHMedianT"
#  [7] "SRM_LLIQRT"           "SRM_HHEnergy"         "SRM_LLStd"
# [10] "SRM_HLIQR"            "SRM_GLSZMGLNU"        "SRM_LHP25"
# [13] "SRM_GLCMClusterShade"
#   Bootstrap pool: 52 (single 13 + 2-feature 39)
# two_sets: 39
#
# 🚀 Running 2-Algorithm Bootstrapping (LR, XGB - B=1000)...
#    Feature Set            Algo App.AUC   Optim Adj.AUC  Sens  Spec
#     --------------------------------------------------------------------
#       CM_Jaw               LR   0.596   0.001   0.595   0.53  0.67
#       CM_Jaw               XGB  0.596   0.001   0.595   0.53  0.67
#    ★  CM_Depth             LR   0.781   -0.002   0.783   0.95  0.56
#    ★★ CM_Depth             XGB  0.860   0.057   0.803   0.95  0.56
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
#       CM_SP                LR   0.606   0.011   0.595   0.26  0.95
#       CM_SP                XGB  0.606   0.008   0.598   0.26  0.95
#       SRM_LLRMS            LR   0.594   -0.001   0.595   0.79  0.44
#       SRM_LLRMS            XGB  0.853   0.174   0.679   0.84  0.69
#       SRM_HHRange          LR   0.538   0.037   0.501   0.74  0.51
#       SRM_HHRange          XGB  0.840   0.118   0.722   0.90  0.59
#       SRM_HHMedianT        LR   0.582   0.052   0.530   0.58  0.61
#       SRM_HHMedianT        XGB  0.843   0.181   0.661   0.95  0.56
#       SRM_LLIQRT           LR   0.453   0.043   0.411   0.90  0.15
#       SRM_LLIQRT           XGB  0.814   0.186   0.629   0.90  0.59
#       SRM_HHEnergy         LR   0.555   0.015   0.540   1.00  0.18
#       SRM_HHEnergy         XGB  0.823   0.165   0.658   0.90  0.67
#       SRM_LLStd            LR   0.572   0.008   0.564   0.95  0.23
#       SRM_LLStd            XGB  0.799   0.147   0.652   0.79  0.69
#       SRM_HLIQR            LR   0.509   0.050   0.459   0.42  0.69
#       SRM_HLIQR            XGB  0.779   0.158   0.621   0.68  0.77
#       SRM_GLSZMGLNU        LR   0.551   0.050   0.501   0.42  0.74
#       SRM_GLSZMGLNU        XGB  0.738   0.201   0.537   0.84  0.56
#       SRM_LHP25            LR   0.660   0.020   0.640   1.00  0.46
#    ★★ SRM_LHP25            XGB  0.885   0.078   0.807   0.95  0.67
#       SRM_GLCMClusterShade LR   0.621   -0.007   0.628   0.74  0.54
#       SRM_GLCMClusterShade XGB  0.796   0.164   0.631   0.90  0.61
#    ★  CM_Jaw_Depth         LR   0.790   0.014   0.776   0.79  0.67
#    ★  CM_Jaw_Depth         XGB  0.860   0.063   0.797   0.95  0.56
#       CRM_Jaw_LLRMS        LR   0.629   0.017   0.612   0.74  0.54
#       CRM_Jaw_LLRMS        XGB  0.818   0.174   0.644   0.58  0.92
#       CRM_Jaw_HHRange      LR   0.633   0.029   0.604   1.00  0.36
#    ★  CRM_Jaw_HHRange      XGB  0.891   0.108   0.784   0.74  0.87
#       CRM_Jaw_HHMedianT    LR   0.679   0.060   0.618   0.63  0.74
#       CRM_Jaw_HHMedianT    XGB  0.831   0.176   0.655   0.90  0.69
#       CRM_Jaw_LLIQRT       LR   0.584   0.036   0.549   1.00  0.20
#       CRM_Jaw_LLIQRT       XGB  0.881   0.177   0.704   0.95  0.64
#       CRM_Jaw_LLStd        LR   0.657   0.022   0.636   0.68  0.72
#       CRM_Jaw_LLStd        XGB  0.821   0.145   0.677   0.95  0.61
#       CRM_Jaw_HLIQR        LR   0.615   0.036   0.580   0.79  0.44
#       CRM_Jaw_HLIQR        XGB  0.760   0.158   0.602   0.90  0.49
#    ★  CRM_Depth_HHMedianT  LR   0.795   0.035   0.760   0.63  0.87
#    ★  CRM_Depth_HHMedianT  XGB  0.888   0.104   0.784   0.95  0.72
#       CRM_Depth_LLIQRT     LR   0.762   0.014   0.749   0.95  0.56
#    ★★ CRM_Depth_LLIQRT     XGB  0.921   0.097   0.824   0.84  0.92
#       CRM_Depth_HHEnergy   LR   0.771   0.023   0.747   0.95  0.56
#    ★  CRM_Depth_HHEnergy   XGB  0.896   0.099   0.797   0.84  0.82
#    ★  CRM_Depth_HLIQR      LR   0.789   0.009   0.781   0.90  0.59
#    ★★ CRM_Depth_HLIQR      XGB  0.894   0.089   0.805   0.84  0.85
#    ★  CRM_Depth_GLSZMGLNU  LR   0.773   0.019   0.755   0.95  0.59
#    ★★ CRM_Depth_GLSZMGLNU  XGB  0.905   0.095   0.810   0.84  0.87
#    ★  CRM_Depth_LHP25      LR   0.787   0.036   0.751   0.90  0.59
#    ★★ CRM_Depth_LHP25      XGB  0.947   0.076   0.870   0.79  0.97
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
#       CRM_SP_HHRange       LR   0.692   0.024   0.668   0.90  0.49
#       CRM_SP_HHRange       XGB  0.858   0.109   0.749   0.74  0.90
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
#       CRM_SP_LLIQRT        LR   0.567   0.033   0.534   0.26  0.95
#       CRM_SP_LLIQRT        XGB  0.825   0.157   0.667   0.90  0.74
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
#       CRM_SP_HHEnergy      LR   0.628   0.031   0.596   0.53  0.72
#       CRM_SP_HHEnergy      XGB  0.839   0.158   0.681   0.79  0.80
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
#       CRM_SP_HLIQR         LR   0.633   0.035   0.598   0.37  0.95
#       CRM_SP_HLIQR         XGB  0.808   0.144   0.664   0.90  0.59
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
#       CRM_SP_GLSZMGLNU     LR   0.652   0.057   0.594   0.58  0.72
#       CRM_SP_GLSZMGLNU     XGB  0.802   0.179   0.623   0.74  0.77
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
#       CRM_SP_LHP25         LR   0.698   0.054   0.644   1.00  0.44
#    ★★ CRM_SP_LHP25         XGB  0.904   0.082   0.822   0.84  0.80
#       RM_LLRMS_HHRange     LR   0.614   0.021   0.593   1.00  0.31
#    ★  RM_LLRMS_HHRange     XGB  0.908   0.158   0.750   0.84  0.90
#       RM_LLRMS_HHMedianT   LR   0.609   0.077   0.531   1.00  0.23
#       RM_LLRMS_HHMedianT   XGB  0.881   0.209   0.672   0.90  0.85
#       RM_LLRMS_LLIQRT      LR   0.586   0.032   0.553   0.58  0.67
#       RM_LLRMS_LLIQRT      XGB  0.872   0.194   0.678   0.84  0.77
#       RM_LLRMS_HLIQR       LR   0.592   0.027   0.566   0.79  0.44
#       RM_LLRMS_HLIQR       XGB  0.893   0.193   0.700   0.95  0.72
#       RM_HHRange_HHMedianT LR   0.659   0.067   0.591   0.47  0.90
#    ★  RM_HHRange_HHMedianT XGB  0.936   0.169   0.767   1.00  0.87
#       RM_HHRange_LLIQRT    LR   0.538   0.054   0.485   0.74  0.51
#    ★  RM_HHRange_LLIQRT    XGB  0.926   0.156   0.770   0.90  0.87
#       RM_HHRange_LLStd     LR   0.621   0.037   0.584   0.74  0.54
#       RM_HHRange_LLStd     XGB  0.861   0.142   0.719   0.68  0.90
#       RM_HHMedianT_LLIQRT  LR   0.580   0.080   0.500   0.47  0.72
#       RM_HHMedianT_LLIQRT  XGB  0.900   0.222   0.678   0.90  0.82
#       RM_HHMedianT_HHEnergy LR   0.584   0.079   0.505   0.79  0.44
#       RM_HHMedianT_HHEnergy XGB  0.877   0.203   0.673   0.95  0.77
#       RM_HHMedianT_LLStd   LR   0.579   0.080   0.499   0.37  0.90
#       RM_HHMedianT_LLStd   XGB  0.887   0.195   0.691   0.90  0.85
#       RM_HHMedianT_GLSZMGLNU LR   0.557   0.101   0.456   0.53  0.67
#       RM_HHMedianT_GLSZMGLNU XGB  0.870   0.225   0.645   0.79  0.82
#       RM_HHMedianT_LHP25   LR   0.664   0.102   0.562   1.00  0.41
#    ★  RM_HHMedianT_LHP25   XGB  0.895   0.115   0.781   0.84  0.82
#       RM_HHMedianT_GLCMClusterShade LR   0.637   0.054   0.583   0.84  0.39
#       RM_HHMedianT_GLCMClusterShade XGB  0.870   0.200   0.670   1.00  0.61
#       RM_LLIQRT_HHEnergy   LR   0.551   0.037   0.513   1.00  0.18
#       RM_LLIQRT_HHEnergy   XGB  0.883   0.194   0.688   0.90  0.74
#       RM_LLIQRT_LLStd      LR   0.571   0.031   0.540   0.95  0.23
#       RM_LLIQRT_LLStd      XGB  0.854   0.178   0.675   0.79  0.82
#       RM_LLIQRT_HLIQR      LR   0.501   0.071   0.430   0.32  0.82
#       RM_LLIQRT_HLIQR      XGB  0.833   0.197   0.636   0.90  0.61
#       RM_LLIQRT_GLSZMGLNU  LR   0.555   0.075   0.479   0.42  0.74
#       RM_LLIQRT_GLSZMGLNU  XGB  0.841   0.210   0.632   0.79  0.82
#       RM_LLIQRT_LHP25      LR   0.660   0.037   0.623   1.00  0.46
#    ★★ RM_LLIQRT_LHP25      XGB  0.897   0.092   0.804   1.00  0.64
#       RM_LLStd_HLIQR       LR   0.576   0.039   0.537   0.74  0.49
#       RM_LLStd_HLIQR       XGB  0.812   0.178   0.633   0.79  0.69
#       RM_LLStd_GLSZMGLNU   LR   0.594   0.044   0.549   0.95  0.31
#       RM_LLStd_GLSZMGLNU   XGB  0.821   0.190   0.631   0.84  0.72
#
# ===== Top 10 Models (Overall Adjusted AUC) =====
#                 Feature_Set Algorithm AUC_Apparent Optimism AUC_Adjusted
# 97.5%51     CRM_Depth_LHP25       XGB        0.947    0.076        0.870
# 97.5%43    CRM_Depth_LLIQRT       XGB        0.921    0.097        0.824
# 97.5%63        CRM_SP_LHP25       XGB        0.904    0.082        0.822
# 97.5%49 CRM_Depth_GLSZMGLNU       XGB        0.905    0.095        0.810
# 97.5%23           SRM_LHP25       XGB        0.885    0.078        0.807
# 97.5%47     CRM_Depth_HLIQR       XGB        0.894    0.089        0.805
# 97.5%99     RM_LLIQRT_LHP25       XGB        0.897    0.092        0.804
# 97.5%3             CM_Depth       XGB        0.860    0.057        0.803
# 97.5%27        CM_Jaw_Depth       XGB        0.860    0.063        0.797
# 97.5%45  CRM_Depth_HHEnergy       XGB        0.896    0.099        0.797
#         CI_lo_95 CI_hi_95 Sensitivity Specificity
# 97.5%51    0.725    0.946       0.789       0.974
# 97.5%43    0.636    0.923       0.842       0.923
# 97.5%63    0.669    0.899       0.842       0.795
# 97.5%49    0.669    0.907       0.842       0.872
# 97.5%23    0.650    0.887       0.947       0.667
# 97.5%47    0.661    0.895       0.842       0.846
# 97.5%99    0.644    0.890       1.000       0.641
# 97.5%3     0.662    0.904       0.947       0.564
# 97.5%27    0.634    0.894       0.947       0.564
# 97.5%45    0.664    0.896       0.842       0.821
#                                            Features
# 97.5%51    Insertion_Depth_mm + Wav_LH_FO_P25_first
# 97.5%43    Insertion_Depth_mm + Wav_LL_FO_IQR_trend
# 97.5%63  Is_Single_Prosthesis + Wav_LH_FO_P25_first
# 97.5%49       Insertion_Depth_mm + GLSZM_GLNU_first
# 97.5%23                         Wav_LH_FO_P25_first
# 97.5%47    Insertion_Depth_mm + Wav_HL_FO_IQR_first
# 97.5%99   Wav_LL_FO_IQR_trend + Wav_LH_FO_P25_first
# 97.5%3                           Insertion_Depth_mm
# 97.5%27               Jaw_Code + Insertion_Depth_mm
# 97.5%45 Insertion_Depth_mm + Wav_HH_FO_Energy_first
#
# ✅ [Success] Data completely saved to: /content/Results_R/0M_Cell8_2Algo_Boot_Categorized.xlsx
#
# [CELL 9] LOGO-CV (Leave-One-Patient-Out) for LR & XGB...
#    N=58 | MRONJ=19 | Control=39 | Patients=7
#
# [CELL 8] Auto feat_sets (singles + Cell7 PASS)...
#   single: 13 (CM 3 + SRM 10)
#  [1] "CM_Jaw"               "CM_Depth"             "CM_SP"
#  [4] "SRM_LLRMS"            "SRM_HHRange"          "SRM_HHMedianT"
#  [7] "SRM_LLIQRT"           "SRM_HHEnergy"         "SRM_LLStd"
# [10] "SRM_HLIQR"            "SRM_GLSZMGLNU"        "SRM_LHP25"
# [13] "SRM_GLCMClusterShade"
#   Bootstrap pool: 52 (single 13 + 2-feature 39)
# two_sets: 39
#
#  🚀 Running LOGO-CV for ALL Models...
#    Feature Set            Algo  CV.AUC   CI.Lo   CI.Hi  Sens  Spec
#     --------------------------------------------------------------------
#       CM_Jaw               LR   0.524   0.363   0.685   0.53  0.67
#       CM_Jaw               XGB  0.526   0.364   0.687   0.53  0.67
#    ★  CM_Depth             LR   0.752   0.620   0.885   0.95  0.46
#    ★  CM_Depth             XGB  0.750   0.615   0.886   0.95  0.51
#       CM_SP                LR   0.533   0.363   0.704   0.26  0.95
#       CM_SP                XGB  0.509   0.347   0.670   0.11  0.97
#       SRM_LLRMS            LR   0.549   0.389   0.709   0.42  0.74
#       SRM_LLRMS            XGB  0.400   0.245   0.555   0.05  0.95
#       SRM_HHRange          LR   0.448   0.283   0.613   0.21  0.85
#       SRM_HHRange          XGB  0.570   0.402   0.737   0.26  0.95
#       SRM_HHMedianT        LR   0.345   0.184   0.507   1.00  0.00
#       SRM_HHMedianT        XGB  0.318   0.169   0.468   1.00  0.03
#       SRM_LLIQRT           LR   0.385   0.227   0.543   1.00  0.05
#       SRM_LLIQRT           XGB  0.336   0.178   0.494   0.11  0.90
#       SRM_HHEnergy         LR   0.528   0.375   0.681   1.00  0.18
#       SRM_HHEnergy         XGB  0.444   0.292   0.596   0.79  0.26
#       SRM_LLStd            LR   0.503   0.342   0.665   0.84  0.26
#       SRM_LLStd            XGB  0.473   0.321   0.625   0.84  0.33
#       SRM_HLIQR            LR   0.372   0.224   0.521   0.95  0.13
#       SRM_HLIQR            XGB  0.395   0.245   0.545   0.79  0.23
#       SRM_GLSZMGLNU        LR   0.409   0.244   0.574   0.16  0.90
#       SRM_GLSZMGLNU        XGB  0.360   0.203   0.518   1.00  0.00
#       SRM_LHP25            LR   0.637   0.494   0.780   0.95  0.49
#       SRM_LHP25            XGB  0.712   0.581   0.842   0.95  0.44
#       SRM_GLCMClusterShade LR   0.599   0.438   0.760   0.47  0.85
#       SRM_GLCMClusterShade XGB  0.370   0.227   0.514   0.74  0.28
#       CM_Jaw_Depth         LR   0.748   0.610   0.885   0.84  0.59
#    ★  CM_Jaw_Depth         XGB  0.755   0.618   0.892   0.95  0.51
#       CRM_Jaw_LLRMS        LR   0.570   0.412   0.727   0.79  0.46
#       CRM_Jaw_LLRMS        XGB  0.398   0.242   0.554   0.05  1.00
#       CRM_Jaw_HHRange      LR   0.547   0.387   0.706   0.79  0.38
#       CRM_Jaw_HHRange      XGB  0.684   0.545   0.822   0.95  0.41
#       CRM_Jaw_HHMedianT    LR   0.431   0.262   0.601   0.47  0.62
#       CRM_Jaw_HHMedianT    XGB  0.393   0.233   0.553   0.21  0.82
#       CRM_Jaw_LLIQRT       LR   0.484   0.325   0.644   0.53  0.64
#       CRM_Jaw_LLIQRT       XGB  0.393   0.233   0.552   0.05  0.95
#       CRM_Jaw_LLStd        LR   0.601   0.441   0.760   0.68  0.62
#       CRM_Jaw_LLStd        XGB  0.540   0.384   0.696   0.79  0.41
#       CRM_Jaw_HLIQR        LR   0.513   0.350   0.676   0.53  0.67
#       CRM_Jaw_HLIQR        XGB  0.413   0.263   0.563   0.79  0.26
#       CRM_Depth_HHMedianT  LR   0.742   0.607   0.877   0.84  0.59
#       CRM_Depth_HHMedianT  XGB  0.689   0.544   0.834   0.79  0.64
#       CRM_Depth_LLIQRT     LR   0.730   0.596   0.864   0.95  0.49
#       CRM_Depth_LLIQRT     XGB  0.661   0.514   0.807   0.95  0.56
#       CRM_Depth_HHEnergy   LR   0.713   0.574   0.851   0.79  0.67
#       CRM_Depth_HHEnergy   XGB  0.693   0.552   0.834   0.95  0.51
#    ★  CRM_Depth_HLIQR      LR   0.764   0.631   0.897   0.95  0.51
#       CRM_Depth_HLIQR      XGB  0.704   0.563   0.846   0.89  0.51
#       CRM_Depth_GLSZMGLNU  LR   0.733   0.595   0.871   0.79  0.67
#       CRM_Depth_GLSZMGLNU  XGB  0.700   0.558   0.841   0.95  0.54
#       CRM_Depth_LHP25      LR   0.719   0.580   0.858   0.84  0.56
#       CRM_Depth_LHP25      XGB  0.748   0.616   0.879   0.84  0.56
#       CRM_SP_HHRange       LR   0.668   0.515   0.821   0.47  0.85
#       CRM_SP_HHRange       XGB  0.619   0.455   0.784   0.68  0.59
#       CRM_SP_LLIQRT        LR   0.555   0.392   0.717   0.26  0.92
#       CRM_SP_LLIQRT        XGB  0.396   0.224   0.569   0.42  0.64
#       CRM_SP_HHEnergy      LR   0.609   0.450   0.767   0.26  0.95
#       CRM_SP_HHEnergy      XGB  0.422   0.266   0.579   0.05  0.97
#       CRM_SP_HLIQR         LR   0.528   0.355   0.700   0.26  0.95
#       CRM_SP_HLIQR         XGB  0.418   0.260   0.576   1.00  0.00
#       CRM_SP_GLSZMGLNU     LR   0.491   0.306   0.677   0.37  0.82
#       CRM_SP_GLSZMGLNU     XGB  0.420   0.259   0.581   0.47  0.56
#       CRM_SP_LHP25         LR   0.636   0.490   0.781   0.95  0.38
#       CRM_SP_LHP25         XGB  0.698   0.565   0.832   0.95  0.41
#       RM_LLRMS_HHRange     LR   0.587   0.434   0.740   0.89  0.38
#       RM_LLRMS_HHRange     XGB  0.505   0.338   0.672   0.21  0.95
#       RM_LLRMS_HHMedianT   LR   0.339   0.189   0.488   1.00  0.00
#       RM_LLRMS_HHMedianT   XGB  0.346   0.201   0.492   1.00  0.00
#       RM_LLRMS_LLIQRT      LR   0.522   0.363   0.682   0.89  0.31
#       RM_LLRMS_LLIQRT      XGB  0.335   0.183   0.488   1.00  0.00
#       RM_LLRMS_HLIQR       LR   0.532   0.366   0.697   0.37  0.85
#       RM_LLRMS_HLIQR       XGB  0.365   0.213   0.517   1.00  0.00
#       RM_HHRange_HHMedianT LR   0.402   0.232   0.573   0.21  0.90
#       RM_HHRange_HHMedianT XGB  0.468   0.304   0.633   0.16  0.97
#       RM_HHRange_LLIQRT    LR   0.459   0.298   0.619   0.79  0.31
#       RM_HHRange_LLIQRT    XGB  0.492   0.312   0.671   0.42  0.72
#       RM_HHRange_LLStd     LR   0.561   0.398   0.725   0.74  0.46
#       RM_HHRange_LLStd     XGB  0.538   0.373   0.704   0.53  0.67
#       RM_HHMedianT_LLIQRT  LR   0.344   0.187   0.501   1.00  0.00
#       RM_HHMedianT_LLIQRT  XGB  0.238   0.096   0.380   1.00  0.00
#       RM_HHMedianT_HHEnergy LR   0.389   0.235   0.542   0.84  0.21
#       RM_HHMedianT_HHEnergy XGB  0.275   0.132   0.417   1.00  0.03
#       RM_HHMedianT_LLStd   LR   0.339   0.177   0.500   0.11  0.92
#       RM_HHMedianT_LLStd   XGB  0.378   0.233   0.523   0.79  0.31
#       RM_HHMedianT_GLSZMGLNU LR   0.256   0.105   0.407   0.11  0.90
#       RM_HHMedianT_GLSZMGLNU XGB  0.242   0.110   0.375   1.00  0.00
#       RM_HHMedianT_LHP25   LR   0.417   0.250   0.584   0.11  0.97
#       RM_HHMedianT_LHP25   XGB  0.643   0.502   0.784   0.95  0.44
#       RM_HHMedianT_GLCMClusterShade LR   0.428   0.269   0.587   0.32  0.72
#       RM_HHMedianT_GLCMClusterShade XGB  0.277   0.133   0.422   1.00  0.00
#       RM_LLIQRT_HHEnergy   LR   0.510   0.359   0.661   1.00  0.21
#       RM_LLIQRT_HHEnergy   XGB  0.320   0.167   0.472   1.00  0.00
#       RM_LLIQRT_LLStd      LR   0.503   0.341   0.666   1.00  0.13
#       RM_LLIQRT_LLStd      XGB  0.339   0.183   0.495   1.00  0.00
#       RM_LLIQRT_HLIQR      LR   0.375   0.226   0.524   1.00  0.03
#       RM_LLIQRT_HLIQR      XGB  0.294   0.131   0.457   0.11  0.90
#       RM_LLIQRT_GLSZMGLNU  LR   0.345   0.192   0.499   1.00  0.05
#       RM_LLIQRT_GLSZMGLNU  XGB  0.294   0.148   0.439   0.05  0.95
#       RM_LLIQRT_LHP25      LR   0.621   0.478   0.764   0.89  0.51
#    ★  RM_LLIQRT_LHP25      XGB  0.753   0.625   0.881   0.89  0.59
#       RM_LLStd_HLIQR       LR   0.489   0.331   0.646   1.00  0.15
#       RM_LLStd_HLIQR       XGB  0.389   0.233   0.545   1.00  0.00
#       RM_LLStd_GLSZMGLNU   LR   0.533   0.370   0.696   0.47  0.72
#       RM_LLStd_GLSZMGLNU   XGB  0.400   0.246   0.555   1.00  0.00
#
# ===== LOGO-CV Top 10 Models (Overall CV AUC) =====
#            Feature_Set Algorithm CV_AUC CI_lo_95 CI_hi_95 Sensitivity
# 1      CRM_Depth_HLIQR        LR  0.764    0.631    0.897       0.947
# 2         CM_Jaw_Depth       XGB  0.755    0.618    0.892       0.947
# 3      RM_LLIQRT_LHP25       XGB  0.753    0.625    0.881       0.895
# 4             CM_Depth        LR  0.752    0.620    0.885       0.947
# 5             CM_Depth       XGB  0.750    0.615    0.886       0.947
# 6         CM_Jaw_Depth        LR  0.748    0.610    0.885       0.842
# 7      CRM_Depth_LHP25       XGB  0.748    0.616    0.879       0.842
# 8  CRM_Depth_HHMedianT        LR  0.742    0.607    0.877       0.842
# 9  CRM_Depth_GLSZMGLNU        LR  0.733    0.595    0.871       0.789
# 10    CRM_Depth_LLIQRT        LR  0.730    0.596    0.864       0.947
#    Specificity                                    Features
# 1        0.513    Insertion_Depth_mm + Wav_HL_FO_IQR_first
# 2        0.513               Jaw_Code + Insertion_Depth_mm
# 3        0.590   Wav_LL_FO_IQR_trend + Wav_LH_FO_P25_first
# 4        0.462                          Insertion_Depth_mm
# 5        0.513                          Insertion_Depth_mm
# 6        0.590               Jaw_Code + Insertion_Depth_mm
# 7        0.564    Insertion_Depth_mm + Wav_LH_FO_P25_first
# 8        0.590 Insertion_Depth_mm + Wav_HH_FO_Median_trend
# 9        0.667       Insertion_Depth_mm + GLSZM_GLNU_first
# 10       0.487    Insertion_Depth_mm + Wav_LL_FO_IQR_trend
#
# ✅ [Success] All category-specific LOGO-CV results and complete ROC data saved to:
# ➡️ /content/Results_R/0M_Cell9_LOGO_CV_Categorized.xlsx
#
# [CELL 10] Running Clinical Utility Validations...
#
# [1] Evaluating Calibration Metrics for ALL 104 Models...
#
# 🎉 [All Tasks Completed] Analysis successfully finished! Results saved to: /content/Results_R/0M_Cell10_ClinicalDefense_Categorized.xlsx
#
#
# ########## OFFSET 3M — validation ##########
#
# [CELL 8] Auto feat_sets (singles + Cell7 PASS)...
#   single: 13 (CM 3 + SRM 10)
#  [1] "CM_Jaw"               "CM_Depth"             "CM_SP"
#  [4] "SRM_LLRMS"            "SRM_HHRange"          "SRM_HHMedianT"
#  [7] "SRM_LLIQRT"           "SRM_HHEnergy"         "SRM_LLStd"
# [10] "SRM_HLIQR"            "SRM_GLSZMGLNU"        "SRM_LHP25"
# [13] "SRM_GLCMClusterShade"
#   Bootstrap pool: 52 (single 13 + 2-feature 39)
# two_sets: 39
#
# 🚀 Running 2-Algorithm Bootstrapping (LR, XGB - B=1000)...
#    Feature Set            Algo App.AUC   Optim Adj.AUC  Sens  Spec
#     --------------------------------------------------------------------
#       CM_Jaw               LR   0.569   0.016   0.553   0.47  0.67
#       CM_Jaw               XGB  0.569   0.016   0.553   0.47  0.67
#    ★  CM_Depth             LR   0.759   -0.000   0.760   0.94  0.56
#    ★  CM_Depth             XGB  0.858   0.069   0.789   0.82  0.72
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
#       CM_SP                LR   0.563   0.016   0.546   0.18  0.95
#       CM_SP                XGB  0.563   0.010   0.552   0.18  0.95
#       SRM_LLRMS            LR   0.582   0.005   0.577   0.77  0.44
#       SRM_LLRMS            XGB  0.831   0.189   0.642   0.77  0.77
#       SRM_HHRange          LR   0.587   0.013   0.574   0.82  0.51
#       SRM_HHRange          XGB  0.854   0.114   0.740   0.82  0.77
#       SRM_HHMedianT        LR   0.557   0.101   0.457   0.23  0.92
#       SRM_HHMedianT        XGB  0.805   0.211   0.594   0.82  0.69
#       SRM_LLIQRT           LR   0.692   0.060   0.633   0.94  0.41
#       SRM_LLIQRT           XGB  0.811   0.132   0.679   0.94  0.56
#       SRM_HHEnergy         LR   0.526   0.025   0.502   1.00  0.18
#       SRM_HHEnergy         XGB  0.851   0.173   0.679   0.82  0.82
#       SRM_LLStd            LR   0.560   0.013   0.547   0.23  0.95
#       SRM_LLStd            XGB  0.810   0.152   0.658   0.65  0.85
#       SRM_HLIQR            LR   0.560   0.029   0.530   1.00  0.18
#       SRM_HLIQR            XGB  0.840   0.166   0.674   0.88  0.72
#       SRM_GLSZMGLNU        LR   0.492   0.067   0.425   0.94  0.15
#       SRM_GLSZMGLNU        XGB  0.731   0.212   0.519   0.53  0.82
#       SRM_LHP25            LR   0.624   0.058   0.566   1.00  0.46
#    ★★ SRM_LHP25            XGB  0.891   0.076   0.816   0.88  0.72
#       SRM_GLCMClusterShade LR   0.593   0.002   0.591   0.71  0.54
#       SRM_GLCMClusterShade XGB  0.816   0.180   0.636   0.77  0.74
#       CM_Jaw_Depth         LR   0.752   0.018   0.733   0.77  0.67
#    ★  CM_Jaw_Depth         XGB  0.851   0.077   0.774   0.94  0.56
#       CRM_Jaw_LLRMS        LR   0.603   0.034   0.569   0.71  0.54
#       CRM_Jaw_LLRMS        XGB  0.824   0.194   0.630   0.77  0.72
#       CRM_Jaw_HHRange      LR   0.618   0.024   0.594   1.00  0.36
#    ★  CRM_Jaw_HHRange      XGB  0.882   0.106   0.776   0.71  0.87
#       CRM_Jaw_HHMedianT    LR   0.621   0.087   0.534   0.65  0.64
#       CRM_Jaw_HHMedianT    XGB  0.799   0.203   0.597   0.82  0.64
#       CRM_Jaw_LLIQRT       LR   0.665   0.063   0.602   0.82  0.56
#       CRM_Jaw_LLIQRT       XGB  0.840   0.137   0.703   0.82  0.72
#       CRM_Jaw_LLStd        LR   0.624   0.036   0.588   0.59  0.77
#       CRM_Jaw_LLStd        XGB  0.806   0.156   0.650   0.82  0.69
#       CRM_Jaw_HLIQR        LR   0.609   0.038   0.572   0.47  0.74
#       CRM_Jaw_HLIQR        XGB  0.845   0.172   0.673   0.88  0.64
#       CRM_Depth_HHMedianT  LR   0.754   0.045   0.709   0.82  0.67
#    ★  CRM_Depth_HHMedianT  XGB  0.904   0.122   0.782   0.88  0.82
# ...
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
# Warning message in predict.lm(object, newdata, se.fit, scale = 1, type = if (type == :
# “prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases”
#       CRM_SP_LHP25         LR   0.672   0.104   0.569   1.00  0.46
#    ★★ CRM_SP_LHP25         XGB  0.917   0.087   0.829   0.94  0.76
#       RM_LLRMS_HHRange     LR   0.676   0.024   0.652   0.75  0.64
#    ★  RM_LLRMS_HHRange     XGB  0.918   0.121   0.797   0.81  0.88
#       RM_LLRMS_HHMedianT   LR   0.528   0.047   0.482   0.88  0.27
#       RM_LLRMS_HHMedianT   XGB  0.880   0.203   0.677   0.88  0.82
#       RM_LLRMS_LLIQRT      LR   0.557   0.042   0.515   0.25  0.94
#       RM_LLRMS_LLIQRT      XGB  0.883   0.204   0.678   0.94  0.73
#       RM_LLRMS_HLIQR       LR   0.644   0.043   0.601   0.56  0.73
#       RM_LLRMS_HLIQR       XGB  0.867   0.193   0.675   1.00  0.64
#       RM_HHRange_HHMedianT LR   0.672   0.039   0.634   0.88  0.55
#    ★★ RM_HHRange_HHMedianT XGB  0.924   0.080   0.844   0.94  0.76
#       RM_HHRange_LLIQRT    LR   0.644   0.045   0.599   0.94  0.42
#    ★  RM_HHRange_LLIQRT    XGB  0.883   0.101   0.781   0.69  0.97
#       RM_HHRange_LLStd     LR   0.680   0.014   0.666   0.81  0.61
#    ★  RM_HHRange_LLStd     XGB  0.885   0.099   0.787   0.81  0.85
#       RM_HHMedianT_LLIQRT  LR   0.540   0.066   0.473   0.94  0.21
#       RM_HHMedianT_LLIQRT  XGB  0.837   0.160   0.677   0.75  0.82
#       RM_HHMedianT_HHEnergy LR   0.564   0.046   0.518   1.00  0.21
#       RM_HHMedianT_HHEnergy XGB  0.914   0.166   0.748   0.94  0.79
#       RM_HHMedianT_LLStd   LR   0.464   0.046   0.418   0.31  0.82
#       RM_HHMedianT_LLStd   XGB  0.858   0.153   0.705   0.88  0.79
#       RM_HHMedianT_GLSZMGLNU LR   0.432   0.104   0.328   0.12  0.97
#       RM_HHMedianT_GLSZMGLNU XGB  0.807   0.211   0.596   0.69  0.85
#       RM_HHMedianT_LHP25   LR   0.636   0.117   0.519   1.00  0.42
#    ★★ RM_HHMedianT_LHP25   XGB  0.917   0.106   0.811   0.94  0.76
#       RM_HHMedianT_GLCMClusterShade LR   0.523   0.052   0.471   0.94  0.27
#       RM_HHMedianT_GLCMClusterShade XGB  0.856   0.181   0.675   0.69  0.91
#       RM_LLIQRT_HHEnergy   LR   0.581   0.046   0.535   1.00  0.21
#    ★  RM_LLIQRT_HHEnergy   XGB  0.926   0.159   0.767   0.88  0.91
#       RM_LLIQRT_LLStd      LR   0.574   0.040   0.534   0.25  0.94
#       RM_LLIQRT_LLStd      XGB  0.884   0.154   0.729   1.00  0.67
#       RM_LLIQRT_HLIQR      LR   0.598   0.050   0.548   0.94  0.33
#       RM_LLIQRT_HLIQR      XGB  0.838   0.182   0.656   0.62  0.91
#       RM_LLIQRT_GLSZMGLNU  LR   0.562   0.091   0.471   0.31  0.85
#       RM_LLIQRT_GLSZMGLNU  XGB  0.913   0.212   0.701   0.88  0.82
#       RM_LLIQRT_LHP25      LR   0.642   0.091   0.551   0.88  0.58
#    ★★ RM_LLIQRT_LHP25      XGB  0.943   0.096   0.848   0.94  0.79
#       RM_LLStd_HLIQR       LR   0.591   0.036   0.555   0.25  0.94
#       RM_LLStd_HLIQR       XGB  0.852   0.164   0.688   0.75  0.82
#       RM_LLStd_GLSZMGLNU   LR   0.521   0.084   0.437   0.25  0.97
#       RM_LLStd_GLSZMGLNU   XGB  0.876   0.184   0.692   1.00  0.64
#
# ===== Top 10 Models (Overall Adjusted AUC) =====
#                  Feature_Set Algorithm AUC_Apparent Optimism AUC_Adjusted
# 97.5%51      CRM_Depth_LHP25       XGB        0.959    0.083        0.877
# 97.5%99      RM_LLIQRT_LHP25       XGB        0.943    0.096        0.848
# 97.5%73 RM_HHRange_HHMedianT       XGB        0.924    0.080        0.844
# 97.5%23            SRM_LHP25       XGB        0.917    0.085        0.832
# 97.5%63         CRM_SP_LHP25       XGB        0.917    0.087        0.829
# 97.5%31      CRM_Jaw_HHRange       XGB        0.898    0.083        0.814
# 97.5%87   RM_HHMedianT_LHP25       XGB        0.917    0.106        0.811
# 97.5%65     RM_LLRMS_HHRange       XGB        0.918    0.121        0.797
# 97.5%41  CRM_Depth_HHMedianT       XGB        0.876    0.082        0.794
# 97.5%43     CRM_Depth_LLIQRT       XGB        0.885    0.095        0.791
#         CI_lo_95 CI_hi_95 Sensitivity Specificity
# 97.5%51    0.712    0.959       0.938       0.879
# 97.5%99    0.712    0.943       0.938       0.788
# 97.5%73    0.696    0.942       0.938       0.758
# 97.5%23    0.680    0.918       0.938       0.758
# 97.5%63    0.680    0.917       0.938       0.758
# 97.5%31    0.670    0.904       0.938       0.697
# 97.5%87    0.669    0.917       0.938       0.758
# 97.5%65    0.633    0.918       0.812       0.879
# 97.5%41    0.648    0.911       0.688       0.848
# 97.5%43    0.621    0.916       0.875       0.727
#                                               Features
# 97.5%51       Insertion_Depth_mm + Wav_LH_FO_P25_first
# 97.5%99      Wav_LL_FO_IQR_trend + Wav_LH_FO_P25_first
# 97.5%73 Wav_HH_FO_Range_first + Wav_HH_FO_Median_trend
# 97.5%23                            Wav_LH_FO_P25_first
# 97.5%63     Is_Single_Prosthesis + Wav_LH_FO_P25_first
# 97.5%31               Jaw_Code + Wav_HH_FO_Range_first
# 97.5%87   Wav_HH_FO_Median_trend + Wav_LH_FO_P25_first
# 97.5%65    Wav_LL_FO_RMS_first + Wav_HH_FO_Range_first
# 97.5%41    Insertion_Depth_mm + Wav_HH_FO_Median_trend
# 97.5%43       Insertion_Depth_mm + Wav_LL_FO_IQR_trend
#
# ✅ [Success] Data completely saved to: /content/Results_R/9M_Cell8_2Algo_Boot_Categorized.xlsx
#
# [CELL 9] LOGO-CV (Leave-One-Patient-Out) for LR & XGB...
#    N=49 | MRONJ=16 | Control=33 | Patients=6
#
# [CELL 8] Auto feat_sets (singles + Cell7 PASS)...
#   single: 13 (CM 3 + SRM 10)
#  [1] "CM_Jaw"               "CM_Depth"             "CM_SP"
#  [4] "SRM_LLRMS"            "SRM_HHRange"          "SRM_HHMedianT"
#  [7] "SRM_LLIQRT"           "SRM_HHEnergy"         "SRM_LLStd"
# [10] "SRM_HLIQR"            "SRM_GLSZMGLNU"        "SRM_LHP25"
# [13] "SRM_GLCMClusterShade"
#   Bootstrap pool: 52 (single 13 + 2-feature 39)
# two_sets: 39
#
#  🚀 Running LOGO-CV for ALL Models...
#    Feature Set            Algo  CV.AUC   CI.Lo   CI.Hi  Sens  Spec
#     --------------------------------------------------------------------
#       CM_Jaw               LR   0.524   0.346   0.701   0.44  0.73
#       CM_Jaw               XGB  0.524   0.346   0.701   0.44  0.73
#       CM_Depth             LR   0.707   0.555   0.860   0.94  0.45
#       CM_Depth             XGB  0.607   0.442   0.772   0.94  0.48
#       CM_SP                LR   0.505   0.324   0.686   0.19  0.94
#       CM_SP                XGB  0.459   0.291   0.628   1.00  0.00
#       SRM_LLRMS            LR   0.479   0.305   0.653   0.81  0.27
#       SRM_LLRMS            XGB  0.275   0.129   0.420   1.00  0.00
#       SRM_HHRange          LR   0.595   0.425   0.765   0.88  0.39
#       SRM_HHRange          XGB  0.737   0.582   0.892   0.88  0.58
#       SRM_HHMedianT        LR   0.420   0.241   0.600   0.12  1.00
#       SRM_HHMedianT        XGB  0.462   0.293   0.631   0.81  0.21
#       SRM_LLIQRT           LR   0.350   0.178   0.523   0.12  0.94
#       SRM_LLIQRT           XGB  0.466   0.295   0.636   0.81  0.30
#       SRM_HHEnergy         LR   0.553   0.386   0.720   1.00  0.18
#       SRM_HHEnergy         XGB  0.524   0.350   0.697   0.81  0.39
#       SRM_LLStd            LR   0.462   0.285   0.639   0.19  0.88
#       SRM_LLStd            XGB  0.545   0.376   0.715   0.75  0.52
#       SRM_HLIQR            LR   0.519   0.349   0.689   0.75  0.39
#       SRM_HLIQR            XGB  0.281   0.133   0.429   1.00  0.03
#       SRM_GLSZMGLNU        LR   0.339   0.164   0.514   0.06  0.94
#       SRM_GLSZMGLNU        XGB  0.364   0.192   0.535   0.44  0.58
#       SRM_LHP25            LR   0.623   0.468   0.778   1.00  0.42
#       SRM_LHP25            XGB  0.680   0.531   0.829   0.94  0.45
#       SRM_GLCMClusterShade LR   0.551   0.379   0.723   0.75  0.45
#       SRM_GLCMClusterShade XGB  0.370   0.210   0.530   1.00  0.00
#       CM_Jaw_Depth         LR   0.689   0.528   0.851   0.81  0.58
#       CM_Jaw_Depth         XGB  0.619   0.456   0.783   0.94  0.48
#       CRM_Jaw_LLRMS        LR   0.532   0.357   0.707   0.88  0.30
#       CRM_Jaw_LLRMS        XGB  0.284   0.131   0.438   1.00  0.00
#       CRM_Jaw_HHRange      LR   0.585   0.421   0.749   0.81  0.45
#    ★  CRM_Jaw_HHRange      XGB  0.770   0.640   0.900   0.88  0.58
#       CRM_Jaw_HHMedianT    LR   0.509   0.329   0.690   0.44  0.73
#       CRM_Jaw_HHMedianT    XGB  0.467   0.299   0.635   0.75  0.39
#       CRM_Jaw_LLIQRT       LR   0.525   0.341   0.708   0.56  0.70
#       CRM_Jaw_LLIQRT       XGB  0.607   0.445   0.769   0.69  0.61
#       CRM_Jaw_LLStd        LR   0.564   0.389   0.740   0.56  0.67
#       CRM_Jaw_LLStd        XGB  0.540   0.360   0.719   0.38  0.79
#       CRM_Jaw_HLIQR        LR   0.528   0.352   0.705   0.56  0.61
#       CRM_Jaw_HLIQR        XGB  0.398   0.233   0.562   1.00  0.00
#       CRM_Depth_HHMedianT  LR   0.617   0.436   0.799   0.75  0.55
#       CRM_Depth_HHMedianT  XGB  0.712   0.555   0.869   0.94  0.48
#       CRM_Depth_LLIQRT     LR   0.686   0.532   0.839   0.94  0.48
#       CRM_Depth_LLIQRT     XGB  0.722   0.568   0.875   0.94  0.58
#       CRM_Depth_HHEnergy   LR   0.634   0.470   0.799   0.81  0.61
#       CRM_Depth_HHEnergy   XGB  0.615   0.450   0.779   0.88  0.48
#       CRM_Depth_HLIQR      LR   0.716   0.554   0.878   0.69  0.73
#       CRM_Depth_HLIQR      XGB  0.646   0.485   0.806   0.94  0.48
#       CRM_Depth_GLSZMGLNU  LR   0.612   0.439   0.784   0.56  0.73
#       CRM_Depth_GLSZMGLNU  XGB  0.624   0.461   0.787   0.94  0.52
#       CRM_Depth_LHP25      LR   0.559   0.392   0.725   0.94  0.33
#       CRM_Depth_LHP25      XGB  0.698   0.550   0.846   0.88  0.52
#       CRM_SP_HHRange       LR   0.642   0.485   0.799   0.94  0.39
#       CRM_SP_HHRange       XGB  0.735   0.580   0.890   0.88  0.58
#       CRM_SP_LLIQRT        LR   0.458   0.277   0.639   0.25  0.85
#       CRM_SP_LLIQRT        XGB  0.472   0.303   0.640   0.81  0.30
#       CRM_SP_HHEnergy      LR   0.549   0.381   0.717   1.00  0.21
#       CRM_SP_HHEnergy      XGB  0.537   0.366   0.708   0.81  0.39
#       CRM_SP_HLIQR         LR   0.585   0.415   0.755   0.94  0.27
#       CRM_SP_HLIQR         XGB  0.283   0.134   0.433   1.00  0.03
#       CRM_SP_GLSZMGLNU     LR   0.400   0.220   0.579   0.12  0.91
#       CRM_SP_GLSZMGLNU     XGB  0.407   0.237   0.578   0.38  0.64
#       CRM_SP_LHP25         LR   0.585   0.426   0.745   1.00  0.30
#       CRM_SP_LHP25         XGB  0.680   0.531   0.829   0.94  0.45
#       RM_LLRMS_HHRange     LR   0.672   0.514   0.830   0.81  0.67
#       RM_LLRMS_HHRange     XGB  0.665   0.493   0.836   0.75  0.58
#       RM_LLRMS_HHMedianT   LR   0.436   0.255   0.616   0.12  1.00
#       RM_LLRMS_HHMedianT   XGB  0.295   0.134   0.457   1.00  0.00
#       RM_LLRMS_LLIQRT      LR   0.479   0.310   0.648   1.00  0.09
#       RM_LLRMS_LLIQRT      XGB  0.319   0.165   0.473   1.00  0.00
#       RM_LLRMS_HLIQR       LR   0.591   0.408   0.773   0.50  0.76
#       RM_LLRMS_HLIQR       XGB  0.328   0.168   0.487   1.00  0.00
#       RM_HHRange_HHMedianT LR   0.606   0.426   0.786   0.88  0.42
#       RM_HHRange_HHMedianT XGB  0.740   0.595   0.884   0.88  0.58
#       RM_HHRange_LLIQRT    LR   0.545   0.365   0.726   0.62  0.58
#       RM_HHRange_LLIQRT    XGB  0.711   0.551   0.871   0.69  0.73
#       RM_HHRange_LLStd     LR   0.644   0.474   0.814   0.62  0.73
#       RM_HHRange_LLStd     XGB  0.688   0.527   0.850   0.88  0.52
#       RM_HHMedianT_LLIQRT  LR   0.428   0.250   0.606   0.12  0.94
#       RM_HHMedianT_LLIQRT  XGB  0.376   0.214   0.538   1.00  0.03
#       RM_HHMedianT_HHEnergy LR   0.508   0.328   0.687   0.12  1.00
#       RM_HHMedianT_HHEnergy XGB  0.476   0.309   0.644   0.50  0.58
#       RM_HHMedianT_LLStd   LR   0.439   0.256   0.622   0.12  1.00
#       RM_HHMedianT_LLStd   XGB  0.542   0.365   0.719   0.75  0.48
#       RM_HHMedianT_GLSZMGLNU LR   0.299   0.127   0.472   0.12  0.94
#       RM_HHMedianT_GLSZMGLNU XGB  0.297   0.119   0.475   1.00  0.00
#       RM_HHMedianT_LHP25   LR   0.515   0.341   0.689   0.69  0.52
#       RM_HHMedianT_LHP25   XGB  0.664   0.512   0.816   0.94  0.45
#       RM_HHMedianT_GLCMClusterShade LR   0.398   0.214   0.582   0.12  0.94
#       RM_HHMedianT_GLCMClusterShade XGB  0.385   0.216   0.555   1.00  0.00
#       RM_LLIQRT_HHEnergy   LR   0.536   0.373   0.699   1.00  0.24
#       RM_LLIQRT_HHEnergy   XGB  0.517   0.336   0.698   0.44  0.76
#       RM_LLIQRT_LLStd      LR   0.426   0.247   0.605   0.19  0.91
#       RM_LLIQRT_LLStd      XGB  0.545   0.377   0.712   0.88  0.30
#       RM_LLIQRT_HLIQR      LR   0.502   0.321   0.683   0.50  0.64
#       RM_LLIQRT_HLIQR      XGB  0.307   0.142   0.471   1.00  0.00
#       RM_LLIQRT_GLSZMGLNU  LR   0.335   0.172   0.498   1.00  0.06
#       RM_LLIQRT_GLSZMGLNU  XGB  0.278   0.115   0.442   1.00  0.00
#       RM_LLIQRT_LHP25      LR   0.591   0.428   0.754   0.94  0.48
#       RM_LLIQRT_LHP25      XGB  0.725   0.577   0.873   0.75  0.73
#       RM_LLStd_HLIQR       LR   0.547   0.377   0.718   0.81  0.36
#       RM_LLStd_HLIQR       XGB  0.453   0.277   0.628   0.81  0.27
#       RM_LLStd_GLSZMGLNU   LR   0.403   0.232   0.575   0.81  0.21
#       RM_LLStd_GLSZMGLNU   XGB  0.429   0.254   0.603   0.50  0.55
#
# ===== LOGO-CV Top 10 Models (Overall CV AUC) =====
#             Feature_Set Algorithm CV_AUC CI_lo_95 CI_hi_95 Sensitivity
# 1       CRM_Jaw_HHRange       XGB  0.770    0.640    0.900       0.875
# 2  RM_HHRange_HHMedianT       XGB  0.740    0.595    0.884       0.875
# 3           SRM_HHRange       XGB  0.737    0.582    0.892       0.875
# 4        CRM_SP_HHRange       XGB  0.735    0.580    0.890       0.875
# 5       RM_LLIQRT_LHP25       XGB  0.725    0.577    0.873       0.750
# 6      CRM_Depth_LLIQRT       XGB  0.722    0.568    0.875       0.938
# 7       CRM_Depth_HLIQR        LR  0.716    0.554    0.878       0.688
# 8   CRM_Depth_HHMedianT       XGB  0.712    0.555    0.869       0.938
# 9     RM_HHRange_LLIQRT       XGB  0.711    0.551    0.871       0.688
# 10             CM_Depth        LR  0.707    0.555    0.860       0.938
#    Specificity                                       Features
# 1        0.576               Jaw_Code + Wav_HH_FO_Range_first
# 2        0.576 Wav_HH_FO_Range_first + Wav_HH_FO_Median_trend
# 3        0.576                          Wav_HH_FO_Range_first
# 4        0.576   Is_Single_Prosthesis + Wav_HH_FO_Range_first
# 5        0.727      Wav_LL_FO_IQR_trend + Wav_LH_FO_P25_first
# 6        0.576       Insertion_Depth_mm + Wav_LL_FO_IQR_trend
# 7        0.727       Insertion_Depth_mm + Wav_HL_FO_IQR_first
# 8        0.485    Insertion_Depth_mm + Wav_HH_FO_Median_trend
# 9        0.727    Wav_HH_FO_Range_first + Wav_LL_FO_IQR_trend
# 10       0.455                             Insertion_Depth_mm
#
# ✅ [Success] All category-specific LOGO-CV results and complete ROC data saved to:
# ➡️ /content/Results_R/9M_Cell9_LOGO_CV_Categorized.xlsx
#
# [CELL 10] Running Clinical Utility Validations...
#
# [1] Evaluating Calibration Metrics for ALL 104 Models...
#
# 🎉 [All Tasks Completed] Analysis successfully finished! Results saved to: /content/Results_R/9M_Cell10_ClinicalDefense_Categorized.xlsx
#
#
# ✅ All offsets complete.

# %% [markdown]
# ## 4b. Feature-level interaction analysis (manuscript Table 3)
#
# Offset-independent: uses all 245 raw timepoints (`raw`) built in the Data foundation step, not looped over `OFFSETS`. Tests `feature_z ~ group * ns(lead_yr, 2) + (1|Patient_ID) + (1|Implant_UID)` for the 10 v5 candidate radiomic features (8 static + 2 dynamic base names) to ask whether case/control trajectories diverge, and if so from how many years before surgery.
#
# Two cells: (1) fits the mixed models and produces `div_table` + the facet plot; (2) applies Benjamini-Hochberg (BH-FDR) and Bonferroni correction across the 10 interaction tests and exports the formatted `Table3_Interaction_FDR.xlsx`.

# %%
# ============================================================
# Lead-time longitudinal mixed model
#   - Uses raw timepoint-level data from the Data foundation step (apply_sensitivity_cutoff)
#   - lead_time reconstructed from Days_Since_Surgery
# ============================================================

# ---------- package check ----------
pkgs <- c("lme4", "lmerTest", "ggplot2", "dplyr", "purrr", "merTools")
to_install <- pkgs[!sapply(pkgs, requireNamespace, quietly = TRUE)]
if (length(to_install) > 0) install.packages(to_install)

library(lme4)
library(lmerTest)
library(splines)   # base/recommended package, usually no install needed
library(ggplot2)
library(merTools)
library(dplyr)
library(purrr)

# ---------- df_long construction ----------
# IMPORTANT:
# - use raw (not df_tp) because this is a timepoint-level trajectory model
# - Days_To_T0 was dropped inside apply_sensitivity_cutoff() (Data foundation step),
#   so reconstruct lead_time from Days_Since_Surgery

df_long <- raw %>%
  mutate(
    group = factor(ifelse(PI_MRONJ == 1, "Case", "Control"),
                   levels = c("Control", "Case")),
    lead_time = pmax(-Days_Since_Surgery, 0),   # days remaining to T0
    lead_yr   = lead_time / 365
  )

# Optional sanity check
cat("\n[df_long check]\n")
cat(sprintf("Rows: %d\n", nrow(df_long)))
cat(sprintf("Patients: %d\n", dplyr::n_distinct(df_long$Patient_ID)))
cat(sprintf("Implants: %d\n", dplyr::n_distinct(df_long$Implant_UID)))
cat(sprintf("Lead-time range (years): %.2f ~ %.2f\n",
            min(df_long$lead_yr, na.rm = TRUE),
            max(df_long$lead_yr, na.rm = TRUE)))

# ---------- features to test ----------
# NOTE:
# These are raw timepoint-level feature names (correct for df_long/raw)
champions <- c(
  "Wav_LL_FO_RMS",
  "Wav_HH_FO_Range",
  "Wav_HH_FO_Energy",
  "Wav_LL_FO_Std",
  "Wav_HL_FO_IQR",
  "GLSZM_GLNU",
  "GLCM_ClusterShade",
  "Wav_LH_FO_P25",
  "Wav_HH_FO_Median",
  "Wav_LL_FO_IQR"
)

# Check whether all feature columns exist
missing_feats <- setdiff(champions, names(df_long))
if (length(missing_feats) > 0) {
  stop("These features are missing in df_long/raw: ",
       paste(missing_feats, collapse = ", "))
}

# ---------- helper: robust model fit ----------
fit_div <- function(feat) {
  d <- df_long %>%
    select(Patient_ID, Implant_ID, Implant_UID, group, lead_yr, all_of(feat)) %>%
    rename(feature_value = all_of(feat)) %>%
    filter(!is.na(feature_value), !is.na(lead_yr), !is.na(group)) %>%
    mutate(y = as.numeric(scale(feature_value)))

  # feature variance check
  if (nrow(d) < 10 || sd(d$feature_value, na.rm = TRUE) == 0 || all(is.na(d$y))) {
    return(data.frame(
      Feature       = feat,
      Interaction_p = NA_real_,
      Group_p       = NA_real_,
      LeadTime_p    = NA_real_,
      N_timepoints  = nrow(d)
    ))
  }

  ct <- lmerControl(check.conv.singular = "ignore")

  # random effect:
  # using Implant_UID is safer because it is unique across whole dataset
  full <- tryCatch(
    lmer(y ~ group * ns(lead_yr, 2) + (1 | Patient_ID) + (1 | Implant_UID),
         data = d, REML = FALSE, control = ct),
    error = function(e) NULL
  )

  noInt <- tryCatch(
    lmer(y ~ group + ns(lead_yr, 2) + (1 | Patient_ID) + (1 | Implant_UID),
         data = d, REML = FALSE, control = ct),
    error = function(e) NULL
  )

  noGrp <- tryCatch(
    lmer(y ~ ns(lead_yr, 2) + (1 | Patient_ID) + (1 | Implant_UID),
         data = d, REML = FALSE, control = ct),
    error = function(e) NULL
  )

  noLT <- tryCatch(
    lmer(y ~ group + (1 | Patient_ID) + (1 | Implant_UID),
         data = d, REML = FALSE, control = ct),
    error = function(e) NULL
  )

  get_p <- function(m0, m1) {
    if (is.null(m0) || is.null(m1)) return(NA_real_)
    out <- tryCatch(anova(m0, m1), error = function(e) NULL)
    if (is.null(out) || !"Pr(>Chisq)" %in% names(out)) return(NA_real_)
    round(out$`Pr(>Chisq)`[2], 3)
  }

  data.frame(
    Feature       = feat,
    Interaction_p = get_p(noInt, full),   # divergence-onset
    Group_p       = get_p(noGrp, noInt),
    LeadTime_p    = get_p(noLT,  noInt),
    N_timepoints  = nrow(d)
  )
}

# ---------- run table ----------
div_table <- bind_rows(lapply(champions, fit_div))
print(div_table)

# ============================================================
# Visualization (facet by feature)
# ============================================================



grid_all_simple <- bind_rows(map(champions, function(feat) {

  d <- df_long %>%
    select(Patient_ID, Implant_UID, group, lead_yr, all_of(feat)) %>%
    rename(feature_value = all_of(feat)) %>%
    filter(!is.na(feature_value), !is.na(lead_yr), !is.na(group)) %>%
    mutate(y = as.numeric(scale(feature_value)))

  if (nrow(d) < 10 || sd(d$feature_value, na.rm = TRUE) == 0 || all(is.na(d$y))) {
    return(NULL)
  }

  m <- tryCatch(
    lmer(y ~ group * ns(lead_yr, 2) + (1 | Patient_ID) + (1 | Implant_UID),
         data = d, REML = FALSE,
         control = lmerControl(check.conv.singular = "ignore")),
    error = function(e) NULL
  )

  if (is.null(m)) return(NULL)

  grid <- expand.grid(
    lead_yr = seq(min(d$lead_yr, na.rm = TRUE),
                  max(d$lead_yr, na.rm = TRUE),
                  length.out = 60),
    group = factor(c("Control", "Case"), levels = c("Control", "Case"))
  )

  grid$fit <- predict(m, newdata = grid, re.form = NA)
  grid$Feature <- feat
  grid
}))

ggplot(grid_all_simple, aes(lead_yr, fit, color = group)) +
  geom_line(linewidth = 1) +
  scale_x_reverse() +
  facet_wrap(~ Feature, scales = "free_y") +
  scale_color_manual(values = c(Control = "#4575b4", Case = "#d73027")) +
  theme_classic(base_size = 11) +
  theme(legend.position = "top")
# Out:
# Registered S3 method overwritten by 'lme4':
#   method           from
#   na.action.merMod car
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘coda’, ‘furrr’, ‘arm’, ‘blme’, ‘broom.mixed’
#
#
#
# Attaching package: ‘lmerTest’
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
#
# The following object is masked from ‘package:stats’:
#
#     step
#
#
#
# Attaching package: ‘purrr’
#
#
# The following object is masked from ‘package:car’:
#
#     some
#
#
# The following object is masked from ‘package:caret’:
#
#     lift
#
#
# The following object is masked from ‘package:scales’:
#
#     discard
# [df_long check]
# Rows: 245
# Patients: 7
# Implants: 58
# Lead-time range (years): 0.00 ~ 5.28
#              Feature Interaction_p Group_p LeadTime_p N_timepoints
# 1      Wav_LL_FO_RMS         0.094   0.135      0.002          245
# 2    Wav_HH_FO_Range         0.143   0.604      0.004          245
# 3   Wav_HH_FO_Energy         0.116   0.342      0.000          245
# 4      Wav_LL_FO_Std         0.035   0.101      0.000          245
# 5      Wav_HL_FO_IQR         0.641   0.381      0.268          245
# 6         GLSZM_GLNU         0.095   0.362      0.408          245
# 7  GLCM_ClusterShade         0.589   0.546      0.222          245
# 8      Wav_LH_FO_P25         0.806   0.014      0.040          245
# 9   Wav_HH_FO_Median         0.999   0.085      0.930          245
# 10     Wav_LL_FO_IQR         0.084   0.296      0.017          245
# plot without title

# %%
# ============================================================
# Table 3 — Multiplicity correction + Excel export
#   Appends to the lead-time longitudinal mixed-model cell.
#   PREREQUISITE: `div_table` must already exist in the session
#   (produced by `bind_rows(lapply(champions, fit_div))`),
#   containing columns: Feature, Interaction_p, Group_p,
#   LeadTime_p, N_timepoints.
#
#   This block was NOT part of the original analysis cell; it adds
#   the Benjamini-Hochberg (BH-FDR) and Bonferroni corrections that
#   Table 3 reports, and exports the formatted table to .xlsx.
# ============================================================

# ---------- package check ----------
pkgs <- c("dplyr", "openxlsx")
to_install <- pkgs[!sapply(pkgs, requireNamespace, quietly = TRUE)]
if (length(to_install) > 0) install.packages(to_install)
library(dplyr)
library(openxlsx)

stopifnot(exists("div_table"))
stopifnot(all(c("Feature", "Interaction_p", "Group_p",
                "LeadTime_p", "N_timepoints") %in% names(div_table)))

# ---------- multiplicity correction (family = the 10 interaction tests) ----------
raw_p <- div_table$Interaction_p
ok    <- !is.na(raw_p)

bh   <- rep(NA_real_, length(raw_p))
bonf <- rep(NA_real_, length(raw_p))
bh[ok]   <- p.adjust(raw_p[ok], method = "BH")
bonf[ok] <- p.adjust(raw_p[ok], method = "bonferroni")

table3 <- div_table %>%
  mutate(
    Interaction_p_raw = round(Interaction_p, 3),
    Interaction_q_BH  = round(bh,   3),
    Interaction_p_Bonf= round(bonf, 3),
    Sig_raw           = ifelse(!is.na(Interaction_p) & Interaction_p < 0.05, "*", ""),
    Survives_BH_FDR   = ifelse(!is.na(bh)   & bh   < 0.05, "Yes", "No"),
    Survives_Bonf     = ifelse(!is.na(bonf) & bonf < 0.05, "Yes", "No")
  ) %>%
  arrange(Interaction_p_raw) %>%
  select(Feature, N_timepoints,
         Interaction_p_raw, Interaction_q_BH, Interaction_p_Bonf, Sig_raw,
         Survives_BH_FDR, Survives_Bonf,
         Group_p, LeadTime_p)

cat("\n================ TABLE 3 (verified) ================\n")
print(table3, row.names = FALSE)
cat(sprintf("\nFeatures tested                : %d\n", sum(ok)))
cat(sprintf("Raw interaction p < 0.05       : %d  (%s)\n",
            sum(raw_p < 0.05, na.rm = TRUE),
            paste(table3$Feature[table3$Sig_raw == "*"], collapse = ", ")))
cat(sprintf("Minimum raw interaction p      : %.3f\n", min(raw_p, na.rm = TRUE)))
cat(sprintf("Minimum BH-FDR q               : %.3f\n", min(bh,   na.rm = TRUE)))
cat(sprintf("Minimum Bonferroni p           : %.3f\n", min(bonf, na.rm = TRUE)))
cat(sprintf("Survive BH-FDR (q < 0.05)      : %d\n", sum(bh   < 0.05, na.rm = TRUE)))
cat(sprintf("Survive Bonferroni (p < 0.05)  : %d\n", sum(bonf < 0.05, na.rm = TRUE)))
cat("====================================================\n")

wb <- createWorkbook()
addWorksheet(wb, "Table3_Interaction")

title <- paste0("Table 3. Feature-level group x lead-time interaction ",
                "(linear mixed-effects models, ", sum(ok), " candidate radiomic features)")
writeData(wb, "Table3_Interaction", title, startRow = 1, startCol = 1)

hdr <- c("Feature", "N (timepoints)",
         "Interaction p (raw)", "BH-FDR q", "Bonferroni p", "Raw p<0.05",
         "Survives BH-FDR", "Survives Bonferroni", "Group p", "Lead-time p")
writeData(wb, "Table3_Interaction", t(hdr), startRow = 3, startCol = 1, colNames = FALSE)
writeData(wb, "Table3_Interaction", table3, startRow = 4, startCol = 1, colNames = FALSE)

foot_row <- 4 + nrow(table3) + 1
footnote <- paste0(
  "Model: feature_z ~ group * ns(lead_yr, 2) + (1|Patient) + (1|Implant); ",
  "ML fit; interaction tested by likelihood-ratio test. ",
  "Multiplicity corrected across the ", sum(ok),
  " interaction tests by Benjamini-Hochberg (BH-FDR) and Bonferroni. ",
  "feature_z, z-standardised feature; ns, natural cubic spline (2 df). ",
  "No feature survived either correction at q/p < 0.05.")
writeData(wb, "Table3_Interaction", footnote, startRow = foot_row, startCol = 1)

hs <- createStyle(textDecoration = "bold", halign = "center", valign = "center",
                  border = "TopBottom")
addStyle(wb, "Table3_Interaction", hs, rows = 3, cols = 1:length(hdr), gridExpand = TRUE)
addStyle(wb, "Table3_Interaction",
         createStyle(border = "bottom"),
         rows = 3 + nrow(table3) + 1, cols = 1:length(hdr), gridExpand = TRUE)
setColWidths(wb, "Table3_Interaction", cols = 1, widths = 20)
setColWidths(wb, "Table3_Interaction", cols = 2:length(hdr), widths = 14)

out <- file.path(SAVE_DIR, "Table3_Interaction_FDR.xlsx")
saveWorkbook(wb, out, overwrite = TRUE)
cat(sprintf("\nSaved: %s\n", normalizePath(out)))
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ================ TABLE 3 (verified) ================
#            Feature N_timepoints Interaction_p_raw Interaction_q_BH
#      Wav_LL_FO_Std          245             0.035            0.232
#      Wav_LL_FO_IQR          245             0.084            0.232
#      Wav_LL_FO_RMS          245             0.094            0.232
#         GLSZM_GLNU          245             0.095            0.232
#   Wav_HH_FO_Energy          245             0.116            0.232
#    Wav_HH_FO_Range          245             0.143            0.238
#  GLCM_ClusterShade          245             0.589            0.801
#      Wav_HL_FO_IQR          245             0.641            0.801
#      Wav_LH_FO_P25          245             0.806            0.896
#   Wav_HH_FO_Median          245             0.999            0.999
#  Interaction_p_Bonf Sig_raw Survives_BH_FDR Survives_Bonf Group_p LeadTime_p
#                0.35       *              No            No   0.101      0.000
#                0.84                      No            No   0.296      0.017
#                0.94                      No            No   0.135      0.002
#                0.95                      No            No   0.362      0.408
#                1.00                      No            No   0.342      0.000
#                1.00                      No            No   0.604      0.004
#                1.00                      No            No   0.546      0.222
#                1.00                      No            No   0.381      0.268
#                1.00                      No            No   0.014      0.040
#                1.00                      No            No   0.085      0.930
#
# Features tested                : 10
# Raw interaction p < 0.05       : 1  (Wav_LL_FO_Std)
# Minimum raw interaction p      : 0.035
# Minimum BH-FDR q               : 0.232
# Minimum Bonferroni p           : 0.350
# Survive BH-FDR (q < 0.05)      : 0
# Survive Bonferroni (p < 0.05)  : 0
# ====================================================
#
# Saved: /content/Results_R/Table3_Interaction_FDR.xlsx

# %% [markdown]
# ## 5. Figure generation (from the one-click outputs)
# Runs after the loop so the figures read the freshly produced `{offset}M_*` spreadsheets.

# %%
# ==============================================================================
# ╔══════════════════════════════════════════════════════════════╗
# ║   FIGURE 3 — Automated AUC Trend Plot (v4 Categorized Style) ║
# ╚══════════════════════════════════════════════════════════════╝

# ── Font & package setup ──────────────────────────────────────
if(!require(showtext)) install.packages("showtext")
library(showtext)

# load the Arimo font under the name "Arial"
font_add_google(name = "Arimo", family = "Arial")
showtext_auto()
showtext_opts(dpi = 600) # for high-resolution output

suppressPackageStartupMessages({
  library(readxl)
  library(dplyr)
  library(purrr)
  library(ggplot2)
  library(patchwork)
  library(svglite)
})

# --- [prerequisite] specify the path where files are saved ---
SAVE_DIR <- "/content/Results_R"

# ── 1) Automated data extraction (reflects the v4 _Categorized structure) ──

# mapping of the newly split Excel files output by Cell 8
offsets_info <- list(
  list(file = "0M_Cell8_2Algo_Boot_Categorized.xlsx", offset = 0),
  list(file = "3M_Cell8_2Algo_Boot_Categorized.xlsx", offset = 3),
  list(file = "6M_Cell8_2Algo_Boot_Categorized.xlsx", offset = 6),
  list(file = "9M_Cell8_2Algo_Boot_Categorized.xlsx", offset = 9)
)

# internal model ID (Feature_Set) -> manuscript-style italic + subscript label (plotmath expression)
name_map_expr <- list(
  "CM_Depth"              = expression(bold(CM)[bold(Depth)]),

  "CRM_Depth_LHP25"       = expression(bold(CRM)[bold("Depth+LH-P25")]),
  "CRM_Depth_HHMedianT"   = expression(bold(CRM)[bold("Depth+\u0394HH-Median")]),

  "RM_LLIQRT_LHP25"       = expression(bold(RM)[bold("LH-P25+\u0394LL-IQR")]),
  "RM_HHRange_LLStd"      = expression(bold(RM)[bold("HH-Range+LL-Std")]),

  "SRM_LHP25"             = expression(bold(SRM)[bold("LH-P25")])
)

# for color mapping / factor ordering — uses the internal ID as-is (only the label is converted to an expression)

model_order <- c(
  "CM_Depth",
  "CRM_Depth_LHP25",
  "CRM_Depth_HHMedianT",
  "RM_LLIQRT_LHP25",
  "RM_HHRange_LLStd",
  "SRM_LHP25"
)


# function to extract data from Excel
extract_auc_trend <- function(info) {
  file_path <- file.path(SAVE_DIR, info$file)

  if (!file.exists(file_path)) {
    warning(sprintf("⚠️ File not found: %s", info$file))
    return(NULL)
  }

  # read the All_Results sheet
  df <- read_excel(file_path, sheet = "All_Results")

  df %>%
    filter(Feature_Set %in% model_order) %>%
    mutate(
      Model = factor(Feature_Set, levels = model_order),  # keep the internal ID as the factor
      Offset = info$offset,
      AUC = as.numeric(AUC_Adjusted)
    ) %>%
    select(Model, Algorithm, Offset, AUC)
}

# combine data across the 4 timepoints
fig3_data <- map_df(offsets_info, extract_auc_trend)

# ── 2) Visualization settings (color palette matching the DCA figure) ──

model_colors <- c(
  "CM_Depth"               = "#D62728", # red (CM)

  "CRM_Depth_LHP25"        = "#FF7F0E", # orange (CRM Static)
  "CRM_Depth_HHMedianT"    = "#A65628", # brown (CRM Dynamic)

  "RM_LLIQRT_LHP25"        = "#984EA3", # purple (RM 1; ΔLL-IQR)
  "RM_HHRange_LLStd"       = "#1F77B4", # blue (RM 2; Range+Std)

  "SRM_LHP25"              = "#4DAF4A"  # green (SRM)
)


# ── 3) Shared theme (inherits the Figure 4 manuscript style) ──
fig4_style <- theme_minimal() +
  theme(
    text             = element_text(family = "Arial"),
    plot.title       = element_text(size = 20, face = "bold",
                                    hjust = 0,
                                    margin = ggplot2::margin(b = 10)),
    axis.title.y = element_text(size = 14, face = "bold",
                                 margin = ggplot2::margin(r = 10)),
    axis.title.x = element_text(size = 14, face = "bold",
                                 margin = ggplot2::margin(t = 10)),
    axis.text        = element_text(size = 12, color = "black"),

    # grid guidelines
    panel.grid.major = element_line(color = "gray88", linewidth = 0.4),
    panel.grid.minor = element_blank(),

    # border and axis-line settings
    panel.border    = element_blank(),
    axis.line       = element_line(color = "black", linewidth = 0.5),

    # panel background
    plot.background  = element_rect(fill = "white", color = NA),
    panel.background = element_rect(fill = "white", color = NA),

    plot.margin     = ggplot2::margin(t = 18, r = 10, b = 18, l = 10, unit = "pt"),

    # legend formatting
    legend.position  = "bottom",
    legend.title     = element_blank(),
    legend.text      = element_text(size = 12, face = "bold"),
    legend.key.width = unit(1.6, "cm"),
    legend.spacing.x = unit(0.5, "cm"),
    legend.margin    = ggplot2::margin(t = 10, b = 5)
  )

# ── 4) Generate per-algorithm panels ─────────────────────────────────────

# LR Panel (revised)
p_lr <- ggplot(filter(fig3_data, Algorithm == "LR"),
               aes(x = Offset, y = AUC, color = Model, group = Model)) +
  geom_line(linewidth = 0.9) +
  geom_point(shape = 16, size = 2.5) +
  scale_color_manual(values = model_colors, labels = name_map_expr) +
  scale_x_reverse(breaks = c(9, 6, 3, 0), labels = c("9M", "6M", "3M", "0M")) +
  scale_y_continuous(
    limits = c(0.45, 0.85),
    breaks = seq(0.45, 0.85, 0.10)   # ★ 0.45, 0.55, 0.65, 0.75, 0.85
  ) +
  labs(title = "(A) Logistic Regression",
       x = "Offset (Months Before Surgery)",
       y = "Optimism-corrected AUC") +
  fig4_style

# XGB Panel (revised)
p_xgb <- ggplot(filter(fig3_data, Algorithm == "XGB"),
                aes(x = Offset, y = AUC, color = Model, group = Model)) +
  geom_line(linewidth = 0.9) +
  geom_point(shape = 16, size = 2.5) +
  scale_color_manual(values = model_colors, labels = name_map_expr) +
  scale_x_reverse(breaks = c(9, 6, 3, 0), labels = c("9M", "6M", "3M", "0M")) +
  scale_y_continuous(
    limits = c(0.70, 0.90),
    breaks = seq(0.70, 0.90, 0.05)   # ★ 0.75, 0.80, 0.85, 0.90, 0.95
  ) +
  labs(title = "(B) XGBoost",
       x = "Offset (Months Before Surgery)",
       y = "Optimism-corrected AUC") +
  fig4_style

# ── 5) Combine panels and build high-resolution output ───────────────────

fig3_final <- p_lr + p_xgb +
  plot_layout(guides = "collect") &
  theme(legend.position = "bottom") &
  guides(color = guide_legend(
    nrow = 2, byrow = TRUE,
    override.aes = list(linewidth = 1.2, size = 3)
  ))

# 600 DPI, lossless LZW-compressed output
ggsave(file.path(SAVE_DIR, "Figure3_AUC_Trend_Final.tiff"), fig3_final, width=12, height=6, dpi=600, compression="lzw")
ggsave(file.path(SAVE_DIR, "Figure3_AUC_Trend_Final.pdf"), fig3_final, width=12, height=6)
ggsave(file.path(SAVE_DIR, "Figure3_AUC_Trend_Final.svg"), fig3_final, width=12, height=6, device = svglite::svglite)

cat("\n✅ [Success] Figure 3 saved, fully synced with the updated Excel results (TIFF, PDF, SVG).")
# Out:
# ✅ [Success] Figure 3 saved, fully synced with the updated Excel results (TIFF, PDF, SVG).

# %%
# ╔══════════════════════════════════════════════════════════════╗
# ║  FIGURE 4 — 2×2 + bottom legend                             ║
# ║  - Input: v4 _Categorized.xlsx (Cell 9 output)               ║
# ║  - Filtering: extracts only the Top 6 pre-specified models (12 lines) for plotting║
# ║  - Legend: bottom-left aligned (Left=LR, Right=XGB)          ║
# ║  - XGB marker: plain "*" (avoids a TIFF encoding error)      ║
# ╚══════════════════════════════════════════════════════════════╝

suppressPackageStartupMessages({
  library(dcurves)
  library(ggplot2)
  library(readxl)
  library(cowplot)
})

# load required packages
if(!require(showtext)) install.packages("showtext")
library(showtext)

# make R recognize Arial among the system fonts
font_add_google("Arimo", "Arimo")
showtext_auto()
showtext_opts(dpi = 600)

# --- [prerequisite] specify the path where files are saved ---
SAVE_DIR <- "/content/Results_R"

# ── 1) Labels — bold + subscript expression list ─────────────
ace_model_labels <- list(
  "CM_Depth_LR"               = expression(bold(CM)[bold(Depth)] * " (LR)"),
  "CM_Depth_XGB"              = expression(bold(CM)[bold(Depth)] * " (XGB)"^"*"),

  "CRM_Depth_LHP25_LR"        = expression(bold(CRM)[bold("Depth+LH-P25")] * " (LR)"),
  "CRM_Depth_LHP25_XGB"       = expression(bold(CRM)[bold("Depth+LH-P25")] * " (XGB)"^"*"),

  "CRM_Depth_HHMedianT_LR"    = expression(bold(CRM)[bold("Depth+\u0394HH-Median")] * " (LR)"),
  "CRM_Depth_HHMedianT_XGB"   = expression(bold(CRM)[bold("Depth+\u0394HH-Median")] * " (XGB)"^"*"),

  "RM_LLIQRT_LHP25_LR"        = expression(bold(RM)[bold("LH-P25+\u0394LL-IQR")] * " (LR)"),
  "RM_LLIQRT_LHP25_XGB"       = expression(bold(RM)[bold("LH-P25+\u0394LL-IQR")] * " (XGB)"^"*"),

  "RM_HHRange_LLStd_LR"       = expression(bold(RM)[bold("HH-Range+LL-Std")] * " (LR)"),
  "RM_HHRange_LLStd_XGB"      = expression(bold(RM)[bold("HH-Range+LL-Std")] * " (XGB)"^"*"),

  "SRM_LHP25_LR"              = expression(bold(SRM)[bold("LH-P25")] * " (LR)"),
  "SRM_LHP25_XGB"             = expression(bold(SRM)[bold("LH-P25")] * " (XGB)"^"*")
)

# ── 2) Colors (keeps the original golden-ratio palette) ─────────
dca_colors <- c(
  "Treat All"                 = "darkgray",
  "Treat None"                = "black",

  "CM_Depth_LR"               = "#D62728",
  "CM_Depth_XGB"              = "#D62728",

  "CRM_Depth_LHP25_LR"        = "#FF7F0E",
  "CRM_Depth_LHP25_XGB"       = "#FF7F0E",

  "CRM_Depth_HHMedianT_LR"    = "#A65628",
  "CRM_Depth_HHMedianT_XGB"   = "#A65628",

  "RM_LLIQRT_LHP25_LR"        = "#984EA3",
  "RM_LLIQRT_LHP25_XGB"       = "#984EA3",

  "RM_HHRange_LLStd_LR"       = "#1F77B4",
  "RM_HHRange_LLStd_XGB"      = "#1F77B4",

  "SRM_LHP25_LR"              = "#4DAF4A",
  "SRM_LHP25_XGB"             = "#4DAF4A"
)

# ── 3) Linetypes (XGB uses "22" dashed, LR uses "solid") ────────
dca_linetypes <- c(
  "Treat All"                 = "solid",
  "Treat None"                = "solid",

  "CM_Depth_LR"               = "solid",
  "CM_Depth_XGB"              = "22",

  "CRM_Depth_LHP25_LR"        = "solid",
  "CRM_Depth_LHP25_XGB"       = "22",

  "CRM_Depth_HHMedianT_LR"    = "solid",
  "CRM_Depth_HHMedianT_XGB"   = "22",

  "RM_LLIQRT_LHP25_LR"        = "solid",
  "RM_LLIQRT_LHP25_XGB"       = "22",

  "RM_HHRange_LLStd_LR"       = "solid",
  "RM_HHRange_LLStd_XGB"      = "22",

  "SRM_LHP25_LR"              = "solid",
  "SRM_LHP25_XGB"             = "22"
)

# Treat All / Treat None stay as plain strings; model labels are expressions
legend_labels <- c(
  list("Treat All" = "Treat All", "Treat None" = "Treat None"),
  ace_model_labels
)
legend_breaks <- names(dca_colors)

# ── 4) Panel function (applies the logic that extracts Top 6 of 60) ──
make_native_dca <- function(file_path, panel_title) {

  if (!file.exists(file_path)) {
    warning(sprintf("⚠️ File not found: %s", file_path))
    return(NULL)
  }

  # load the sheet containing predicted probabilities for all 60 models
  df_prob <- read_excel(file_path, sheet = "Probabilities")

  # 🚨 [key fix] extract only the Event column and columns matching ace_models (avoids spaghetti plots)
  target_cols <- c("Event", names(ace_model_labels))
  df_prob <- df_prob[, target_cols]

  # build the formula
  models  <- names(ace_model_labels)
  dca_formula <- as.formula(paste("Event ~", paste(models, collapse = " + ")))
  dca_res <- dcurves::dca(dca_formula, data = df_prob)

  p <- plot(dca_res, smooth = TRUE) +
    aes(linetype = label) +
    scale_color_manual(values = dca_colors, labels = legend_labels, breaks = legend_breaks) +
    scale_linetype_manual(values = dca_linetypes, labels = legend_labels, breaks = legend_breaks) +
    scale_x_continuous(breaks = seq(0, 0.75, by = 0.1), expand = c(0, 0)) +
    coord_cartesian(xlim = c(0, 0.75), ylim = c(-0.1, 0.35)) +
    labs(title = panel_title, x = "Risk Threshold", y = "Net Benefit") +
    theme_minimal() +
    theme(
    text = element_text(family = "Arimo"),
    plot.title  = element_text(size = 18, face = "bold", hjust = 0, margin = ggplot2::margin(b = 10)),
    axis.title  = element_text(size = 14, face = "bold"),
    axis.text   = element_text(size = 12, color = "black"),                    # ★ added
    panel.grid.major = element_line(color = "gray88", linewidth = 0.4),       # (optional) matches Figure 3
    panel.grid.minor = element_blank(),                                        # (optional) matches Figure 3
    legend.position = "none",
    plot.background  = element_rect(fill = "white", color = NA),
    panel.background = element_rect(fill = "white", color = NA),
    plot.margin = ggplot2::margin(t = 18, r = 8, b = 18, l = 8, unit = "pt")
  )

}

# ── 5) Render 4 panels (reflects the revised Categorized filenames) ──
offsets <- list(
  list(file = "0M_Cell10_ClinicalDefense_Categorized.xlsx", title = "(A) 0-month offset from surgery"),
  list(file = "3M_Cell10_ClinicalDefense_Categorized.xlsx", title = "(B) 3-month offset from surgery"),
  list(file = "6M_Cell10_ClinicalDefense_Categorized.xlsx", title = "(C) 6-month offset from surgery"),
  list(file = "9M_Cell10_ClinicalDefense_Categorized.xlsx", title = "(D) 9-month offset from surgery")
)

panels <- lapply(offsets, function(o) make_native_dca(file.path(SAVE_DIR, o$file), o$title))

# ── 6) left aligned, 2 columns grouped ─
lr_keys  <- grep("_LR$",  legend_breaks, value = TRUE)
xgb_keys <- grep("_XGB$", legend_breaks, value = TRUE)

legend_breaks <- c("Treat All", lr_keys, "Treat None", xgb_keys)
legend_breaks <- legend_breaks[legend_breaks %in% legend_breaks]
legend_labels <- legend_labels[legend_breaks]

legend_dummy <- data.frame(
  x = rep(c(1, 2), times = length(legend_breaks)),
  y = rep(c(1, 2), times = length(legend_breaks)),
  model = factor(rep(legend_breaks, each = 2), levels = legend_breaks)
)

p_legend <- ggplot(legend_dummy, aes(x = x, y = y, color = model, linetype = model, group = model)) +
  geom_line(linewidth = 1.1) +
  scale_color_manual(values = dca_colors,   breaks = legend_breaks, labels = legend_labels) +
  scale_linetype_manual(values = dca_linetypes, breaks = legend_breaks, labels = legend_labels) +
  theme_void() +
  theme(
  text = element_text(family = "Arimo"),
  legend.position = "bottom",
  legend.justification = "left",
  legend.box.just = "left",
  legend.title = element_blank(),
  legend.text  = element_text(size = 13, face = "bold", margin = ggplot2::margin(r = 22)),  # ★ 13pt
  legend.box.margin = ggplot2::margin(t = -4, r = 0, b = -4, l = 4, unit = "pt"),
  legend.key.width = unit(1.8, "cm"),
  legend.spacing.y = unit(0.15, "cm")
) +
  guides(
    color    = guide_legend(ncol = 2, byrow = FALSE),
    linetype = guide_legend(ncol = 2, byrow = FALSE)
  )

shared_legend <- get_legend(p_legend)

# ── 7) Assemble: 2×2 panels + bottom-left legend ───────────────
row_plots <- plot_grid(
  panels[[1]], panels[[2]],
  panels[[3]], panels[[4]],
  ncol = 2, align = "hv"
)

row_legend <- plot_grid(shared_legend, ncol = 1, align = "h")

fig4_final <- plot_grid(
  row_plots,
  row_legend,
  ncol = 1,
  rel_heights = c(1, 0.30)
)

# ── 8) Export  ───────────────────────────────────
tiff_path <- file.path(SAVE_DIR, "Figure4_DCA_Final.tiff")
pdf_path  <- file.path(SAVE_DIR, "Figure4_DCA_Final.pdf")
svg_path  <- file.path(SAVE_DIR, "Figure4_DCA_Final.svg")

FIG_W <- 12
FIG_H <- 15

if (requireNamespace("ragg", quietly = TRUE)) {
  ggsave(tiff_path, fig4_final, width = FIG_W, height = FIG_H, units = "in",
         dpi = 600, compression = "lzw", bg = "white",
         device = ragg::agg_tiff)
} else {
  ggsave(tiff_path, fig4_final, width = FIG_W, height = FIG_H, units = "in",
         dpi = 600, compression = "lzw", bg = "white")
}

ggsave(pdf_path, fig4_final, width = FIG_W, height = FIG_H, units = "in", bg = "white")
ggsave(svg_path, fig4_final, width = FIG_W, height = FIG_H, units = "in", device = svglite::svglite, bg = "white")

cat(sprintf("\n✅ Figure 4 (DCA 2x2 Panels) successfully saved:\n 📍 TIFF: %s\n 📍 PDF: %s\n 📍 SVG: %s\n", tiff_path, pdf_path, svg_path))
# Out:
# Assuming '1' is [Event] and '0' is [non-Event]
#
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Coordinate system already present.
# ℹ Adding new coordinate system, which will replace the existing one.
# Assuming '1' is [Event] and '0' is [non-Event]
#
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Coordinate system already present.
# ℹ Adding new coordinate system, which will replace the existing one.
# Assuming '1' is [Event] and '0' is [non-Event]
#
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Coordinate system already present.
# ℹ Adding new coordinate system, which will replace the existing one.
# Assuming '1' is [Event] and '0' is [non-Event]
#
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# Coordinate system already present.
# ℹ Adding new coordinate system, which will replace the existing one.
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# ...
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “font family 'Arimo' not found in PostScript font database”
# ✅ Figure 4 (DCA 2x2 Panels) successfully saved:
#  📍 TIFF: /content/Results_R/Figure4_DCA_Final.tiff
#  📍 PDF: /content/Results_R/Figure4_DCA_Final.pdf
#  📍 SVG: /content/Results_R/Figure4_DCA_Final.svg

# %%
# ╔══════════════════════════════════════════════════════════════╗
# ║  FIGURE S2 — Offset Stability Heatmap (v4 Categorized Sync)  ║
# ╚══════════════════════════════════════════════════════════════╝

suppressPackageStartupMessages({
  library(ggplot2)
  library(dplyr)
  library(tidyr)
  library(patchwork)
  library(svglite)
  library(showtext)
  library(readxl)
})

SAVE_DIR <- "/content/Results_R"

# ── 1. Font & resolution setup ────────────────────────────────────
font_add_google(name = "Arimo", family = "Arial")
showtext_auto()
showtext_opts(dpi = 600) # keeps font size in sync at high resolution

# ── 2. Data setup (reflects the v4 lineup and latest _Categorized files) ──────
model_order <- c(
  "CM_Depth",
  "CRM_Depth+LH-P25",
  "CRM_Depth+\u0394HH-Median",
  "RM_LH-P25+\u0394LL-IQR",
  "RM_HH-Range+LL-Std",
  "SRM_LH-P25"
)


# apply plotmath syntax: italic(Base[Subscript])

model_labels_formatted <- c(
  "CM_Depth"                = expression(italic(CM[Depth])),

  "CRM_Depth+LH-P25"        = expression(italic(CRM[Depth*"+"*"LH-P25"])),
  "CRM_Depth+\u0394HH-Median"  = expression(italic(CRM[Depth*"+"*Delta*"HH-Median"])),

  "RM_LH-P25+\u0394LL-IQR"  = expression(italic(RM["LH-P25"*"+"*Delta*"LL-IQR"])),
  "RM_HH-Range+LL-Std"      = expression(italic(RM["HH-Range"*"+"*"LL-Std"])),

  "SRM_LH-P25"              = expression(italic(SRM["LH-P25"]))
)


# 🚨 [revised] added the Categorized Excel filenames (synced to Cell 8 v4 output)
offsets_info <- list(
  list(file = "0M_Cell8_2Algo_Boot_Categorized.xlsx", offset_label = "0M"),
  list(file = "3M_Cell8_2Algo_Boot_Categorized.xlsx", offset_label = "3M"),
  list(file = "6M_Cell8_2Algo_Boot_Categorized.xlsx", offset_label = "6M"),
  list(file = "9M_Cell8_2Algo_Boot_Categorized.xlsx", offset_label = "9M")
)

# internal ID (the Excel Feature_Set column) -> display name mapping for the plot

name_map <- c(
  "CM_Depth"               = "CM_Depth",

  "CRM_Depth_LHP25"        = "CRM_Depth+LH-P25",
  "CRM_Depth_HHMedianT"    = "CRM_Depth+\u0394HH-Median",

  "RM_LLIQRT_LHP25"        = "RM_LH-P25+\u0394LL-IQR",
  "RM_HHRange_LLStd"       = "RM_HH-Range+LL-Std",

  "SRM_LHP25"              = "SRM_LH-P25"
)


# extract both AUC_Adjusted and Optimism values from each Excel file
extract_heatmap_data <- function(info) {
  file_path <- file.path(SAVE_DIR, info$file)

  if (!file.exists(file_path)) {
    warning(sprintf("⚠️ File not found: %s", info$file))
    return(NULL)
  }

  df <- read_excel(file_path, sheet = "All_Results")

  df %>%
    filter(Feature_Set %in% names(name_map)) %>%
    mutate(
      Model = factor(name_map[Feature_Set], levels = model_order),
      Offset = info$offset_label,
      AUC = as.numeric(AUC_Adjusted),
      Opt = as.numeric(Optimism),
      Algorithm = factor(Algorithm, levels = c("LR", "XGB"))
    ) %>%
    select(Model, Algorithm, Offset, AUC, Opt)
}

# combine the 4 files
auc_data_all <- map_df(offsets_info, extract_heatmap_data)

# preprocess data for the heatmap
offsets_order <- c("9M", "6M", "3M", "0M")

df_heat <- auc_data_all %>%
  mutate(
    Model     = factor(Model, levels = rev(model_order)), # reversed so rows print top-to-bottom in order
    Offset    = factor(Offset, levels = offsets_order),
    Algorithm = factor(Algorithm, levels = c("LR","XGB")),
    # when Opt > 0.10, apply an overfitting dagger (†) superscript and bold formatting
    Label     = ifelse(Opt > 0.10, sprintf("bold('%.3f')^'\u2020'", AUC), sprintf("bold('%.3f')", AUC)),
    # auto-invert text color based on the AUC value (for contrast against the background)
    TextColor = ifelse(AUC >= 0.850 | AUC <= 0.550, "white", "black")
  )

# ── 3. Plot function (adjusts legend text position and x-axis title) ─────────
make_heatmap <- function(data, algo_label, show_y = TRUE, show_legend = FALSE) {
  p <- ggplot(data, aes(x = Offset, y = Model, fill = AUC)) +
    geom_tile(color = "white", linewidth = 0.8) +
    geom_text(aes(label = Label, color = TextColor), size = 4, family = "Arial", parse = TRUE) +
    scale_fill_gradientn(
      colours = c("#4575b4", "#74add1", "#abd9e9", "#e0f3f8", "#fee090", "#fdae61", "#f46d43", "#d73027"),
      limits  = c(0.45, 0.90),
      name    = "AUC\n(Opt-corrected)",
      guide   = guide_colorbar(barwidth = 1.0, barheight = 10, title.position = "top", title.hjust = 0.5)
    ) +
    scale_color_identity() +
    scale_y_discrete(labels = model_labels_formatted) +
    scale_x_discrete(labels = offsets_order) +
    labs(title = algo_label, x = "Offset (Months Before Surgery)", y = NULL) +
    coord_fixed(ratio = 1) +
    theme_minimal(base_family = "Arial") +
    theme(
      plot.title       = element_text(size=16, face="bold", hjust=0.5, margin=ggplot2::margin(b=10)),
      axis.text.x      = element_text(size=12, color="black", face="bold"),
      axis.text.y      = if(show_y) element_text(size=12, color="black", hjust=1) else element_blank(),
      axis.title.x     = element_text(size=11, face="bold", margin=ggplot2::margin(t=10)),
      panel.grid       = element_blank(),
      legend.position  = if(show_legend) "right" else "none",
      legend.title     = element_text(size=12, face="bold"),
      legend.text      = element_text(size=11, vjust = 1.5),
      plot.margin      = ggplot2::margin(10, 5, 10, 5, "pt"),
      plot.background  = element_rect(fill="white", color=NA),
      panel.background = element_rect(fill="white", color=NA)
    )
  return(p)
}

# ── 4. Generate and combine panels ─────────────────────────────────
p_lr  <- make_heatmap(filter(df_heat, Algorithm == "LR"),  "(A) Logistic Regression", show_y = TRUE,  show_legend = FALSE)
p_xgb <- make_heatmap(filter(df_heat, Algorithm == "XGB"), "(B) XGBoost",             show_y = FALSE, show_legend = TRUE)

figS2_final <- p_lr + p_xgb + plot_layout(guides = "collect")

# ── 5. Save (matrix enlarged by adjusting the canvas size) ────────────
FIG_W <- 12
FIG_H <- 8

ggsave(file.path(SAVE_DIR, "FigureS2_Heatmap_Final.tiff"), figS2_final, width=FIG_W, height=FIG_H, units="in", dpi=600, compression="lzw", bg="white")
ggsave(file.path(SAVE_DIR, "FigureS2_Heatmap_Final.pdf"),  figS2_final, width=FIG_W, height=FIG_H, units="in", bg="white")
ggsave(file.path(SAVE_DIR, "FigureS2_Heatmap_Final.svg"),  figS2_final, width=FIG_W, height=FIG_H, units="in", device=svglite::svglite, bg="white")

cat("✅ Figure S2: synced with Categorized files and plotted (TIFF, PDF, SVG)\n")
# Out:
# ✅ Figure S2: synced with Categorized files and plotted (TIFF, PDF, SVG)

# %% [markdown]
# ## 6. Session info (reproducibility record)

# %%
sessionInfo()
cat("\n--- key package versions ---\n")
for (p in c("geepack","survival","rms","pROC","caret","xgboost","dcurves",
            "ResourceSelection","writexl","readxl","dplyr","ggplot2")) {
  v <- tryCatch(as.character(packageVersion(p)), error=function(e) "NOT INSTALLED")
  cat(sprintf("  %-18s %s\n", p, v))
}
# Out:
# R version 4.6.0 (2026-04-24)
# Platform: x86_64-pc-linux-gnu
# Running under: Ubuntu 22.04.5 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/openblas-pthread/libblas.so.3
# LAPACK: /usr/lib/x86_64-linux-gnu/openblas-pthread/libopenblasp-r0.3.20.so;  LAPACK version 3.10.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Etc/UTC
# tzcode source: system (glibc)
#
# attached base packages:
# [1] splines   stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] showtext_0.9-8          showtextdb_3.0          sysfonts_0.8.9
#  [4] openxlsx_4.2.8.1        purrr_1.2.2             merTools_1.0.0
#  [7] lmerTest_3.2-1          lme4_2.0-1              ggbreak_0.1.7
# [10] svglite_2.2.2           patchwork_1.3.2         randomForest_4.7-1.2
# [13] ResourceSelection_0.3-6 RColorBrewer_1.1-3      corrplot_0.95
# [16] dcurves_0.5.1           ggcorrplot_0.1.4.1      car_3.1-5
# [19] carData_3.0-5           xgboost_3.2.1.1         e1071_1.7-17
# [22] caret_7.0-1             lattice_0.22-9          writexl_1.5.4
# [25] viridis_0.6.5           viridisLite_0.4.3       ggrepel_0.9.8
# [28] tableone_0.13.2         cowplot_1.2.0           gridExtra_2.3.1
# [31] scales_1.4.0            rms_8.1-1               Hmisc_5.2-6
# [34] pROC_1.19.0.1           glmnet_5.0              Matrix_1.7-5
# [37] survminer_0.5.2         ggpubr_0.6.3            survival_3.8-6
# [40] geepack_1.3.13          ggplot2_4.0.3           tidyr_1.3.2
# [43] dplyr_1.2.1             readxl_1.5.0
#
# loaded via a namespace (and not attached):
#   [1] pbdZMQ_0.3-14        polspline_1.1.25     ggplotify_0.1.3
#   [4] tibble_3.3.1         cellranger_1.1.0     hardhat_1.4.3
#   [7] rpart_4.1.27         lifecycle_1.0.5      Rdpack_2.6.6
#  [10] rstatix_0.7.3        globals_0.19.1       MASS_7.3-65
#  [13] backports_1.5.1      survey_4.5           magrittr_2.0.5
#  [16] rmarkdown_2.31       otel_0.2.0           zip_2.3.3
#  [19] DBI_1.3.0            minqa_1.2.8          lubridate_1.9.5
#  [22] multcomp_1.4-30      abind_1.4-8          yulab.utils_0.2.4
#  [25] nnet_7.3-20          TH.data_1.1-5        rappdirs_0.3.4
#  [28] sandwich_3.1-1       ipred_0.9-15         lava_1.9.2
#  [31] listenv_1.0.0        arm_1.15-3           MatrixModels_0.5-4
#  [34] parallelly_1.48.0    codetools_0.2-20     tidyselect_1.2.1
#  [37] shape_1.4.6.1        aplot_0.3.0          farver_2.1.2
#  [40] broom.mixed_0.2.9.7  stats4_4.6.0         base64enc_0.1-6
#  [43] jsonlite_2.0.0       Formula_1.2-5        iterators_1.0.14
#  [46] systemfonts_1.3.2    foreach_1.5.2        tools_4.6.0
#  [49] ragg_1.5.2           blme_1.0-7           Rcpp_1.1.1-1.1
#  [52] glue_1.8.1           prodlim_2026.03.11   mgcv_1.9-4
#  [55] xfun_0.58            IRdisplay_1.1        withr_3.0.2
#  [58] numDeriv_2016.8-1.1  fastmap_1.2.0        mitools_2.4
#  [61] boot_1.3-32          SparseM_1.84-2       digest_0.6.39
#  [64] timechange_0.4.0     R6_2.6.1             gridGraphics_0.5-1
#  [67] textshaping_1.0.5    colorspace_2.1-2     utf8_1.2.6
#  [70] generics_0.1.4       data.table_1.18.4    recipes_1.3.3
#  [73] class_7.3-23         htmlwidgets_1.6.4    ModelMetrics_1.2.2.2
#  [76] pkgconfig_2.0.3      gtable_0.3.6         timeDate_4052.112
#  [79] S7_0.2.2             furrr_0.4.0          htmltools_0.5.9
#  [82] gower_1.0.2          reformulas_0.4.4     ggfun_0.2.0
#  [85] knitr_1.51           rstudioapi_0.18.0    reshape2_1.4.5
#  [88] uuid_1.2-2           curl_7.1.0           coda_0.19-4.1
#  [91] checkmate_2.3.4      nlme_3.1-169         nloptr_2.2.1
#  [94] repr_1.1.7           proxy_0.4-29         zoo_1.8-15
#  [97] stringr_1.6.0        parallel_4.6.0       foreign_0.8-91
# [100] pillar_1.11.1        grid_4.6.0           vctrs_0.7.3
# [103] cluster_2.1.8.2      htmlTable_2.5.0      evaluate_1.0.5
# [106] mvtnorm_1.4-1        cli_3.6.6            compiler_4.6.0
# [109] rlang_1.2.0          crayon_1.5.3         future.apply_1.20.2
# [112] ggsignif_0.6.4       labeling_0.4.3       forcats_1.0.1
# [115] plyr_1.8.9           fs_2.1.0             stringi_1.8.7
# [118] quantreg_6.1         IRkernel_1.3.2       future_1.70.0
# [121] rbibutils_2.4.1      broom_1.0.13
# --- key package versions ---
#   geepack            1.3.13
#   survival           3.8.6
#   rms                8.1.1
#   pROC               1.19.0.1
#   caret              7.0.1
#   xgboost            3.2.1.1
#   dcurves            0.5.1
#   ResourceSelection  0.3.6
#   writexl            1.5.4
#   readxl             1.5.0
#   dplyr              1.2.1
#   ggplot2            4.0.3
